# %% [markdown]
# # simulation with ivs data

# %% [markdown]
# ### Imports
# Import the required libraries

# %%
# package(s) related to time, space and id
import datetime, time
import platform
import random
import os
import pathlib

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy

# spatial libraries 
import pyproj
import shapely.geometry
from shapely.geometry import Point
import shapely
import geopandas as gpd
import movingpandas as mpd

# package(s) for data handling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pickle

# OpenTNSIM
import opentnsim
import opentnsim.core as core
import opentnsim.graph_module as graph_module
import opentnsim.plot as plot


# dtv_backend
import dtv_backend.fis as fis
import dtv_backend.network
import dtv_backend.network.network_utilities
import dtv_backend.postprocessing
import dtv_backend.simple
import dtv_backend.simulate

# Used for mathematical functions
import math             
import numpy as np

# Used for making the graph to visualize our problem
import networkx as nx

# %% [markdown]
# ### Create graph

# %%
#Load lock info
# url = "https://zenodo.org/records/6673604/files/FIS_locks_grouped.geojson?download=1"
# import requests
# import io
# resp = requests.get(url)
# stream = io.BytesIO(resp.content)
# locks_gdf = gpd.read_file(stream)

# %%
#Load graph
graph1 =pickle.load(open("data\euris\euris_graph_v0.1.pickle", "rb"))

# remove edge ('NL5245', 'NLJ1934')
graph1.remove_edge((("NL"),('J5245')), (("NL"),('J1934')))

graph = graph_module.Graph()
graph.graph = graph1
graph.graph_info = opentnsim.utils.info(graph.graph)

# %%
print(graph.graph[('RO', 'D5940')])
# Out:
# {('RO', 'D7500'): {'name': 'Danube 1075-1059.4 (RS-RO)', 'name_cb': None, 'cntrycode': 'RO', 'cntrycode_cb': 'RS', 'fw_code': '00001', 'fw_code_cb': '00001', 'seq_nr': 'D7500', 'seq_nr_cb': '10750', 'code_cb': 'RS0000110750', 'ww_name': 'Dunărea', 'ww_name_cb': 'Dunav', 'rt_name': 'Route Danube', 'rt_name_cb': 'Route Danube', 'wwauthorit': 'RNA Drobeta', 'wwauthorit_cb': 'Direkcija za vodne puteve - Plovput', 'cemt': 'VII', 'mdraughtcm': 250.0, 'mlengthcm': 14000.0, 'mlencon': 30000.0, 'mwidthcm': 1200.0, 'mwidcon': 3300.0, 'speed': '18', 'speedcon': '18', 'calspeed_up': 8.0, 'calspeed_down': 15.0, 'calspeedc_up': 8.0, 'calspeedc_down': 15.0, 'maxspeed_up': nan, 'maxspeed_down': nan, 'maxspeedc_up': nan, 'maxspeedc_down': nan, 'tidedep': 0, 'tot_length': nan, 'estuary': nan, 'active': 1, 'ww_charges': nan, 'remark': None, 'istentec': None, 'geometry': <LINESTRING (21.36 44.821, 21.36 44.82, 21.361 44.82, 21.361 44.82, 21.361 4...>, 'dataset': 'FairwaySection', 'date': '20240527', 'length_m': 15497.835274668165}, ('RO', '99000'): {'name': 'Danube 1059.4-990 (RS-RO)', 'name_cb': None, 'cntrycode': 'RO', 'cntrycode_cb': 'RS', 'fw_code': '00001', 'fw_code_cb': '00001', 'seq_nr': 'D5940', 'seq_nr_cb': '10594', 'code_cb': 'RS0000110594', 'ww_name': 'Dunărea', 'ww_name_cb': 'Dunav', 'rt_name': 'Route Danube', 'rt_name_cb': 'Route Danube', 'wwauthorit': 'RNA Drobeta', 'wwauthorit_cb': 'Direkcija za vodne puteve - Plovput', 'cemt': 'VII', 'mdraughtcm': 250.0, 'mlengthcm': 14000.0, 'mlencon': 30000.0, 'mwidthcm': 1200.0, 'mwidcon': 3300.0, 'speed': '18', 'speedcon': '18', 'calspeed_up': 8.0, 'calspeed_down': 15.0, 'calspeedc_up': 8.0, 'calspeedc_down': 15.0, 'maxspeed_up': nan, 'maxspeed_down': nan, 'maxspeedc_up': nan, 'maxspeedc_down': nan, 'tidedep': 0, 'tot_length': nan, 'estuary': nan, 'active': 1, 'ww_charges': nan, 'remark': None, 'istentec': None, 'geometry': <LINESTRING (21.517 44.773, 21.519 44.773, 21.522 44.773, 21.524 44.773, 21....>, 'dataset': 'FairwaySection', 'date': '20240527', 'length_m': 68378.22564548017}}

# %%
# save afzetting in geopanda
afzetting = pd.DataFrame({'A': graph1.nodes[(("NL"),('J5245'))],
'B': graph1.nodes[(("NL"),('J1934'))]}).T
afzetting = gpd.GeoDataFrame(afzetting[['ww_name', 'rt_name', 'locode', 'objectname', 'sectionref', 'hectom', 'geometry', 'date']])
afzetting.to_file('dtv_backend/plots_routes/afzetting_locatie')

# %%
# save graph in geopanda
df_edges = nx.to_pandas_edgelist(graph1)
gpd_edges = gpd.GeoDataFrame(df_edges)
gpd_edges['target'] = gpd_edges.target.str.join("_") # shape file cannot handle tuples
gpd_edges['source'] = gpd_edges.source.str.join("_") # shape file cannot handle tuples
gpd_edges.to_file('dtv_backend/plots_routes/edges_met_afzetting')
# Out:
# D:\Users\ALPF\AppData\Local\Temp\ipykernel_16896\2826873833.py:6: UserWarning:
#
# Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.

# %% [markdown]
# ### Make vessels and paths

# %% [markdown]
# ##### read data

# %%
# lees data in.
data = gpd.read_file("dtv_backend\data\ivs\ivs-2024-geocoded-sample.gpkg")

#filter data op bestaande iso datum en geometry.
data['datetime'] = pd.to_datetime(data['v05_06_begindt_evenement_iso'], format = 'ISO8601', errors = 'coerce')
data.dropna(subset = ['datetime', 'geometry'], inplace = True)
# Out:
# D:\Users\ALPF\AppData\Local\Temp\ipykernel_16896\114855860.py:5: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`

# %% [markdown]
# filter only on rotterdam to duisburg, 2023. Only keep 5 ships

# %%
data = data[
    (data.UNLO_herkomst== "NLDOR")
    #(data.UNLO_herkomst== "NLGAM")
     & (data.UNLO_bestemming.str.startswith("DE"))
     & (data.v05_06_begindt_evenement_iso.str.startswith("2023"))
     ].head()
data
# Out:
#        Jaarmaand  Jaar  Maand  Weeknr v05_06_begindt_evenement_iso  \
# 14694       2308  2023      8      32    2023-08-10T08:00:00+02:00
# 20814       2301  2023      1       1    2023-01-04T16:00:00+01:00
# 27391       2309  2023      9      39    2023-09-25T10:00:00+02:00
# 32727       2309  2023      9      39    2023-09-26T06:00:00+02:00
# 35894       2308  2023      8      32    2023-08-12T15:00:00+02:00
#
#              v05_06_Begindt_evenement UNLO_herkomst UNLO_bestemming  \
# 14694   10 augustus 2023 08:00:00 uur         NLDOR           DEDUI
# 20814    04 januari 2023 16:00:00 uur         NLDOR           DEMHG
# 27391  25 september 2023 10:00:00 uur         NLDOR           DENSS
# 32727  26 september 2023 06:00:00 uur         NLDOR           DEGEK
# 35894   12 augustus 2023 15:00:00 uur         NLDOR           DEFRA
#
#       v15_1_Scheepstype_RWS SK_CODE  v18_Laadvermogen  v28_Beladingscode  \
# 14694                     9     C3l            4320.0                5.0
# 20814                     9     C3l            5730.0                7.0
# 27391                     2      M3             690.0                5.0
# 32727                     1      M2             510.0                7.0
# 35894                    21  BII-2L            5320.0                5.0
#
#        v38_Vervoerd_gewicht  v30_4_Containers_TEU_S nstr_nw nst2007_nw  \
# 14694                   0.0                     0.0       9         16
# 20814             3550000.0                     0.0       2        2.1
# 27391                   0.0                     0.0       9         16
# 32727              375000.0                     0.0       0        1.1
# 35894                   0.0                     0.0       9         16
#
#                                               geometry  \
# 14694  LINESTRING (4.63333 51.78333, 6.75000 51.46667)
# 20814  LINESTRING (4.63333 51.78333, 8.45000 49.48333)
# 27391  LINESTRING (4.63333 51.78333, 6.68333 51.18333)
# 32727  LINESTRING (4.63333 51.78333, 7.11667 51.51667)
# 35894  LINESTRING (4.63333 51.78333, 8.68333 50.11667)
#
#                         datetime
# 14694  2023-08-10 08:00:00+02:00
# 20814  2023-01-04 16:00:00+01:00
# 27391  2023-09-25 10:00:00+02:00
# 32727  2023-09-26 06:00:00+02:00
# 35894  2023-08-12 15:00:00+02:00

# %% [markdown]
# ##### Create vessels

# %%
path
# Out:
# [('NL', 'J2676'),
#  ('NL', 'J2140'),
#  ('NL', 'J2139'),
#  ('NL', 'J2138'),
#  ('NL', 'J2137'),
#  ('NL', 'J2136'),
#  ('NL', 'J2323'),
#  ('NL', 'J2320'),
#  ('NL', 'J2319'),
#  ('NL', 'J2312'),
#  ('NL', 'J2311'),
#  ('NL', 'J2310'),
#  ('NL', 'J2309'),
#  ('NL', 'J2322'),
#  ('NL', 'J4495'),
#  ('NL', 'J2321'),
#  ('NL', 'J2174'),
#  ('NL', 'J2402'),
#  ('NL', 'J2401'),
#  ('NL', 'J2400'),
#  ('NL', 'J2399'),
#  ('NL', 'J2398'),
#  ('NL', 'J3544'),
#  ('NL', 'J2408'),
#  ('NL', 'J0871'),
#  ('NL', 'J3308'),
#  ('NL', 'J2016'),
#  ('NL', 'J2407'),
#  ('NL', 'J2406'),
#  ('NL', 'J4235'),
#  ('NL', 'J4236'),
#  ('NL', 'J2397'),
#  ('NL', 'J4230'),
#  ('NL', 'J2394'),
#  ('NL', 'J2162'),
#  ('NL', 'J4227'),
#  ('NL', 'J4228'),
#  ('NL', 'J1609'),
#  ('NL', 'J1236'),
#  ('NL', 'J2158'),
#  ('NL', 'J1813'),
#  ('NL', 'J1684'),
#  ('NL', 'J1835'),
#  ('NL', 'J1839'),
#  ('NL', 'J1834'),
#  ('NL', 'J3499'),
#  ('NL', 'J1822'),
#  ('NL', 'J1821'),
#  ('NL', 'J1823'),
#  ('NL', 'J4508'),
#  ('NL', 'J4506'),
#  ('NL', 'J1819'),
#  ('NL', 'J1817'),
#  ('NL', 'J1816'),
#  ('NL', 'J1818'),
#  ('NL', 'J1766'),
#  ('NL', 'J1820'),
#  ('NL', 'J1832'),
#  ('NL', 'J1837'),
#  ('NL', 'J1830'),
#  ('NL', 'J1826'),
#  ('NL', 'J1760'),
#  ('NL', 'J1385'),
#  ('NL', 'J1814'),
#  ('NL', 'J4254'),
#  ('NL', 'J4210'),
#  ('NL', 'J2386'),
#  ('NL', 'J2385'),
#  ('NL', 'J5240'),
#  ('NL', 'J4252'),
#  ('DE', 'J9000'),
#  ('DE', 'J3235'),
#  ('DE', 'J1141'),
#  ('DE', 'J1140'),
#  ('DE', 'J3352'),
#  ('DE', 'J3237'),
#  ('DE', 'J3238'),
#  ('DE', 'J3239'),
#  ('DE', 'J3240'),
#  ('DE', 'J1120'),
#  ('DE', 'J3242'),
#  ('DE', 'J3350'),
#  ('DE', 'J3243'),
#  ('DE', 'J3248'),
#  ('DE', 'J3249'),
#  ('DE', 'J3250'),
#  ('DE', 'J1095'),
#  ('DE', 'J3251'),
#  ('DE', 'J3351'),
#  ('DE', 'J1078'),
#  ('DE', 'J3252'),
#  ('DE', 'J3301')]

# %%
graph.graph.edges[(("NL"),("J1609")), (("NL"), ("J1236"))]
# Out:
# {'name': 'Merwedekanaal (bezuiden de Lek)',
#  'name_cb': None,
#  'cntrycode': 'NL',
#  'cntrycode_cb': None,
#  'fw_code': '00104',
#  'fw_code_cb': None,
#  'seq_nr': '01804',
#  'seq_nr_cb': None,
#  'code_cb': None,
#  'ww_name': 'Merwedekanaal (bezuiden de Lek)',
#  'ww_name_cb': None,
#  'rt_name': 'Merwedekanaal (bezuiden de Lek)',
#  'rt_name_cb': None,
#  'wwauthorit': 'RIS-NL',
#  'wwauthorit_cb': None,
#  'cemt': 'IV',
#  'mdraughtcm': 280.0,
#  'mlengthcm': 10000.0,
#  'mlencon': 10000.0,
#  'mwidthcm': 950.0,
#  'mwidcon': 950.0,
#  'speed': 'Beroepsvaart  : 12 km/u.\nRecreatievaart: 12 km/u.',
#  'speedcon': None,
#  'calspeed_up': 10.0,
#  'calspeed_down': 10.0,
#  'calspeedc_up': 10.0,
#  'calspeedc_down': 10.0,
#  'maxspeed_up': 12.0,
#  'maxspeed_down': 12.0,
#  'maxspeedc_up': nan,
#  'maxspeedc_down': nan,
#  'tidedep': 0,
#  'tot_length': 4556.0,
#  'estuary': 0.0,
#  'active': 1,
#  'ww_charges': 0.0,
#  'remark': None,
#  'istentec': None,
#  'geometry': <LINESTRING (4.997 51.871, 4.997 51.87, 4.997 51.869, 4.996 51.867, 4.995 51...>,
#  'dataset': 'FairwaySection',
#  'date': '20240527',
#  'length_m': 4555.927004110071}

# %%
# Make a class out of mix-ins
TransportResource = type('TransportResource', 
                         (core.Identifiable, core.ContainerDependentMovable, 
                          core.HasResource, core.Routable,
                          core.VesselProperties,
                         core.ExtraMetadata), 
                         {})

#define speed: 
def compute_v_provider(v_empty, v_full):
    return lambda x: 1

# define weight
def compute_weight(origin, target, dictionary):
    if dictionary['cemt'] == 'IV': #niet langs te kleine wegen
        return None
    elif origin[1] == 'J0103':
        return None
    else:
        return dictionary['length_m']

vessels = []
for index, row in data.iterrows():
    #determine path
    point_1 = fis.find_closest_node(graph.graph, Point(row.geometry.coords[0]))
    point_2 = fis.find_closest_node(graph.graph, Point(row.geometry.coords[-1]))
    path = nx.dijkstra_path(graph.graph, point_1[0], point_2[0], weight = compute_weight) 
    #determine capacity
    capacity = max(row.v18_Laadvermogen*1000, row.v38_Vervoerd_gewicht, 1)
    data_vessel = {"env": None,
               "name": row.name,
               "type": row['v15_1_Scheepstype_RWS'],
               "B": 1,
               "L": 10,
               "route": path,
               "geometry": Point(row.geometry.coords[0]),  # lon, lat
               "capacity": capacity,
               "v": 1,
               "compute_v": compute_v_provider(v_empty=1, v_full=1),
               }
    vessel = TransportResource(**data_vessel)
    vessels.append(vessel)

# %% [markdown]
# # sluis maken

# %% [markdown]
# Een sluis maken is mogelijk. Hiervoor moet de sluismodule wel worden aangepast. Dit is nu niet in dit script verwerkt

# %% [markdown]
# ### Start simulation

# %%
def start(env, vessel):
    while True:
        vessel.log_entry_v0("Start sailing", env.now, "", vessel.geometry)
        yield from vessel.move()
        vessel.log_entry_v0("Stop sailing", env.now, "", vessel.geometry)
        
        if vessel.geometry == nx.get_node_attributes(env.FG, "geometry")[vessel.route[-1]]:
            break

# %%
# Start simpy environment
simulation_start = datetime.datetime.now()
env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
env.epoch = time.mktime(simulation_start.timetuple())


# Add graph to environment
#graph.add_resources(list(graph.graph.edges), np.ones(len(list(graph.graph.edges))), env)
env.FG = graph.graph

# %%
vessels = vessels[0:3]
for i, vessel in enumerate(vessels):
    # Add environment and path to the vessel
    vessel.env = env

    # Add the movements of the vessel to the simulation
    env.process(start(env, vessel))


env.epoch = datetime.datetime.now() #TODO standaard datum kiezen.

env.run()

# %% [markdown]
# ### Obtain vessel log information
# The cel below uses the vessel log. The core function *log_entry* is used, which takes four arguments:
#
# - **Log.** A text to describe what is logged.
# - **t.** The timestamp.
# - **Value.**  The value for the log (for sailing this is the distance).
# - **Geometry** The location of the vessel while loggin.

# %%
vessel_log = gpd.GeoDataFrame(vessels[0].logbook, geometry='Geometry')
vessel_log = mpd.Trajectory(vessel_log, traj_id='vessel_1_trip_1', obj_id='vessel_1', t='Timestamp')
#vessel_log.to_line_gdf()
vessel_log.to_line_gdf().to_file('dtv_backend/plots_routes/dordrecht_afzetting_met_weight_function.gpkg')
# Out:
# d:\Users\ALPF\AppData\Local\pypoetry\Cache\virtualenvs\dtv-backend-pvs5eNot-py3.10\lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.

# %%
vessels[0].logbook
# Out:
# [{'Message': 'Start sailing',
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 11, 45),
#   'Value': '',
#   'Geometry': <POINT (4.633 51.783)>},
#  {'Message': 'Sailing to start',
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 18, 0, 340248),
#   'Value': 375.34024804315567,
#   'Geometry': <POINT (4.635 51.787)>},
#  {'Message': "Sailing from node ('NL', 'J2676') to node ('NL', 'J2140') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 18, 0, 340248),
#   'Value': 0,
#   'Geometry': <POINT (4.635 51.787)>},
#  {'Message': "Sailing from node ('NL', 'J2676') to node ('NL', 'J2140') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 22, 51, 189663),
#   'Value': 0,
#   'Geometry': <POINT (4.637 51.789)>},
#  {'Message': "Sailing from node ('NL', 'J2676') to node ('NL', 'J2140') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 22, 51, 189663),
#   'Value': 0,
#   'Geometry': <POINT (4.637 51.789)>},
#  {'Message': "Sailing from node ('NL', 'J2676') to node ('NL', 'J2140') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 24, 58, 613301),
#   'Value': 0,
#   'Geometry': <POINT (4.638 51.79)>},
#  {'Message': "Sailing from node ('NL', 'J2140') to node ('NL', 'J2139') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 24, 58, 613301),
#   'Value': 0,
#   'Geometry': <POINT (4.638 51.79)>},
#  {'Message': "Sailing from node ('NL', 'J2140') to node ('NL', 'J2139') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 28, 8, 746948),
#   'Value': 0,
#   'Geometry': <POINT (4.636 51.791)>},
#  {'Message': "Sailing from node ('NL', 'J2140') to node ('NL', 'J2139') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 28, 8, 746948),
#   'Value': 0,
#   'Geometry': <POINT (4.636 51.791)>},
#  {'Message': "Sailing from node ('NL', 'J2140') to node ('NL', 'J2139') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 29, 55, 375823),
#   'Value': 0,
#   'Geometry': <POINT (4.636 51.792)>},
#  {'Message': "Sailing from node ('NL', 'J2139') to node ('NL', 'J2138') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 29, 55, 375823),
#   'Value': 0,
#   'Geometry': <POINT (4.636 51.792)>},
#  {'Message': "Sailing from node ('NL', 'J2139') to node ('NL', 'J2138') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 32, 31, 250035),
#   'Value': 0,
#   'Geometry': <POINT (4.635 51.794)>},
#  {'Message': "Sailing from node ('NL', 'J2138') to node ('NL', 'J2137') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 32, 31, 250035),
#   'Value': 0,
#   'Geometry': <POINT (4.635 51.794)>},
#  {'Message': "Sailing from node ('NL', 'J2138') to node ('NL', 'J2137') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 34, 15, 647625),
#   'Value': 0,
#   'Geometry': <POINT (4.634 51.794)>},
#  {'Message': "Sailing from node ('NL', 'J2137') to node ('NL', 'J2136') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 34, 15, 647625),
#   'Value': 0,
#   'Geometry': <POINT (4.634 51.794)>},
#  {'Message': "Sailing from node ('NL', 'J2137') to node ('NL', 'J2136') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 35, 8, 44566),
#   'Value': 0,
#   'Geometry': <POINT (4.634 51.795)>},
#  {'Message': "Sailing from node ('NL', 'J2137') to node ('NL', 'J2136') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 35, 8, 44566),
#   'Value': 0,
#   'Geometry': <POINT (4.634 51.795)>},
#  {'Message': "Sailing from node ('NL', 'J2137') to node ('NL', 'J2136') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 38, 7, 746682),
#   'Value': 0,
#   'Geometry': <POINT (4.633 51.796)>},
#  {'Message': "Sailing from node ('NL', 'J2137') to node ('NL', 'J2136') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 38, 7, 746682),
#   'Value': 0,
#   'Geometry': <POINT (4.633 51.796)>},
#  {'Message': "Sailing from node ('NL', 'J2137') to node ('NL', 'J2136') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 44, 26, 670233),
#   'Value': 0,
#   'Geometry': <POINT (4.63 51.799)>},
#  {'Message': "Sailing from node ('NL', 'J2137') to node ('NL', 'J2136') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 44, 26, 670233),
#   'Value': 0,
#   'Geometry': <POINT (4.63 51.799)>},
#  {'Message': "Sailing from node ('NL', 'J2137') to node ('NL', 'J2136') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 48, 11, 652013),
#   'Value': 0,
#   'Geometry': <POINT (4.629 51.801)>},
#  {'Message': "Sailing from node ('NL', 'J2136') to node ('NL', 'J2323') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 48, 11, 652013),
#   'Value': 0,
#   'Geometry': <POINT (4.629 51.801)>},
#  {'Message': "Sailing from node ('NL', 'J2136') to node ('NL', 'J2323') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 49, 29, 658006),
#   'Value': 0,
#   'Geometry': <POINT (4.63 51.801)>},
#  {'Message': "Sailing from node ('NL', 'J2323') to node ('NL', 'J2320') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 49, 29, 658006),
#   'Value': 0,
#   'Geometry': <POINT (4.63 51.801)>},
#  {'Message': "Sailing from node ('NL', 'J2323') to node ('NL', 'J2320') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 54, 50, 9925),
#   'Value': 0,
#   'Geometry': <POINT (4.634 51.802)>},
#  {'Message': "Sailing from node ('NL', 'J2323') to node ('NL', 'J2320') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 54, 50, 9925),
#   'Value': 0,
#   'Geometry': <POINT (4.634 51.802)>},
#  {'Message': "Sailing from node ('NL', 'J2323') to node ('NL', 'J2320') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 56, 14, 922280),
#   'Value': 0,
#   'Geometry': <POINT (4.635 51.803)>},
#  {'Message': "Sailing from node ('NL', 'J2320') to node ('NL', 'J2319') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 10, 56, 14, 922280),
#   'Value': 0,
#   'Geometry': <POINT (4.635 51.803)>},
#  {'Message': "Sailing from node ('NL', 'J2320') to node ('NL', 'J2319') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 0, 47, 229601),
#   'Value': 0,
#   'Geometry': <POINT (4.638 51.804)>},
#  {'Message': "Sailing from node ('NL', 'J2320') to node ('NL', 'J2319') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 0, 47, 229601),
#   'Value': 0,
#   'Geometry': <POINT (4.638 51.804)>},
#  {'Message': "Sailing from node ('NL', 'J2320') to node ('NL', 'J2319') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 3, 10, 267032),
#   'Value': 0,
#   'Geometry': <POINT (4.64 51.805)>},
#  {'Message': "Sailing from node ('NL', 'J2320') to node ('NL', 'J2319') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 3, 10, 267032),
#   'Value': 0,
#   'Geometry': <POINT (4.64 51.805)>},
#  {'Message': "Sailing from node ('NL', 'J2320') to node ('NL', 'J2319') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 5, 57, 456913),
#   'Value': 0,
#   'Geometry': <POINT (4.642 51.806)>},
#  {'Message': "Sailing from node ('NL', 'J2319') to node ('NL', 'J2312') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 5, 57, 456913),
#   'Value': 0,
#   'Geometry': <POINT (4.642 51.806)>},
#  {'Message': "Sailing from node ('NL', 'J2319') to node ('NL', 'J2312') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 8, 26, 984291),
#   'Value': 0,
#   'Geometry': <POINT (4.644 51.806)>},
#  {'Message': "Sailing from node ('NL', 'J2319') to node ('NL', 'J2312') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 8, 26, 984291),
#   'Value': 0,
#   'Geometry': <POINT (4.644 51.806)>},
#  {'Message': "Sailing from node ('NL', 'J2319') to node ('NL', 'J2312') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 10, 45, 859106),
#   'Value': 0,
#   'Geometry': <POINT (4.645 51.807)>},
#  {'Message': "Sailing from node ('NL', 'J2319') to node ('NL', 'J2312') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 10, 45, 859106),
#   'Value': 0,
#   'Geometry': <POINT (4.645 51.807)>},
#  {'Message': "Sailing from node ('NL', 'J2319') to node ('NL', 'J2312') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 21, 5, 426219),
#   'Value': 0,
#   'Geometry': <POINT (4.651 51.812)>},
#  {'Message': "Sailing from node ('NL', 'J2319') to node ('NL', 'J2312') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 21, 5, 426219),
#   'Value': 0,
#   'Geometry': <POINT (4.651 51.812)>},
#  {'Message': "Sailing from node ('NL', 'J2319') to node ('NL', 'J2312') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 23, 22, 176235),
#   'Value': 0,
#   'Geometry': <POINT (4.652 51.812)>},
#  {'Message': "Sailing from node ('NL', 'J2312') to node ('NL', 'J2311') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 23, 22, 176235),
#   'Value': 0,
#   'Geometry': <POINT (4.652 51.812)>},
#  {'Message': "Sailing from node ('NL', 'J2312') to node ('NL', 'J2311') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 30, 3, 934332),
#   'Value': 0,
#   'Geometry': <POINT (4.656 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J2312') to node ('NL', 'J2311') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 30, 3, 934332),
#   'Value': 0,
#   'Geometry': <POINT (4.656 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J2312') to node ('NL', 'J2311') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 30, 6, 763677),
#   'Value': 0,
#   'Geometry': <POINT (4.656 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J2311') to node ('NL', 'J2310') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 30, 6, 763677),
#   'Value': 0,
#   'Geometry': <POINT (4.656 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J2311') to node ('NL', 'J2310') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 31, 9, 9871),
#   'Value': 0,
#   'Geometry': <POINT (4.657 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2310') to node ('NL', 'J2309') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 31, 9, 9871),
#   'Value': 0,
#   'Geometry': <POINT (4.657 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2310') to node ('NL', 'J2309') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 31, 18, 229549),
#   'Value': 0,
#   'Geometry': <POINT (4.657 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2310') to node ('NL', 'J2309') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 31, 18, 229549),
#   'Value': 0,
#   'Geometry': <POINT (4.657 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2310') to node ('NL', 'J2309') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 32, 50, 171975),
#   'Value': 0,
#   'Geometry': <POINT (4.658 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2310') to node ('NL', 'J2309') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 32, 50, 171975),
#   'Value': 0,
#   'Geometry': <POINT (4.658 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2310') to node ('NL', 'J2309') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 34, 34, 984650),
#   'Value': 0,
#   'Geometry': <POINT (4.659 51.817)>},
#  {'Message': "Sailing from node ('NL', 'J2309') to node ('NL', 'J2322') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 34, 34, 984650),
#   'Value': 0,
#   'Geometry': <POINT (4.659 51.817)>},
#  {'Message': "Sailing from node ('NL', 'J2309') to node ('NL', 'J2322') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 34, 42, 56603),
#   'Value': 0,
#   'Geometry': <POINT (4.659 51.817)>},
#  {'Message': "Sailing from node ('NL', 'J2309') to node ('NL', 'J2322') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 34, 42, 56603),
#   'Value': 0,
#   'Geometry': <POINT (4.659 51.817)>},
#  {'Message': "Sailing from node ('NL', 'J2309') to node ('NL', 'J2322') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 39, 22, 450683),
#   'Value': 0,
#   'Geometry': <POINT (4.662 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J2309') to node ('NL', 'J2322') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 39, 22, 450683),
#   'Value': 0,
#   'Geometry': <POINT (4.662 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J2309') to node ('NL', 'J2322') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 46, 23, 626487),
#   'Value': 0,
#   'Geometry': <POINT (4.667 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2309') to node ('NL', 'J2322') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 46, 23, 626487),
#   'Value': 0,
#   'Geometry': <POINT (4.667 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2309') to node ('NL', 'J2322') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 46, 58, 111627),
#   'Value': 0,
#   'Geometry': <POINT (4.668 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2322') to node ('NL', 'J4495') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 46, 58, 111627),
#   'Value': 0,
#   'Geometry': <POINT (4.668 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2322') to node ('NL', 'J4495') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 49, 48, 990360),
#   'Value': 0,
#   'Geometry': <POINT (4.67 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J4495') to node ('NL', 'J2321') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 49, 48, 990360),
#   'Value': 0,
#   'Geometry': <POINT (4.67 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J4495') to node ('NL', 'J2321') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 51, 32, 887958),
#   'Value': 0,
#   'Geometry': <POINT (4.671 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J2321') to node ('NL', 'J2174') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 51, 32, 887958),
#   'Value': 0,
#   'Geometry': <POINT (4.671 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J2321') to node ('NL', 'J2174') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 54, 35, 847465),
#   'Value': 0,
#   'Geometry': <POINT (4.673 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2321') to node ('NL', 'J2174') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 54, 35, 847465),
#   'Value': 0,
#   'Geometry': <POINT (4.673 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2321') to node ('NL', 'J2174') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 57, 53, 299568),
#   'Value': 0,
#   'Geometry': <POINT (4.676 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2174') to node ('NL', 'J2402') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 11, 57, 53, 299568),
#   'Value': 0,
#   'Geometry': <POINT (4.676 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2174') to node ('NL', 'J2402') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 4, 44, 508169),
#   'Value': 0,
#   'Geometry': <POINT (4.682 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2174') to node ('NL', 'J2402') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 4, 44, 508169),
#   'Value': 0,
#   'Geometry': <POINT (4.682 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2174') to node ('NL', 'J2402') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 10, 41, 493946),
#   'Value': 0,
#   'Geometry': <POINT (4.687 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2174') to node ('NL', 'J2402') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 10, 41, 493946),
#   'Value': 0,
#   'Geometry': <POINT (4.687 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J2174') to node ('NL', 'J2402') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 13, 36, 679431),
#   'Value': 0,
#   'Geometry': <POINT (4.69 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J2402') to node ('NL', 'J2401') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 13, 36, 679431),
#   'Value': 0,
#   'Geometry': <POINT (4.69 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J2402') to node ('NL', 'J2401') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 20, 4, 149908),
#   'Value': 0,
#   'Geometry': <POINT (4.695 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J2402') to node ('NL', 'J2401') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 20, 4, 149908),
#   'Value': 0,
#   'Geometry': <POINT (4.695 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J2402') to node ('NL', 'J2401') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 20, 36, 909192),
#   'Value': 0,
#   'Geometry': <POINT (4.696 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2401') to node ('NL', 'J2400') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 20, 36, 909192),
#   'Value': 0,
#   'Geometry': <POINT (4.696 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2401') to node ('NL', 'J2400') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 22, 35, 797044),
#   'Value': 0,
#   'Geometry': <POINT (4.697 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2401') to node ('NL', 'J2400') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 22, 35, 797044),
#   'Value': 0,
#   'Geometry': <POINT (4.697 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2401') to node ('NL', 'J2400') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 31, 12, 336353),
#   'Value': 0,
#   'Geometry': <POINT (4.705 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2401') to node ('NL', 'J2400') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 31, 12, 336353),
#   'Value': 0,
#   'Geometry': <POINT (4.705 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2401') to node ('NL', 'J2400') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 35, 26, 406711),
#   'Value': 0,
#   'Geometry': <POINT (4.708 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2400') to node ('NL', 'J2399') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 35, 26, 406711),
#   'Value': 0,
#   'Geometry': <POINT (4.708 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2400') to node ('NL', 'J2399') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 36, 39, 440111),
#   'Value': 0,
#   'Geometry': <POINT (4.709 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2400') to node ('NL', 'J2399') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 36, 39, 440111),
#   'Value': 0,
#   'Geometry': <POINT (4.709 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2400') to node ('NL', 'J2399') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 41, 28, 546387),
#   'Value': 0,
#   'Geometry': <POINT (4.714 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2399') to node ('NL', 'J2398') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 41, 28, 546387),
#   'Value': 0,
#   'Geometry': <POINT (4.714 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2399') to node ('NL', 'J2398') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 43, 51, 64326),
#   'Value': 0,
#   'Geometry': <POINT (4.716 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2399') to node ('NL', 'J2398') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 43, 51, 64326),
#   'Value': 0,
#   'Geometry': <POINT (4.716 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2399') to node ('NL', 'J2398') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 52, 46, 127662),
#   'Value': 0,
#   'Geometry': <POINT (4.723 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2398') to node ('NL', 'J3544') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 52, 46, 127662),
#   'Value': 0,
#   'Geometry': <POINT (4.723 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2398') to node ('NL', 'J3544') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 57, 5, 706619),
#   'Value': 0,
#   'Geometry': <POINT (4.727 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2398') to node ('NL', 'J3544') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 12, 57, 5, 706619),
#   'Value': 0,
#   'Geometry': <POINT (4.727 51.823)>},
#  {'Message': "Sailing from node ('NL', 'J2398') to node ('NL', 'J3544') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 4, 20, 945096),
#   'Value': 0,
#   'Geometry': <POINT (4.734 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 4, 20, 945096),
#   'Value': 0,
#   'Geometry': <POINT (4.734 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 10, 44, 707306),
#   'Value': 0,
#   'Geometry': <POINT (4.739 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 10, 44, 707306),
#   'Value': 0,
#   'Geometry': <POINT (4.739 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 16, 32, 655946),
#   'Value': 0,
#   'Geometry': <POINT (4.744 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 16, 32, 655946),
#   'Value': 0,
#   'Geometry': <POINT (4.744 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 20, 28, 993252),
#   'Value': 0,
#   'Geometry': <POINT (4.748 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 20, 28, 993252),
#   'Value': 0,
#   'Geometry': <POINT (4.748 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 22, 6, 695625),
#   'Value': 0,
#   'Geometry': <POINT (4.749 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 4 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 22, 6, 695625),
#   'Value': 0,
#   'Geometry': <POINT (4.749 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 4 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 24, 20, 767457),
#   'Value': 0,
#   'Geometry': <POINT (4.751 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 5 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 24, 20, 767457),
#   'Value': 0,
#   'Geometry': <POINT (4.751 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 5 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 26, 44, 631022),
#   'Value': 0,
#   'Geometry': <POINT (4.753 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 6 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 26, 44, 631022),
#   'Value': 0,
#   'Geometry': <POINT (4.753 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 6 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 29, 18, 832530),
#   'Value': 0,
#   'Geometry': <POINT (4.755 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 7 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 29, 18, 832530),
#   'Value': 0,
#   'Geometry': <POINT (4.755 51.821)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 7 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 30, 59, 27540),
#   'Value': 0,
#   'Geometry': <POINT (4.756 51.82)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 8 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 30, 59, 27540),
#   'Value': 0,
#   'Geometry': <POINT (4.756 51.82)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 8 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 31, 42, 227280),
#   'Value': 0,
#   'Geometry': <POINT (4.756 51.82)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 9 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 31, 42, 227280),
#   'Value': 0,
#   'Geometry': <POINT (4.756 51.82)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 9 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 32, 44, 79153),
#   'Value': 0,
#   'Geometry': <POINT (4.757 51.82)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 10 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 32, 44, 79153),
#   'Value': 0,
#   'Geometry': <POINT (4.757 51.82)>},
#  {'Message': "Sailing from node ('NL', 'J3544') to node ('NL', 'J2408') sub edge 10 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 34, 15, 301051),
#   'Value': 0,
#   'Geometry': <POINT (4.758 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 34, 15, 301051),
#   'Value': 0,
#   'Geometry': <POINT (4.758 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 38, 13, 642439),
#   'Value': 0,
#   'Geometry': <POINT (4.761 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 38, 13, 642439),
#   'Value': 0,
#   'Geometry': <POINT (4.761 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 44, 42, 386517),
#   'Value': 0,
#   'Geometry': <POINT (4.766 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 44, 42, 386517),
#   'Value': 0,
#   'Geometry': <POINT (4.766 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 47, 25, 593689),
#   'Value': 0,
#   'Geometry': <POINT (4.768 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 47, 25, 593689),
#   'Value': 0,
#   'Geometry': <POINT (4.768 51.816)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 48, 55, 99959),
#   'Value': 0,
#   'Geometry': <POINT (4.769 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 4 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 48, 55, 99959),
#   'Value': 0,
#   'Geometry': <POINT (4.769 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 4 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 56, 28, 704607),
#   'Value': 0,
#   'Geometry': <POINT (4.776 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 5 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 13, 56, 28, 704607),
#   'Value': 0,
#   'Geometry': <POINT (4.776 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J2408') to node ('NL', 'J0871') sub edge 5 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 3, 58, 73689),
#   'Value': 0,
#   'Geometry': <POINT (4.783 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 3, 58, 73689),
#   'Value': 0,
#   'Geometry': <POINT (4.783 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 6, 59, 875756),
#   'Value': 0,
#   'Geometry': <POINT (4.785 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 6, 59, 875756),
#   'Value': 0,
#   'Geometry': <POINT (4.785 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 10, 3, 875334),
#   'Value': 0,
#   'Geometry': <POINT (4.788 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 10, 3, 875334),
#   'Value': 0,
#   'Geometry': <POINT (4.788 51.815)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 18, 32, 235334),
#   'Value': 0,
#   'Geometry': <POINT (4.795 51.817)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 18, 32, 235334),
#   'Value': 0,
#   'Geometry': <POINT (4.795 51.817)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 24, 47, 663635),
#   'Value': 0,
#   'Geometry': <POINT (4.8 51.817)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 4 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 24, 47, 663635),
#   'Value': 0,
#   'Geometry': <POINT (4.8 51.817)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 4 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 33, 17, 608886),
#   'Value': 0,
#   'Geometry': <POINT (4.807 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 5 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 33, 17, 608886),
#   'Value': 0,
#   'Geometry': <POINT (4.807 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 5 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 42, 5, 572817),
#   'Value': 0,
#   'Geometry': <POINT (4.815 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 6 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 42, 5, 572817),
#   'Value': 0,
#   'Geometry': <POINT (4.815 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 6 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 55, 33, 433802),
#   'Value': 0,
#   'Geometry': <POINT (4.827 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 7 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 55, 33, 433802),
#   'Value': 0,
#   'Geometry': <POINT (4.827 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J0871') to node ('NL', 'J3308') sub edge 7 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 55, 41, 663526),
#   'Value': 0,
#   'Geometry': <POINT (4.827 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J3308') to node ('NL', 'J2016') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 14, 55, 41, 663526),
#   'Value': 0,
#   'Geometry': <POINT (4.827 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J3308') to node ('NL', 'J2016') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 5, 52, 277096),
#   'Value': 0,
#   'Geometry': <POINT (4.836 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J3308') to node ('NL', 'J2016') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 5, 52, 277096),
#   'Value': 0,
#   'Geometry': <POINT (4.836 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J3308') to node ('NL', 'J2016') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 20, 4, 266219),
#   'Value': 0,
#   'Geometry': <POINT (4.848 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J3308') to node ('NL', 'J2016') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 20, 4, 266219),
#   'Value': 0,
#   'Geometry': <POINT (4.848 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J3308') to node ('NL', 'J2016') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 26, 21, 495469),
#   'Value': 0,
#   'Geometry': <POINT (4.853 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2016') to node ('NL', 'J2407') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 26, 21, 495469),
#   'Value': 0,
#   'Geometry': <POINT (4.853 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2016') to node ('NL', 'J2407') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 28, 22, 918393),
#   'Value': 0,
#   'Geometry': <POINT (4.855 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2407') to node ('NL', 'J2406') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 28, 22, 918393),
#   'Value': 0,
#   'Geometry': <POINT (4.855 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2407') to node ('NL', 'J2406') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 28, 29, 2211),
#   'Value': 0,
#   'Geometry': <POINT (4.855 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2407') to node ('NL', 'J2406') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 28, 29, 2211),
#   'Value': 0,
#   'Geometry': <POINT (4.855 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2407') to node ('NL', 'J2406') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 36, 35, 40341),
#   'Value': 0,
#   'Geometry': <POINT (4.862 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2407') to node ('NL', 'J2406') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 36, 35, 40341),
#   'Value': 0,
#   'Geometry': <POINT (4.862 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2407') to node ('NL', 'J2406') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 42, 48, 908801),
#   'Value': 0,
#   'Geometry': <POINT (4.868 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2407') to node ('NL', 'J2406') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 42, 48, 908801),
#   'Value': 0,
#   'Geometry': <POINT (4.868 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2407') to node ('NL', 'J2406') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 49, 9, 131114),
#   'Value': 0,
#   'Geometry': <POINT (4.873 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2406') to node ('NL', 'J4235') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 49, 9, 131114),
#   'Value': 0,
#   'Geometry': <POINT (4.873 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2406') to node ('NL', 'J4235') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 51, 28, 201418),
#   'Value': 0,
#   'Geometry': <POINT (4.875 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2406') to node ('NL', 'J4235') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 15, 51, 28, 201418),
#   'Value': 0,
#   'Geometry': <POINT (4.875 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2406') to node ('NL', 'J4235') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 0, 20, 572119),
#   'Value': 0,
#   'Geometry': <POINT (4.883 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2406') to node ('NL', 'J4235') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 0, 20, 572119),
#   'Value': 0,
#   'Geometry': <POINT (4.883 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J2406') to node ('NL', 'J4235') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 0, 48, 443723),
#   'Value': 0,
#   'Geometry': <POINT (4.883 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J4235') to node ('NL', 'J4236') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 0, 48, 443723),
#   'Value': 0,
#   'Geometry': <POINT (4.883 51.818)>},
#  {'Message': "Sailing from node ('NL', 'J4235') to node ('NL', 'J4236') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 10, 48, 852754),
#   'Value': 0,
#   'Geometry': <POINT (4.892 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 10, 48, 852754),
#   'Value': 0,
#   'Geometry': <POINT (4.892 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 10, 55, 691819),
#   'Value': 0,
#   'Geometry': <POINT (4.892 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 10, 55, 691819),
#   'Value': 0,
#   'Geometry': <POINT (4.892 51.819)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 19, 46, 586815),
#   'Value': 0,
#   'Geometry': <POINT (4.898 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 19, 46, 586815),
#   'Value': 0,
#   'Geometry': <POINT (4.898 51.822)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 27, 46, 280861),
#   'Value': 0,
#   'Geometry': <POINT (4.904 51.824)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 27, 46, 280861),
#   'Value': 0,
#   'Geometry': <POINT (4.904 51.824)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 36, 36, 763730),
#   'Value': 0,
#   'Geometry': <POINT (4.911 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 4 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 36, 36, 763730),
#   'Value': 0,
#   'Geometry': <POINT (4.911 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 4 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 45, 13, 669222),
#   'Value': 0,
#   'Geometry': <POINT (4.918 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 5 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 45, 13, 669222),
#   'Value': 0,
#   'Geometry': <POINT (4.918 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 5 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 49, 7, 648158),
#   'Value': 0,
#   'Geometry': <POINT (4.922 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 6 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 49, 7, 648158),
#   'Value': 0,
#   'Geometry': <POINT (4.922 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 6 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 52, 35, 740727),
#   'Value': 0,
#   'Geometry': <POINT (4.925 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 7 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 52, 35, 740727),
#   'Value': 0,
#   'Geometry': <POINT (4.925 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 7 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 56, 8, 342983),
#   'Value': 0,
#   'Geometry': <POINT (4.928 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 8 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 56, 8, 342983),
#   'Value': 0,
#   'Geometry': <POINT (4.928 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 8 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 58, 36, 636416),
#   'Value': 0,
#   'Geometry': <POINT (4.93 51.829)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 9 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 16, 58, 36, 636416),
#   'Value': 0,
#   'Geometry': <POINT (4.93 51.829)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 9 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 0, 6, 766051),
#   'Value': 0,
#   'Geometry': <POINT (4.931 51.829)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 10 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 0, 6, 766051),
#   'Value': 0,
#   'Geometry': <POINT (4.931 51.829)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 10 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 2, 44, 735754),
#   'Value': 0,
#   'Geometry': <POINT (4.934 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 11 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 2, 44, 735754),
#   'Value': 0,
#   'Geometry': <POINT (4.934 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J4236') to node ('NL', 'J2397') sub edge 11 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 4, 32, 753881),
#   'Value': 0,
#   'Geometry': <POINT (4.935 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 4, 32, 753881),
#   'Value': 0,
#   'Geometry': <POINT (4.935 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 5, 38, 101902),
#   'Value': 0,
#   'Geometry': <POINT (4.936 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 5, 38, 101902),
#   'Value': 0,
#   'Geometry': <POINT (4.936 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 6, 33, 27482),
#   'Value': 0,
#   'Geometry': <POINT (4.937 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 6, 33, 27482),
#   'Value': 0,
#   'Geometry': <POINT (4.937 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 8, 7, 355145),
#   'Value': 0,
#   'Geometry': <POINT (4.938 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 8, 7, 355145),
#   'Value': 0,
#   'Geometry': <POINT (4.938 51.828)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 13, 10, 364612),
#   'Value': 0,
#   'Geometry': <POINT (4.942 51.827)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 4 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 13, 10, 364612),
#   'Value': 0,
#   'Geometry': <POINT (4.942 51.827)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 4 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 17, 46, 271106),
#   'Value': 0,
#   'Geometry': <POINT (4.946 51.827)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 5 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 17, 46, 271106),
#   'Value': 0,
#   'Geometry': <POINT (4.946 51.827)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 5 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 23, 35, 95544),
#   'Value': 0,
#   'Geometry': <POINT (4.951 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 6 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 23, 35, 95544),
#   'Value': 0,
#   'Geometry': <POINT (4.951 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 6 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 24, 2, 243184),
#   'Value': 0,
#   'Geometry': <POINT (4.952 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 7 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 24, 2, 243184),
#   'Value': 0,
#   'Geometry': <POINT (4.952 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2397') to node ('NL', 'J4230') sub edge 7 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 24, 21, 924043),
#   'Value': 0,
#   'Geometry': <POINT (4.952 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 24, 21, 924043),
#   'Value': 0,
#   'Geometry': <POINT (4.952 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 25, 17, 883296),
#   'Value': 0,
#   'Geometry': <POINT (4.953 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 25, 17, 883296),
#   'Value': 0,
#   'Geometry': <POINT (4.953 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 25, 57, 463176),
#   'Value': 0,
#   'Geometry': <POINT (4.953 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 25, 57, 463176),
#   'Value': 0,
#   'Geometry': <POINT (4.953 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 26, 52, 508113),
#   'Value': 0,
#   'Geometry': <POINT (4.954 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 26, 52, 508113),
#   'Value': 0,
#   'Geometry': <POINT (4.954 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 27, 30, 824688),
#   'Value': 0,
#   'Geometry': <POINT (4.955 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 4 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 27, 30, 824688),
#   'Value': 0,
#   'Geometry': <POINT (4.955 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 4 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 28, 15, 183095),
#   'Value': 0,
#   'Geometry': <POINT (4.955 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 5 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 28, 15, 183095),
#   'Value': 0,
#   'Geometry': <POINT (4.955 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J4230') to node ('NL', 'J2394') sub edge 5 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 28, 43, 110947),
#   'Value': 0,
#   'Geometry': <POINT (4.956 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2394') to node ('NL', 'J2162') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 28, 43, 110947),
#   'Value': 0,
#   'Geometry': <POINT (4.956 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2394') to node ('NL', 'J2162') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 29, 17, 396363),
#   'Value': 0,
#   'Geometry': <POINT (4.956 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2394') to node ('NL', 'J2162') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 29, 17, 396363),
#   'Value': 0,
#   'Geometry': <POINT (4.956 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2394') to node ('NL', 'J2162') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 29, 58, 947883),
#   'Value': 0,
#   'Geometry': <POINT (4.957 51.826)>},
#  {'Message': "Sailing from node ('NL', 'J2394') to node ('NL', 'J2162') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 18, 17, 29, 58, 947883),
#   'Value': 0,
#   'Geometry': <POINT (4.957 51.826)>},
# ...
#   'Value': 0,
#   'Geometry': <POINT (5.397 51.974)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 20, 35, 711716),
#   'Value': 0,
#   'Geometry': <POINT (5.397 51.974)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 22, 32, 341610),
#   'Value': 0,
#   'Geometry': <POINT (5.398 51.974)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 4 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 22, 32, 341610),
#   'Value': 0,
#   'Geometry': <POINT (5.398 51.974)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 4 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 25, 34, 525975),
#   'Value': 0,
#   'Geometry': <POINT (5.401 51.975)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 5 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 25, 34, 525975),
#   'Value': 0,
#   'Geometry': <POINT (5.401 51.975)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 5 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 32, 56, 682360),
#   'Value': 0,
#   'Geometry': <POINT (5.407 51.976)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 6 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 32, 56, 682360),
#   'Value': 0,
#   'Geometry': <POINT (5.407 51.976)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 6 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 38, 32, 988769),
#   'Value': 0,
#   'Geometry': <POINT (5.412 51.977)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 7 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 38, 32, 988769),
#   'Value': 0,
#   'Geometry': <POINT (5.412 51.977)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 7 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 42, 23, 776131),
#   'Value': 0,
#   'Geometry': <POINT (5.415 51.978)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 8 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 42, 23, 776131),
#   'Value': 0,
#   'Geometry': <POINT (5.415 51.978)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 8 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 46, 55, 273496),
#   'Value': 0,
#   'Geometry': <POINT (5.418 51.979)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 9 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 46, 55, 273496),
#   'Value': 0,
#   'Geometry': <POINT (5.418 51.979)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 9 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 50, 25, 597744),
#   'Value': 0,
#   'Geometry': <POINT (5.421 51.98)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 10 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 50, 25, 597744),
#   'Value': 0,
#   'Geometry': <POINT (5.421 51.98)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 10 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 53, 18, 832920),
#   'Value': 0,
#   'Geometry': <POINT (5.423 51.981)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 11 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 53, 18, 832920),
#   'Value': 0,
#   'Geometry': <POINT (5.423 51.981)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 11 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 57, 7, 73739),
#   'Value': 0,
#   'Geometry': <POINT (5.425 51.982)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 12 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 57, 7, 73739),
#   'Value': 0,
#   'Geometry': <POINT (5.425 51.982)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 12 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 58, 20, 897660),
#   'Value': 0,
#   'Geometry': <POINT (5.426 51.982)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 13 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 58, 20, 897660),
#   'Value': 0,
#   'Geometry': <POINT (5.426 51.982)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 13 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 59, 6, 90490),
#   'Value': 0,
#   'Geometry': <POINT (5.427 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 14 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 59, 6, 90490),
#   'Value': 0,
#   'Geometry': <POINT (5.427 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 14 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 59, 46, 702031),
#   'Value': 0,
#   'Geometry': <POINT (5.427 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 15 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 7, 59, 46, 702031),
#   'Value': 0,
#   'Geometry': <POINT (5.427 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1817') to node ('NL', 'J1816') sub edge 15 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 0, 8, 704017),
#   'Value': 0,
#   'Geometry': <POINT (5.428 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1816') to node ('NL', 'J1818') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 0, 8, 704017),
#   'Value': 0,
#   'Geometry': <POINT (5.428 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1816') to node ('NL', 'J1818') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 1, 46, 386582),
#   'Value': 0,
#   'Geometry': <POINT (5.429 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 0 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 1, 46, 386582),
#   'Value': 0,
#   'Geometry': <POINT (5.429 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 0 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 3, 37, 935898),
#   'Value': 0,
#   'Geometry': <POINT (5.43 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 1 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 3, 37, 935898),
#   'Value': 0,
#   'Geometry': <POINT (5.43 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 1 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 5, 20, 236372),
#   'Value': 0,
#   'Geometry': <POINT (5.432 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 2 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 5, 20, 236372),
#   'Value': 0,
#   'Geometry': <POINT (5.432 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 2 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 7, 33, 894722),
#   'Value': 0,
#   'Geometry': <POINT (5.433 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 3 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 7, 33, 894722),
#   'Value': 0,
#   'Geometry': <POINT (5.433 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 3 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 8, 36, 8521),
#   'Value': 0,
#   'Geometry': <POINT (5.434 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 4 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 8, 36, 8521),
#   'Value': 0,
#   'Geometry': <POINT (5.434 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 4 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 9, 33, 73595),
#   'Value': 0,
#   'Geometry': <POINT (5.435 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 5 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 9, 33, 73595),
#   'Value': 0,
#   'Geometry': <POINT (5.435 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 5 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 11, 17, 177399),
#   'Value': 0,
#   'Geometry': <POINT (5.436 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 6 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 11, 17, 177399),
#   'Value': 0,
#   'Geometry': <POINT (5.436 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 6 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 12, 55, 159347),
#   'Value': 0,
#   'Geometry': <POINT (5.438 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 7 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 12, 55, 159347),
#   'Value': 0,
#   'Geometry': <POINT (5.438 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 7 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 15, 0, 183584),
#   'Value': 0,
#   'Geometry': <POINT (5.439 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 8 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 15, 0, 183584),
#   'Value': 0,
#   'Geometry': <POINT (5.439 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 8 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 16, 47, 803360),
#   'Value': 0,
#   'Geometry': <POINT (5.441 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 9 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 16, 47, 803360),
#   'Value': 0,
#   'Geometry': <POINT (5.441 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 9 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 18, 8, 465830),
#   'Value': 0,
#   'Geometry': <POINT (5.442 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 10 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 18, 8, 465830),
#   'Value': 0,
#   'Geometry': <POINT (5.442 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 10 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 19, 30, 863643),
#   'Value': 0,
#   'Geometry': <POINT (5.443 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 11 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 19, 30, 863643),
#   'Value': 0,
#   'Geometry': <POINT (5.443 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 11 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 20, 48, 632058),
#   'Value': 0,
#   'Geometry': <POINT (5.444 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 12 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 20, 48, 632058),
#   'Value': 0,
#   'Geometry': <POINT (5.444 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 12 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 22, 5, 845902),
#   'Value': 0,
#   'Geometry': <POINT (5.445 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 13 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 22, 5, 845902),
#   'Value': 0,
#   'Geometry': <POINT (5.445 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 13 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 23, 16, 645041),
#   'Value': 0,
#   'Geometry': <POINT (5.446 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 14 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 23, 16, 645041),
#   'Value': 0,
#   'Geometry': <POINT (5.446 51.986)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 14 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 24, 39, 654170),
#   'Value': 0,
#   'Geometry': <POINT (5.448 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 15 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 24, 39, 654170),
#   'Value': 0,
#   'Geometry': <POINT (5.448 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 15 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 26, 29, 16105),
#   'Value': 0,
#   'Geometry': <POINT (5.449 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 16 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 26, 29, 16105),
#   'Value': 0,
#   'Geometry': <POINT (5.449 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 16 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 27, 48, 767540),
#   'Value': 0,
#   'Geometry': <POINT (5.45 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 17 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 27, 48, 767540),
#   'Value': 0,
#   'Geometry': <POINT (5.45 51.985)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 17 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 29, 29, 966648),
#   'Value': 0,
#   'Geometry': <POINT (5.451 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 18 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 29, 29, 966648),
#   'Value': 0,
#   'Geometry': <POINT (5.451 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 18 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 31, 1, 409136),
#   'Value': 0,
#   'Geometry': <POINT (5.453 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 19 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 31, 1, 409136),
#   'Value': 0,
#   'Geometry': <POINT (5.453 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 19 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 33, 34, 2714),
#   'Value': 0,
#   'Geometry': <POINT (5.455 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 20 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 33, 34, 2714),
#   'Value': 0,
#   'Geometry': <POINT (5.455 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 20 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 36, 44, 593446),
#   'Value': 0,
#   'Geometry': <POINT (5.458 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 21 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 36, 44, 593446),
#   'Value': 0,
#   'Geometry': <POINT (5.458 51.984)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 21 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 39, 39, 384167),
#   'Value': 0,
#   'Geometry': <POINT (5.46 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 22 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 39, 39, 384167),
#   'Value': 0,
#   'Geometry': <POINT (5.46 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 22 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 42, 16, 278121),
#   'Value': 0,
#   'Geometry': <POINT (5.462 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 23 start",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 42, 16, 278121),
#   'Value': 0,
#   'Geometry': <POINT (5.462 51.983)>},
#  {'Message': "Sailing from node ('NL', 'J1818') to node ('NL', 'J1766') sub edge 23 stop",
#   'Timestamp': datetime.datetime(2024, 6, 19, 8, 45, 15, 204726),
#   'Value': 0,
#   'Geometry': <POINT (5.465 51.983)>},
#  ...]

# %% [markdown]
# ### Visualization of path
# If you get an error regarding ffmpeg use [this](https://stackoverflow.com/questions/13316397/matplotlib-animation-no-moviewriters-available) answer. You have to install ffmpeg in your Conda environment. It can be done using the following command.
#
# ```bash
# #Install ffmpeg using Conda
# conda install -c conda-forge ffmpeg
# ```

# %%
# visualise vessel movements based on the information included in the vessel.log
# plot.vessel_kml(env, vessels, stepsize = 60)
#plot.graph_kml(env)

# %%
! start explorer .
