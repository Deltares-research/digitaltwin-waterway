# %% [markdown]
# # simulation with ivs data

# %% [markdown]
# ### Imports
# Import the required libraries

# %%
# package(s) related to time, space and id
import datetime, time
import platform
import random
import os
import pathlib

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy

# spatial libraries 
import pyproj
import shapely.geometry
from shapely.geometry import Point
import shapely
import geopandas as gpd
import movingpandas as mpd

# package(s) for data handling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation

# OpenTNSIM
import opentnsim
import opentnsim.core as core
import opentnsim.graph_module as graph_module
import opentnsim.plot as plot


# dtv_backend
import dtv_backend.fis as fis
import dtv_backend.network
import dtv_backend.network.network_utilities
import dtv_backend.postprocessing
import dtv_backend.simple
import dtv_backend.simulate

# Used for mathematical functions
import math             
import numpy as np

# Used for making the graph to visualize our problem
import networkx as nx

# %% [markdown]
# ### Create graph

# %%
#Load graph
url = "https://zenodo.org/record/6673604/files/network_digital_twin_v0.3.pickle?download=1"
graph1 = dtv_backend.fis.load_fis_network(url).copy()

# remove edge ('8865412', 'B20540_A')
graph1.remove_edge('8865412', 'B20540_A')


# #remove edges without classification
# for edge in graph1.edges:
#     if str(graph1.edges[edge]['Classification']) == 'nan':
#         graph1.remove_edge(edge[0], edge[1])

graph = graph_module.Graph()
graph.graph = graph1
graph.graph_info = opentnsim.utils.info(graph.graph)

# %%
afzetting = pd.DataFrame({'A': graph1.nodes['8865412'],
'B': graph1.nodes['B20540_A']}).T
afzetting = gpd.GeoDataFrame(afzetting)
afzetting.to_file('plots_routes/afzetting_locatie')

# %%
df_edges = nx.to_pandas_edgelist(graph1)
gpd.GeoDataFrame(df_edges).to_file('plots_routes/edges_met_afzetting')
gpd.GeoDataFrame(df_edges).dtypes
# Out:
# D:\Users\ALPF\AppData\Local\Temp\ipykernel_30968\2119284774.py:2: UserWarning:
#
# Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
# source                object
# target                object
# GeneralDepth         float64
# WidePushedLength     float64
# Classification        object
# SeaFairingWidth      float64
# SeaFairingDepth      float64
# CoupledLength        float64
# subgraph               int64
# Wkt                   object
# length_m             float64
# Name                  object
# CoupledDepth         float64
# PushedDepth          float64
# GeneralLength        float64
# length_deg           float64
# StartJunctionId       object
# EndJunctionId         object
# PushedWidth          float64
# Id_navigability      float64
# Length               float64
# SeaFairingLength     float64
# WidePushedWidth      float64
# PushedLength         float64
# WidePushedDepth      float64
# Code                  object
# GeneralWidth         float64
# geometry            geometry
# length               float64
# GeoType               object
# GeneralHeight        float64
# Description           object
# SeaFairingHeight     float64
# CoupledWidth         float64
# dtype: object

# %% [markdown]
# ### Make vessels and paths

# %% [markdown]
# ##### read data

# %%
data = gpd.read_file("data\ivs\ivs-2024-geocoded-sample.gpkg")
data['datetime'] = pd.to_datetime(data['v05_06_begindt_evenement_iso'], format = 'ISO8601', errors = 'coerce')
data.dropna(subset = ['datetime', 'geometry'], inplace = True)
# Out:
# D:\Users\ALPF\AppData\Local\Temp\ipykernel_30968\2736635994.py:2: FutureWarning:
#
# In a future version of pandas, parsing datetimes with mixed time zones will raise an error unless `utc=True`. Please specify `utc=True` to opt in to the new behaviour and silence this warning. To create a `Series` with mixed offsets and `object` dtype, please use `apply` and `datetime.datetime.strptime`

# %% [markdown]
# filter only on rotterdam to duisburg, 2023. Only keep 5 ships

# %%
data1= data

# %%
data = data1
data = data[
    (data.UNLO_herkomst== "NLDOR")
    #(data.UNLO_herkomst== "NLGAM")
     & (data.UNLO_bestemming.str.startswith("DE"))
     & (data.v05_06_begindt_evenement_iso.str.startswith("2023"))
     ].head()
data
# Out:
#        Jaarmaand  Jaar  Maand  Weeknr v05_06_begindt_evenement_iso  \
# 14694       2308  2023      8      32    2023-08-10T08:00:00+02:00
# 20814       2301  2023      1       1    2023-01-04T16:00:00+01:00
# 27391       2309  2023      9      39    2023-09-25T10:00:00+02:00
# 32727       2309  2023      9      39    2023-09-26T06:00:00+02:00
# 35894       2308  2023      8      32    2023-08-12T15:00:00+02:00
#
#              v05_06_Begindt_evenement UNLO_herkomst UNLO_bestemming  \
# 14694   10 augustus 2023 08:00:00 uur         NLDOR           DEDUI
# 20814    04 januari 2023 16:00:00 uur         NLDOR           DEMHG
# 27391  25 september 2023 10:00:00 uur         NLDOR           DENSS
# 32727  26 september 2023 06:00:00 uur         NLDOR           DEGEK
# 35894   12 augustus 2023 15:00:00 uur         NLDOR           DEFRA
#
#       v15_1_Scheepstype_RWS SK_CODE  v18_Laadvermogen  v28_Beladingscode  \
# 14694                     9     C3l            4320.0                5.0
# 20814                     9     C3l            5730.0                7.0
# 27391                     2      M3             690.0                5.0
# 32727                     1      M2             510.0                7.0
# 35894                    21  BII-2L            5320.0                5.0
#
#        v38_Vervoerd_gewicht  v30_4_Containers_TEU_S nstr_nw nst2007_nw  \
# 14694                   0.0                     0.0       9         16
# 20814             3550000.0                     0.0       2        2.1
# 27391                   0.0                     0.0       9         16
# 32727              375000.0                     0.0       0        1.1
# 35894                   0.0                     0.0       9         16
#
#                                               geometry  \
# 14694  LINESTRING (4.63333 51.78333, 6.75000 51.46667)
# 20814  LINESTRING (4.63333 51.78333, 8.45000 49.48333)
# 27391  LINESTRING (4.63333 51.78333, 6.68333 51.18333)
# 32727  LINESTRING (4.63333 51.78333, 7.11667 51.51667)
# 35894  LINESTRING (4.63333 51.78333, 8.68333 50.11667)
#
#                         datetime
# 14694  2023-08-10 08:00:00+02:00
# 20814  2023-01-04 16:00:00+01:00
# 27391  2023-09-25 10:00:00+02:00
# 32727  2023-09-26 06:00:00+02:00
# 35894  2023-08-12 15:00:00+02:00

# %% [markdown]
# ##### Create vessels

# %%
# Make a class out of mix-ins
TransportResource = type('TransportResource', 
                         (core.Identifiable, core.ContainerDependentMovable, 
                          core.HasResource, core.Routable,
                          core.VesselProperties,
                         core.ExtraMetadata), 
                         {})

#define speed: 
def compute_v_provider(v_empty, v_full):
    return lambda x: 1

vessels = []
for index, row in data.iterrows():
    #determine path
    point_1 = fis.find_closest_node(graph.graph, Point(row.geometry.coords[0]))
    point_2 = fis.find_closest_node(graph.graph, Point(row.geometry.coords[-1]))
    path = nx.dijkstra_path(graph.graph, point_1[0], point_2[0])
    #determine capacity
    capacity = max(row.v18_Laadvermogen*1000, row.v38_Vervoerd_gewicht, 1)
    data_vessel = {"env": None,
               "name": row.name,
               "type": row['v15_1_Scheepstype_RWS'],
               "B": 1,
               "L": 10,
               "route": path,
               "geometry": Point(row.geometry.coords[0]),  # lon, lat
               "capacity": capacity,
               "v": 1,
               "compute_v": compute_v_provider(v_empty=1, v_full=1),
               }
    vessel = TransportResource(**data_vessel)
    vessels.append(vessel)

vessels = [TransportResource(**{
    "env" : None,
    "name": 'korte_route', 
    "type": 'M6',
    "B": 1, 
    "L": 10,
    "route": nx.dijkstra_path(graph.graph, "8865735", "8861687"),
    "geometry": Point(row.geometry.coords[0]),  # lon, lat
    "capacity": capacity,
    "v": 1,
    "compute_v": compute_v_provider(v_empty=1, v_full=1),
})]

# %% [markdown]
# ### Start simulation

# %%
def start(env, vessel):
    while True:
        vessel.log_entry_v0("Start sailing", env.now, "", vessel.geometry)
        yield from vessel.move()
        vessel.log_entry_v0("Stop sailing", env.now, "", vessel.geometry)
        
        if vessel.geometry == nx.get_node_attributes(env.FG, "geometry")[vessel.route[-1]]:
            break

# %%
# Start simpy environment
simulation_start = datetime.datetime.now()
env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
env.epoch = time.mktime(simulation_start.timetuple())


# Add graph to environment
graph.add_resources(list(graph.graph.edges), np.ones(len(list(graph.graph.edges))), env)
env.FG = graph.graph

# %%
vessels = vessels[0:3]
for i, vessel in enumerate(vessels):
    # Add environment and path to the vessel
    vessel.env = env

    # Add the movements of the vessel to the simulation
    env.process(start(env, vessel))


env.epoch = datetime.datetime.now()

env.run()

# %% [markdown]
# ### Obtain vessel log information
# The cel below uses the vessel log. The core function *log_entry* is used, which takes four arguments:
#
# - **Log.** A text to describe what is logged.
# - **t.** The timestamp.
# - **Value.**  The value for the log (for sailing this is the distance).
# - **Geometry** The location of the vessel while loggin.

# %%
vessel_log = gpd.GeoDataFrame(vessels[0].logbook, geometry='Geometry')
vessel_log = mpd.Trajectory(vessel_log, traj_id='vessel_1_trip_1', obj_id='vessel_1', t='Timestamp')
#vessel_log.to_line_gdf()
vessel_log.to_line_gdf().to_file('plots_routes/wegafzetting_logboek_movingpandas.gpkg')
# Out:
# d:\Users\ALPF\AppData\Local\pypoetry\Cache\virtualenvs\dtv-backend-pvs5eNot-py3.10\lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.

# %%
vessels[0].logbook
# Out:
# [{'Message': 'Start sailing',
#   'Timestamp': datetime.datetime(2024, 6, 3, 14, 23, 10),
#   'Value': '',
#   'Geometry': <POINT (4.633 51.783)>},
#  {'Message': 'Sailing to start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 7, 15, 180390),
#   'Value': 49445.180389901776,
#   'Geometry': <POINT (5.349 51.804)>},
#  {'Message': 'Sailing from node 8865735 to node 22638402 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 7, 15, 180390),
#   'Value': 0,
#   'Geometry': <POINT (5.349 51.804)>},
#  {'Message': 'Sailing from node 8865735 to node 22638402 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 10, 9, 283271),
#   'Value': 0,
#   'Geometry': <POINT (5.351 51.803)>},
#  {'Message': 'Sailing from node 22638402 to node B51956_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 10, 9, 283271),
#   'Value': 0,
#   'Geometry': <POINT (5.351 51.803)>},
#  {'Message': 'Sailing from node 22638402 to node B51956_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 16, 26, 394525),
#   'Value': 0,
#   'Geometry': <POINT (5.354 51.8)>},
#  {'Message': 'Sailing from node 22638402 to node B51956_B sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 16, 26, 394525),
#   'Value': 0,
#   'Geometry': <POINT (5.354 51.8)>},
#  {'Message': 'Sailing from node 22638402 to node B51956_B sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 3, 155972),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B51956_B to node B51956_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 3, 155972),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B51956_B to node B51956_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 11, 566106),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B51956_A to node B7937_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 11, 566106),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B51956_A to node B7937_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 14, 361303),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B51956_A to node B7937_B sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 14, 361303),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B51956_A to node B7937_B sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 16, 94313),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B7937_B to node B7937_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 16, 94313),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B7937_B to node B7937_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 24, 572192),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B7937_A to node L24504_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 21, 24, 572192),
#   'Value': 0,
#   'Geometry': <POINT (5.357 51.798)>},
#  {'Message': 'Sailing from node B7937_A to node L24504_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 22, 8, 133375),
#   'Value': 0,
#   'Geometry': <POINT (5.358 51.798)>},
#  {'Message': 'Sailing from node L24504_B to node L24504_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 22, 8, 133375),
#   'Value': 0,
#   'Geometry': <POINT (5.358 51.798)>},
#  {'Message': 'Sailing from node L24504_B to node L24504_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 22, 42, 45037),
#   'Value': 0,
#   'Geometry': <POINT (5.358 51.798)>},
#  {'Message': 'Sailing from node L24504_A to node 22638239 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 22, 42, 45037),
#   'Value': 0,
#   'Geometry': <POINT (5.358 51.798)>},
#  {'Message': 'Sailing from node L24504_A to node 22638239 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 23, 9, 63166),
#   'Value': 0,
#   'Geometry': <POINT (5.358 51.798)>},
#  {'Message': 'Sailing from node L24504_A to node 22638239 sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 23, 9, 63166),
#   'Value': 0,
#   'Geometry': <POINT (5.358 51.798)>},
#  {'Message': 'Sailing from node L24504_A to node 22638239 sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 24, 11, 358772),
#   'Value': 0,
#   'Geometry': <POINT (5.359 51.797)>},
#  {'Message': 'Sailing from node L24504_A to node 22638239 sub edge 2 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 24, 11, 358772),
#   'Value': 0,
#   'Geometry': <POINT (5.359 51.797)>},
#  {'Message': 'Sailing from node L24504_A to node 22638239 sub edge 2 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 26, 13, 932925),
#   'Value': 0,
#   'Geometry': <POINT (5.36 51.796)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 26, 13, 932925),
#   'Value': 0,
#   'Geometry': <POINT (5.36 51.796)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 28, 4, 280178),
#   'Value': 0,
#   'Geometry': <POINT (5.361 51.796)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 28, 4, 280178),
#   'Value': 0,
#   'Geometry': <POINT (5.361 51.796)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 29, 59, 655857),
#   'Value': 0,
#   'Geometry': <POINT (5.362 51.795)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 2 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 29, 59, 655857),
#   'Value': 0,
#   'Geometry': <POINT (5.362 51.795)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 2 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 32, 43, 564800),
#   'Value': 0,
#   'Geometry': <POINT (5.364 51.794)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 3 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 32, 43, 564800),
#   'Value': 0,
#   'Geometry': <POINT (5.364 51.794)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 3 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 34, 46, 230524),
#   'Value': 0,
#   'Geometry': <POINT (5.366 51.793)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 4 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 34, 46, 230524),
#   'Value': 0,
#   'Geometry': <POINT (5.366 51.793)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 4 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 36, 16, 377933),
#   'Value': 0,
#   'Geometry': <POINT (5.367 51.793)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 5 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 36, 16, 377933),
#   'Value': 0,
#   'Geometry': <POINT (5.367 51.793)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 5 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 37, 43, 386259),
#   'Value': 0,
#   'Geometry': <POINT (5.368 51.792)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 6 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 37, 43, 386259),
#   'Value': 0,
#   'Geometry': <POINT (5.368 51.792)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 6 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 38, 47, 400197),
#   'Value': 0,
#   'Geometry': <POINT (5.368 51.792)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 7 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 38, 47, 400197),
#   'Value': 0,
#   'Geometry': <POINT (5.368 51.792)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 7 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 39, 9, 963384),
#   'Value': 0,
#   'Geometry': <POINT (5.368 51.792)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 8 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 39, 9, 963384),
#   'Value': 0,
#   'Geometry': <POINT (5.368 51.792)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 8 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 40, 36, 319780),
#   'Value': 0,
#   'Geometry': <POINT (5.369 51.791)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 9 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 40, 36, 319780),
#   'Value': 0,
#   'Geometry': <POINT (5.369 51.791)>},
#  {'Message': 'Sailing from node 22638239 to node 22637914 sub edge 9 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 41, 16, 20262),
#   'Value': 0,
#   'Geometry': <POINT (5.369 51.791)>},
#  {'Message': 'Sailing from node 22637914 to node 8865119 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 41, 16, 20262),
#   'Value': 0,
#   'Geometry': <POINT (5.369 51.791)>},
#  {'Message': 'Sailing from node 22637914 to node 8865119 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 42, 43, 205876),
#   'Value': 0,
#   'Geometry': <POINT (5.369 51.79)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 42, 43, 205876),
#   'Value': 0,
#   'Geometry': <POINT (5.369 51.79)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 42, 56, 482009),
#   'Value': 0,
#   'Geometry': <POINT (5.369 51.79)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 42, 56, 482009),
#   'Value': 0,
#   'Geometry': <POINT (5.369 51.79)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 43, 58, 114271),
#   'Value': 0,
#   'Geometry': <POINT (5.37 51.791)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 2 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 43, 58, 114271),
#   'Value': 0,
#   'Geometry': <POINT (5.37 51.791)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 2 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 45, 4, 958349),
#   'Value': 0,
#   'Geometry': <POINT (5.37 51.791)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 3 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 45, 4, 958349),
#   'Value': 0,
#   'Geometry': <POINT (5.37 51.791)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 3 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 48, 17, 272053),
#   'Value': 0,
#   'Geometry': <POINT (5.372 51.793)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 4 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 48, 17, 272053),
#   'Value': 0,
#   'Geometry': <POINT (5.372 51.793)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 4 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 52, 57, 457464),
#   'Value': 0,
#   'Geometry': <POINT (5.374 51.795)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 5 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 52, 57, 457464),
#   'Value': 0,
#   'Geometry': <POINT (5.374 51.795)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 5 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 59, 36, 219131),
#   'Value': 0,
#   'Geometry': <POINT (5.377 51.798)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 6 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 4, 59, 36, 219131),
#   'Value': 0,
#   'Geometry': <POINT (5.377 51.798)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 6 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 7, 36, 823652),
#   'Value': 0,
#   'Geometry': <POINT (5.38 51.801)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 7 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 7, 36, 823652),
#   'Value': 0,
#   'Geometry': <POINT (5.38 51.801)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 7 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 11, 35, 228749),
#   'Value': 0,
#   'Geometry': <POINT (5.382 51.803)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 8 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 11, 35, 228749),
#   'Value': 0,
#   'Geometry': <POINT (5.382 51.803)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 8 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 13, 42, 302700),
#   'Value': 0,
#   'Geometry': <POINT (5.383 51.804)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 9 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 13, 42, 302700),
#   'Value': 0,
#   'Geometry': <POINT (5.383 51.804)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 9 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 17, 32, 913917),
#   'Value': 0,
#   'Geometry': <POINT (5.385 51.806)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 10 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 17, 32, 913917),
#   'Value': 0,
#   'Geometry': <POINT (5.385 51.806)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 10 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 18, 37, 630678),
#   'Value': 0,
#   'Geometry': <POINT (5.386 51.806)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 11 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 18, 37, 630678),
#   'Value': 0,
#   'Geometry': <POINT (5.386 51.806)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 11 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 23, 50, 882233),
#   'Value': 0,
#   'Geometry': <POINT (5.388 51.809)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 12 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 23, 50, 882233),
#   'Value': 0,
#   'Geometry': <POINT (5.388 51.809)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 12 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 26, 14, 93538),
#   'Value': 0,
#   'Geometry': <POINT (5.39 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 13 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 26, 14, 93538),
#   'Value': 0,
#   'Geometry': <POINT (5.39 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 13 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 28, 39, 659495),
#   'Value': 0,
#   'Geometry': <POINT (5.391 51.811)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 14 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 28, 39, 659495),
#   'Value': 0,
#   'Geometry': <POINT (5.391 51.811)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 14 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 32, 51, 200975),
#   'Value': 0,
#   'Geometry': <POINT (5.394 51.812)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 15 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 32, 51, 200975),
#   'Value': 0,
#   'Geometry': <POINT (5.394 51.812)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 15 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 36, 57, 962412),
#   'Value': 0,
#   'Geometry': <POINT (5.396 51.814)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 16 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 36, 57, 962412),
#   'Value': 0,
#   'Geometry': <POINT (5.396 51.814)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 16 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 39, 34, 529788),
#   'Value': 0,
#   'Geometry': <POINT (5.397 51.815)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 17 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 39, 34, 529788),
#   'Value': 0,
#   'Geometry': <POINT (5.397 51.815)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 17 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 43, 22, 426780),
#   'Value': 0,
#   'Geometry': <POINT (5.398 51.817)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 18 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 43, 22, 426780),
#   'Value': 0,
#   'Geometry': <POINT (5.398 51.817)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 18 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 44, 41, 977356),
#   'Value': 0,
#   'Geometry': <POINT (5.399 51.818)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 19 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 44, 41, 977356),
#   'Value': 0,
#   'Geometry': <POINT (5.399 51.818)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 19 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 46, 5, 458293),
#   'Value': 0,
#   'Geometry': <POINT (5.399 51.818)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 20 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 46, 5, 458293),
#   'Value': 0,
#   'Geometry': <POINT (5.399 51.818)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 20 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 47, 56, 52889),
#   'Value': 0,
#   'Geometry': <POINT (5.4 51.819)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 21 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 47, 56, 52889),
#   'Value': 0,
#   'Geometry': <POINT (5.4 51.819)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 21 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 49, 28, 889034),
#   'Value': 0,
#   'Geometry': <POINT (5.401 51.82)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 22 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 49, 28, 889034),
#   'Value': 0,
#   'Geometry': <POINT (5.401 51.82)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 22 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 51, 8, 741322),
#   'Value': 0,
#   'Geometry': <POINT (5.402 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 23 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 51, 8, 741322),
#   'Value': 0,
#   'Geometry': <POINT (5.402 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 23 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 52, 51, 555495),
#   'Value': 0,
#   'Geometry': <POINT (5.403 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 24 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 52, 51, 555495),
#   'Value': 0,
#   'Geometry': <POINT (5.403 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 24 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 53, 42, 881208),
#   'Value': 0,
#   'Geometry': <POINT (5.403 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 25 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 53, 42, 881208),
#   'Value': 0,
#   'Geometry': <POINT (5.403 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 25 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 54, 44, 65280),
#   'Value': 0,
#   'Geometry': <POINT (5.404 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 26 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 54, 44, 65280),
#   'Value': 0,
#   'Geometry': <POINT (5.404 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 26 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 56, 29, 899608),
#   'Value': 0,
#   'Geometry': <POINT (5.405 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 27 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 56, 29, 899608),
#   'Value': 0,
#   'Geometry': <POINT (5.405 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 27 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 57, 26, 201543),
#   'Value': 0,
#   'Geometry': <POINT (5.406 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 28 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 57, 26, 201543),
#   'Value': 0,
#   'Geometry': <POINT (5.406 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 28 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 58, 27, 614876),
#   'Value': 0,
#   'Geometry': <POINT (5.407 51.823)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 29 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 58, 27, 614876),
#   'Value': 0,
#   'Geometry': <POINT (5.407 51.823)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 29 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 59, 35, 418433),
#   'Value': 0,
#   'Geometry': <POINT (5.408 51.823)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 30 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 5, 59, 35, 418433),
#   'Value': 0,
#   'Geometry': <POINT (5.408 51.823)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 30 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 0, 39, 368389),
#   'Value': 0,
#   'Geometry': <POINT (5.409 51.823)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 31 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 0, 39, 368389),
#   'Value': 0,
#   'Geometry': <POINT (5.409 51.823)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 31 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 1, 37, 799403),
#   'Value': 0,
#   'Geometry': <POINT (5.41 51.823)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 32 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 1, 37, 799403),
#   'Value': 0,
#   'Geometry': <POINT (5.41 51.823)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 32 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 2, 57, 207573),
#   'Value': 0,
#   'Geometry': <POINT (5.411 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 33 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 2, 57, 207573),
#   'Value': 0,
#   'Geometry': <POINT (5.411 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 33 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 4, 11, 266864),
#   'Value': 0,
#   'Geometry': <POINT (5.412 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 34 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 4, 11, 266864),
#   'Value': 0,
#   'Geometry': <POINT (5.412 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 34 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 5, 1, 744641),
#   'Value': 0,
#   'Geometry': <POINT (5.413 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 35 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 5, 1, 744641),
#   'Value': 0,
#   'Geometry': <POINT (5.413 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 35 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 6, 12, 395304),
#   'Value': 0,
#   'Geometry': <POINT (5.414 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 36 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 6, 12, 395304),
#   'Value': 0,
#   'Geometry': <POINT (5.414 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 36 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 6, 50, 488015),
#   'Value': 0,
#   'Geometry': <POINT (5.414 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 37 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 6, 50, 488015),
#   'Value': 0,
#   'Geometry': <POINT (5.414 51.822)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 37 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 7, 37, 500560),
#   'Value': 0,
#   'Geometry': <POINT (5.415 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 38 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 7, 37, 500560),
#   'Value': 0,
#   'Geometry': <POINT (5.415 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 38 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 7, 49, 667973),
#   'Value': 0,
#   'Geometry': <POINT (5.415 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 39 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 7, 49, 667973),
#   'Value': 0,
#   'Geometry': <POINT (5.415 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 39 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 8, 21, 961414),
#   'Value': 0,
#   'Geometry': <POINT (5.415 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 40 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 8, 21, 961414),
#   'Value': 0,
#   'Geometry': <POINT (5.415 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 40 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 9, 25, 673051),
#   'Value': 0,
#   'Geometry': <POINT (5.416 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 41 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 9, 25, 673051),
#   'Value': 0,
#   'Geometry': <POINT (5.416 51.821)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 41 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 11, 12, 538333),
#   'Value': 0,
#   'Geometry': <POINT (5.417 51.82)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 42 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 11, 12, 538333),
#   'Value': 0,
#   'Geometry': <POINT (5.417 51.82)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 42 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 13, 36, 308545),
#   'Value': 0,
#   'Geometry': <POINT (5.418 51.819)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 43 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 13, 36, 308545),
#   'Value': 0,
#   'Geometry': <POINT (5.418 51.819)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 43 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 18, 36, 758353),
#   'Value': 0,
#   'Geometry': <POINT (5.42 51.817)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 44 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 18, 36, 758353),
#   'Value': 0,
#   'Geometry': <POINT (5.42 51.817)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 44 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 20, 15, 236743),
#   'Value': 0,
#   'Geometry': <POINT (5.421 51.816)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 45 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 20, 15, 236743),
#   'Value': 0,
#   'Geometry': <POINT (5.421 51.816)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 45 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 21, 47, 624879),
#   'Value': 0,
#   'Geometry': <POINT (5.422 51.815)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 46 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 21, 47, 624879),
#   'Value': 0,
#   'Geometry': <POINT (5.422 51.815)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 46 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 24, 34, 814824),
#   'Value': 0,
#   'Geometry': <POINT (5.423 51.814)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 47 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 24, 34, 814824),
#   'Value': 0,
#   'Geometry': <POINT (5.423 51.814)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 47 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 27, 35, 79509),
#   'Value': 0,
#   'Geometry': <POINT (5.425 51.813)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 48 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 27, 35, 79509),
#   'Value': 0,
#   'Geometry': <POINT (5.425 51.813)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 48 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 30, 5, 137478),
#   'Value': 0,
#   'Geometry': <POINT (5.427 51.812)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 49 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 30, 5, 137478),
#   'Value': 0,
#   'Geometry': <POINT (5.427 51.812)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 49 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 32, 43, 610187),
#   'Value': 0,
#   'Geometry': <POINT (5.429 51.811)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 50 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 32, 43, 610187),
#   'Value': 0,
#   'Geometry': <POINT (5.429 51.811)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 50 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 33, 34, 794579),
#   'Value': 0,
#   'Geometry': <POINT (5.43 51.811)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 51 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 33, 34, 794579),
#   'Value': 0,
#   'Geometry': <POINT (5.43 51.811)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 51 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 37, 43, 440104),
#   'Value': 0,
#   'Geometry': <POINT (5.433 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 52 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 37, 43, 440104),
#   'Value': 0,
#   'Geometry': <POINT (5.433 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 52 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 41, 30, 556780),
#   'Value': 0,
#   'Geometry': <POINT (5.436 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 53 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 41, 30, 556780),
#   'Value': 0,
#   'Geometry': <POINT (5.436 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 53 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 45, 53, 759550),
#   'Value': 0,
#   'Geometry': <POINT (5.44 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 54 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 45, 53, 759550),
#   'Value': 0,
#   'Geometry': <POINT (5.44 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 54 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 50, 12, 450970),
#   'Value': 0,
#   'Geometry': <POINT (5.444 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 55 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 50, 12, 450970),
#   'Value': 0,
#   'Geometry': <POINT (5.444 51.81)>},
#  {'Message': 'Sailing from node 8865119 to node 8867204 sub edge 55 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 50, 57, 617341),
#   'Value': 0,
#   'Geometry': <POINT (5.444 51.81)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 50, 57, 617341),
#   'Value': 0,
#   'Geometry': <POINT (5.444 51.81)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 54, 12, 700079),
#   'Value': 0,
#   'Geometry': <POINT (5.447 51.809)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 54, 12, 700079),
#   'Value': 0,
#   'Geometry': <POINT (5.447 51.809)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 55, 36, 642600),
#   'Value': 0,
#   'Geometry': <POINT (5.448 51.808)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 2 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 55, 36, 642600),
#   'Value': 0,
#   'Geometry': <POINT (5.448 51.808)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 2 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 57, 8, 439173),
#   'Value': 0,
#   'Geometry': <POINT (5.449 51.808)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 3 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 6, 57, 8, 439173),
#   'Value': 0,
#   'Geometry': <POINT (5.449 51.808)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 3 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 0, 48, 250989),
#   'Value': 0,
#   'Geometry': <POINT (5.452 51.808)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 4 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 0, 48, 250989),
#   'Value': 0,
#   'Geometry': <POINT (5.452 51.808)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 4 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 1, 7, 488212),
#   'Value': 0,
#   'Geometry': <POINT (5.452 51.808)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 5 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 1, 7, 488212),
#   'Value': 0,
#   'Geometry': <POINT (5.452 51.808)>},
#  {'Message': 'Sailing from node 8867204 to node L12784_B sub edge 5 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 2, 9, 244537),
#   'Value': 0,
#   'Geometry': <POINT (5.453 51.809)>},
#  {'Message': 'Sailing from node L12784_B to node L12784_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 2, 9, 244537),
#   'Value': 0,
#   'Geometry': <POINT (5.453 51.809)>},
#  {'Message': 'Sailing from node L12784_B to node L12784_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 2, 25, 809169),
#   'Value': 0,
#   'Geometry': <POINT (5.454 51.809)>},
#  {'Message': 'Sailing from node L12784_B to node L12784_A sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 2, 25, 809169),
#   'Value': 0,
#   'Geometry': <POINT (5.454 51.809)>},
#  {'Message': 'Sailing from node L12784_B to node L12784_A sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 2, 36, 890170),
#   'Value': 0,
#   'Geometry': <POINT (5.454 51.809)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 2, 36, 890170),
#   'Value': 0,
#   'Geometry': <POINT (5.454 51.809)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 3, 34, 996702),
#   'Value': 0,
#   'Geometry': <POINT (5.455 51.809)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 3, 34, 996702),
#   'Value': 0,
#   'Geometry': <POINT (5.455 51.809)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 9, 51, 840349),
#   'Value': 0,
#   'Geometry': <POINT (5.46 51.809)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 2 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 9, 51, 840349),
#   'Value': 0,
#   'Geometry': <POINT (5.46 51.809)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 2 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 12, 35, 428589),
#   'Value': 0,
#   'Geometry': <POINT (5.462 51.809)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 3 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 12, 35, 428589),
#   'Value': 0,
#   'Geometry': <POINT (5.462 51.809)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 3 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 13, 54, 556309),
#   'Value': 0,
#   'Geometry': <POINT (5.463 51.81)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 4 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 13, 54, 556309),
#   'Value': 0,
#   'Geometry': <POINT (5.463 51.81)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 4 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 14, 3, 101129),
#   'Value': 0,
#   'Geometry': <POINT (5.464 51.81)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 5 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 14, 3, 101129),
#   'Value': 0,
#   'Geometry': <POINT (5.464 51.81)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 5 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 15, 27, 708263),
#   'Value': 0,
#   'Geometry': <POINT (5.465 51.81)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 6 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 15, 27, 708263),
#   'Value': 0,
#   'Geometry': <POINT (5.465 51.81)>},
#  {'Message': 'Sailing from node L12784_A to node 8862883 sub edge 6 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 18, 50, 202289),
#   'Value': 0,
#   'Geometry': <POINT (5.467 51.811)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 18, 50, 202289),
#   'Value': 0,
#   'Geometry': <POINT (5.467 51.811)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 21, 49, 328298),
#   'Value': 0,
#   'Geometry': <POINT (5.469 51.812)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 21, 49, 328298),
#   'Value': 0,
#   'Geometry': <POINT (5.469 51.812)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 24, 42, 726573),
#   'Value': 0,
#   'Geometry': <POINT (5.471 51.813)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 2 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 24, 42, 726573),
#   'Value': 0,
#   'Geometry': <POINT (5.471 51.813)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 2 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 28, 3, 366220),
#   'Value': 0,
#   'Geometry': <POINT (5.473 51.814)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 3 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 28, 3, 366220),
#   'Value': 0,
#   'Geometry': <POINT (5.473 51.814)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 3 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 30, 1, 601309),
#   'Value': 0,
#   'Geometry': <POINT (5.474 51.815)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 4 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 30, 1, 601309),
#   'Value': 0,
#   'Geometry': <POINT (5.474 51.815)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 4 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 32, 16, 728088),
#   'Value': 0,
#   'Geometry': <POINT (5.476 51.816)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 5 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 32, 16, 728088),
#   'Value': 0,
#   'Geometry': <POINT (5.476 51.816)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 5 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 34, 29, 78628),
#   'Value': 0,
#   'Geometry': <POINT (5.477 51.817)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 6 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 34, 29, 78628),
#   'Value': 0,
#   'Geometry': <POINT (5.477 51.817)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 6 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 35, 47, 764365),
#   'Value': 0,
#   'Geometry': <POINT (5.477 51.818)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 7 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 35, 47, 764365),
#   'Value': 0,
#   'Geometry': <POINT (5.477 51.818)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 7 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 38, 0, 72669),
#   'Value': 0,
#   'Geometry': <POINT (5.478 51.819)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 8 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 38, 0, 72669),
#   'Value': 0,
#   'Geometry': <POINT (5.478 51.819)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 8 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 40, 7, 616387),
#   'Value': 0,
#   'Geometry': <POINT (5.478 51.82)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 9 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 40, 7, 616387),
#   'Value': 0,
#   'Geometry': <POINT (5.478 51.82)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 9 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 46, 26, 866567),
#   'Value': 0,
#   'Geometry': <POINT (5.479 51.823)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 10 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 46, 26, 866567),
#   'Value': 0,
#   'Geometry': <POINT (5.479 51.823)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 10 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 50, 22, 481277),
#   'Value': 0,
#   'Geometry': <POINT (5.48 51.825)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 11 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 50, 22, 481277),
#   'Value': 0,
#   'Geometry': <POINT (5.48 51.825)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 11 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 52, 43, 247522),
#   'Value': 0,
#   'Geometry': <POINT (5.481 51.826)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 12 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 52, 43, 247522),
#   'Value': 0,
#   'Geometry': <POINT (5.481 51.826)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 12 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 56, 40, 344628),
#   'Value': 0,
#   'Geometry': <POINT (5.483 51.828)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 13 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 56, 40, 344628),
#   'Value': 0,
#   'Geometry': <POINT (5.483 51.828)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 13 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 58, 13, 224360),
#   'Value': 0,
#   'Geometry': <POINT (5.484 51.829)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 14 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 58, 13, 224360),
#   'Value': 0,
#   'Geometry': <POINT (5.484 51.829)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 14 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 59, 23, 660514),
#   'Value': 0,
#   'Geometry': <POINT (5.485 51.829)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 15 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 7, 59, 23, 660514),
#   'Value': 0,
#   'Geometry': <POINT (5.485 51.829)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 15 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 1, 57, 845945),
#   'Value': 0,
#   'Geometry': <POINT (5.487 51.83)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 16 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 1, 57, 845945),
#   'Value': 0,
#   'Geometry': <POINT (5.487 51.83)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 16 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 3, 5, 268110),
#   'Value': 0,
#   'Geometry': <POINT (5.487 51.83)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 17 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 3, 5, 268110),
#   'Value': 0,
#   'Geometry': <POINT (5.487 51.83)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 17 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 6, 14, 295499),
#   'Value': 0,
#   'Geometry': <POINT (5.49 51.831)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 18 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 6, 14, 295499),
#   'Value': 0,
#   'Geometry': <POINT (5.49 51.831)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 18 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 7, 18, 986635),
#   'Value': 0,
#   'Geometry': <POINT (5.491 51.831)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 19 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 7, 18, 986635),
#   'Value': 0,
#   'Geometry': <POINT (5.491 51.831)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 19 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 9, 45, 838065),
#   'Value': 0,
#   'Geometry': <POINT (5.493 51.831)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 20 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 9, 45, 838065),
#   'Value': 0,
#   'Geometry': <POINT (5.493 51.831)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 20 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 12, 25, 567107),
#   'Value': 0,
#   'Geometry': <POINT (5.495 51.831)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 21 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 12, 25, 567107),
#   'Value': 0,
#   'Geometry': <POINT (5.495 51.831)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 21 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 14, 57, 888556),
#   'Value': 0,
#   'Geometry': <POINT (5.498 51.83)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 22 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 14, 57, 888556),
#   'Value': 0,
#   'Geometry': <POINT (5.498 51.83)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 22 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 17, 52, 610666),
#   'Value': 0,
#   'Geometry': <POINT (5.5 51.83)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 23 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 17, 52, 610666),
#   'Value': 0,
#   'Geometry': <POINT (5.5 51.83)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 23 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 20, 25, 594752),
#   'Value': 0,
#   'Geometry': <POINT (5.502 51.829)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 24 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 20, 25, 594752),
#   'Value': 0,
#   'Geometry': <POINT (5.502 51.829)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 24 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 22, 45, 729880),
#   'Value': 0,
#   'Geometry': <POINT (5.504 51.829)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 25 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 22, 45, 729880),
#   'Value': 0,
#   'Geometry': <POINT (5.504 51.829)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 25 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 26, 14, 424299),
#   'Value': 0,
#   'Geometry': <POINT (5.506 51.828)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 26 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 26, 14, 424299),
#   'Value': 0,
#   'Geometry': <POINT (5.506 51.828)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 26 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 27, 45, 399129),
#   'Value': 0,
#   'Geometry': <POINT (5.507 51.827)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 27 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 27, 45, 399129),
#   'Value': 0,
#   'Geometry': <POINT (5.507 51.827)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 27 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 30, 9, 623981),
#   'Value': 0,
#   'Geometry': <POINT (5.508 51.826)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 28 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 30, 9, 623981),
#   'Value': 0,
#   'Geometry': <POINT (5.508 51.826)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 28 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 33, 47, 72360),
#   'Value': 0,
#   'Geometry': <POINT (5.51 51.824)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 29 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 8, 33, 47, 72360),
#   'Value': 0,
#   'Geometry': <POINT (5.51 51.824)>},
#  {'Message': 'Sailing from node 8862883 to node 8860920 sub edge 29 stop',
# ...
#   'Value': 0,
#   'Geometry': <POINT (5.819 51.802)>},
#  {'Message': 'Sailing from node B27379_B to node B58055_A sub edge 4 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 28, 57, 287665),
#   'Value': 0,
#   'Geometry': <POINT (5.818 51.804)>},
#  {'Message': 'Sailing from node B27379_B to node B58055_A sub edge 5 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 28, 57, 287665),
#   'Value': 0,
#   'Geometry': <POINT (5.818 51.804)>},
#  {'Message': 'Sailing from node B27379_B to node B58055_A sub edge 5 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 33, 18, 61870),
#   'Value': 0,
#   'Geometry': <POINT (5.816 51.806)>},
#  {'Message': 'Sailing from node B58055_A to node B58055_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 33, 18, 61870),
#   'Value': 0,
#   'Geometry': <POINT (5.816 51.806)>},
#  {'Message': 'Sailing from node B58055_A to node B58055_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 33, 27, 698849),
#   'Value': 0,
#   'Geometry': <POINT (5.816 51.806)>},
#  {'Message': 'Sailing from node B58055_A to node B58055_B sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 33, 27, 698849),
#   'Value': 0,
#   'Geometry': <POINT (5.816 51.806)>},
#  {'Message': 'Sailing from node B58055_A to node B58055_B sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 33, 28, 135868),
#   'Value': 0,
#   'Geometry': <POINT (5.816 51.806)>},
#  {'Message': 'Sailing from node B58055_B to node B17724_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 33, 28, 135868),
#   'Value': 0,
#   'Geometry': <POINT (5.816 51.806)>},
#  {'Message': 'Sailing from node B58055_B to node B17724_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 55, 8, 228314),
#   'Value': 0,
#   'Geometry': <POINT (5.812 51.818)>},
#  {'Message': 'Sailing from node B17724_A to node B17724_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 55, 8, 228314),
#   'Value': 0,
#   'Geometry': <POINT (5.812 51.818)>},
#  {'Message': 'Sailing from node B17724_A to node B17724_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 55, 15, 84378),
#   'Value': 0,
#   'Geometry': <POINT (5.812 51.818)>},
#  {'Message': 'Sailing from node B17724_A to node B17724_B sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 55, 15, 84378),
#   'Value': 0,
#   'Geometry': <POINT (5.812 51.818)>},
#  {'Message': 'Sailing from node B17724_A to node B17724_B sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 55, 18, 868587),
#   'Value': 0,
#   'Geometry': <POINT (5.812 51.818)>},
#  {'Message': 'Sailing from node B17724_B to node B16982_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 18, 55, 18, 868587),
#   'Value': 0,
#   'Geometry': <POINT (5.812 51.818)>},
#  {'Message': 'Sailing from node B17724_B to node B16982_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 4, 54, 109096),
#   'Value': 0,
#   'Geometry': <POINT (5.81 51.823)>},
#  {'Message': 'Sailing from node B17724_B to node B16982_A sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 4, 54, 109096),
#   'Value': 0,
#   'Geometry': <POINT (5.81 51.823)>},
#  {'Message': 'Sailing from node B17724_B to node B16982_A sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 10, 18, 323105),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B16982_A to node B16982_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 10, 18, 323105),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B16982_A to node B16982_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 10, 28, 979991),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B16982_B to node B44447_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 10, 28, 979991),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B16982_B to node B44447_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 10, 44, 604771),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B16982_B to node B44447_A sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 10, 44, 604771),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B16982_B to node B44447_A sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 11, 8, 214689),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B44447_A to node B44447_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 11, 8, 214689),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B44447_A to node B44447_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 11, 19, 52450),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 11, 19, 52450),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.826)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 16, 12, 549054),
#   'Value': 0,
#   'Geometry': <POINT (5.807 51.829)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 16, 12, 549054),
#   'Value': 0,
#   'Geometry': <POINT (5.807 51.829)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 19, 39, 739219),
#   'Value': 0,
#   'Geometry': <POINT (5.807 51.831)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 2 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 19, 39, 739219),
#   'Value': 0,
#   'Geometry': <POINT (5.807 51.831)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 2 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 23, 38, 63099),
#   'Value': 0,
#   'Geometry': <POINT (5.807 51.833)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 3 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 23, 38, 63099),
#   'Value': 0,
#   'Geometry': <POINT (5.807 51.833)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 3 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 27, 34, 687534),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.835)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 4 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 27, 34, 687534),
#   'Value': 0,
#   'Geometry': <POINT (5.808 51.835)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 4 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 30, 41, 305578),
#   'Value': 0,
#   'Geometry': <POINT (5.809 51.836)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 5 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 30, 41, 305578),
#   'Value': 0,
#   'Geometry': <POINT (5.809 51.836)>},
#  {'Message': 'Sailing from node B44447_B to node B17568_A sub edge 5 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 32, 57, 982558),
#   'Value': 0,
#   'Geometry': <POINT (5.809 51.838)>},
#  {'Message': 'Sailing from node B17568_A to node B17568_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 32, 57, 982558),
#   'Value': 0,
#   'Geometry': <POINT (5.809 51.838)>},
#  {'Message': 'Sailing from node B17568_A to node B17568_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 32, 58, 613286),
#   'Value': 0,
#   'Geometry': <POINT (5.809 51.838)>},
#  {'Message': 'Sailing from node B17568_A to node B17568_B sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 32, 58, 613286),
#   'Value': 0,
#   'Geometry': <POINT (5.809 51.838)>},
#  {'Message': 'Sailing from node B17568_A to node B17568_B sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 33, 7, 719305),
#   'Value': 0,
#   'Geometry': <POINT (5.809 51.838)>},
#  {'Message': 'Sailing from node B17568_B to node 8864666 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 33, 7, 719305),
#   'Value': 0,
#   'Geometry': <POINT (5.809 51.838)>},
#  {'Message': 'Sailing from node B17568_B to node 8864666 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 46, 24, 619643),
#   'Value': 0,
#   'Geometry': <POINT (5.815 51.844)>},
#  {'Message': 'Sailing from node 8864666 to node Berth151 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 46, 24, 619643),
#   'Value': 0,
#   'Geometry': <POINT (5.815 51.844)>},
#  {'Message': 'Sailing from node 8864666 to node Berth151 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 50, 0, 816960),
#   'Value': 0,
#   'Geometry': <POINT (5.816 51.846)>},
#  {'Message': 'Sailing from node Berth151 to node Berth152 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 50, 0, 816960),
#   'Value': 0,
#   'Geometry': <POINT (5.816 51.846)>},
#  {'Message': 'Sailing from node Berth151 to node Berth152 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 53, 2, 964058),
#   'Value': 0,
#   'Geometry': <POINT (5.817 51.847)>},
#  {'Message': 'Sailing from node Berth152 to node Berth153 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 53, 2, 964058),
#   'Value': 0,
#   'Geometry': <POINT (5.817 51.847)>},
#  {'Message': 'Sailing from node Berth152 to node Berth153 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 56, 2, 379935),
#   'Value': 0,
#   'Geometry': <POINT (5.819 51.849)>},
#  {'Message': 'Sailing from node Berth153 to node L49032_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 19, 56, 2, 379935),
#   'Value': 0,
#   'Geometry': <POINT (5.819 51.849)>},
#  {'Message': 'Sailing from node Berth153 to node L49032_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 3, 44, 831073),
#   'Value': 0,
#   'Geometry': <POINT (5.822 51.852)>},
#  {'Message': 'Sailing from node Berth153 to node L49032_A sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 3, 44, 831073),
#   'Value': 0,
#   'Geometry': <POINT (5.822 51.852)>},
#  {'Message': 'Sailing from node Berth153 to node L49032_A sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 5, 18, 445305),
#   'Value': 0,
#   'Geometry': <POINT (5.822 51.853)>},
#  {'Message': 'Sailing from node L49032_A to node L49032_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 5, 18, 445305),
#   'Value': 0,
#   'Geometry': <POINT (5.822 51.853)>},
#  {'Message': 'Sailing from node L49032_A to node L49032_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 5, 57, 275603),
#   'Value': 0,
#   'Geometry': <POINT (5.823 51.853)>},
#  {'Message': 'Sailing from node L49032_B to node 8864190 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 5, 57, 275603),
#   'Value': 0,
#   'Geometry': <POINT (5.823 51.853)>},
#  {'Message': 'Sailing from node L49032_B to node 8864190 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 8, 3, 809940),
#   'Value': 0,
#   'Geometry': <POINT (5.823 51.854)>},
#  {'Message': 'Sailing from node 8864190 to node B24080_A sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 8, 3, 809940),
#   'Value': 0,
#   'Geometry': <POINT (5.823 51.854)>},
#  {'Message': 'Sailing from node 8864190 to node B24080_A sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 8, 30, 975758),
#   'Value': 0,
#   'Geometry': <POINT (5.824 51.855)>},
#  {'Message': 'Sailing from node B24080_A to node B24080_B sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 8, 30, 975758),
#   'Value': 0,
#   'Geometry': <POINT (5.824 51.855)>},
#  {'Message': 'Sailing from node B24080_A to node B24080_B sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 8, 40, 626222),
#   'Value': 0,
#   'Geometry': <POINT (5.824 51.855)>},
#  {'Message': 'Sailing from node B24080_B to node Berth156 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 8, 40, 626222),
#   'Value': 0,
#   'Geometry': <POINT (5.824 51.855)>},
#  {'Message': 'Sailing from node B24080_B to node Berth156 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 8, 50, 771586),
#   'Value': 0,
#   'Geometry': <POINT (5.824 51.855)>},
#  {'Message': 'Sailing from node B24080_B to node Berth156 sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 8, 50, 771586),
#   'Value': 0,
#   'Geometry': <POINT (5.824 51.855)>},
#  {'Message': 'Sailing from node B24080_B to node Berth156 sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 12, 12, 918163),
#   'Value': 0,
#   'Geometry': <POINT (5.825 51.856)>},
#  {'Message': 'Sailing from node Berth156 to node Berth155 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 12, 12, 918163),
#   'Value': 0,
#   'Geometry': <POINT (5.825 51.856)>},
#  {'Message': 'Sailing from node Berth156 to node Berth155 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 15, 27, 529000),
#   'Value': 0,
#   'Geometry': <POINT (5.826 51.858)>},
#  {'Message': 'Sailing from node Berth155 to node Berth154 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 15, 27, 529000),
#   'Value': 0,
#   'Geometry': <POINT (5.826 51.858)>},
#  {'Message': 'Sailing from node Berth155 to node Berth154 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 16, 11, 466341),
#   'Value': 0,
#   'Geometry': <POINT (5.826 51.858)>},
#  {'Message': 'Sailing from node Berth155 to node Berth154 sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 16, 11, 466341),
#   'Value': 0,
#   'Geometry': <POINT (5.826 51.858)>},
#  {'Message': 'Sailing from node Berth155 to node Berth154 sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 16, 42, 413865),
#   'Value': 0,
#   'Geometry': <POINT (5.826 51.859)>},
#  {'Message': 'Sailing from node Berth154 to node 8865102 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 16, 42, 413865),
#   'Value': 0,
#   'Geometry': <POINT (5.826 51.859)>},
#  {'Message': 'Sailing from node Berth154 to node 8865102 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 18, 3, 46957),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.859)>},
#  {'Message': 'Sailing from node 8865102 to node 22638038 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 18, 3, 46957),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.859)>},
#  {'Message': 'Sailing from node 8865102 to node 22638038 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 20, 23, 491030),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.861)>},
#  {'Message': 'Sailing from node 8865102 to node 22638038 sub edge 1 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 20, 23, 491030),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.861)>},
#  {'Message': 'Sailing from node 8865102 to node 22638038 sub edge 1 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 24, 30, 454462),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.863)>},
#  {'Message': 'Sailing from node 8865102 to node 22638038 sub edge 2 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 24, 30, 454462),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.863)>},
#  {'Message': 'Sailing from node 8865102 to node 22638038 sub edge 2 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 27, 18, 555721),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.864)>},
#  {'Message': 'Sailing from node 22638038 to node 8861687 sub edge 0 start',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 27, 18, 555721),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.864)>},
#  {'Message': 'Sailing from node 22638038 to node 8861687 sub edge 0 stop',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 30, 6, 190041),
#   'Value': 0,
#   'Geometry': <POINT (5.827 51.866)>},
#  {'Message': 'Stop sailing',
#   'Timestamp': datetime.datetime(2024, 6, 4, 20, 30, 6, 190041),
#   'Value': '',
#   'Geometry': <POINT (5.827 51.866)>}]

# %% [markdown]
# ### Visualization of path
# If you get an error regarding ffmpeg use [this](https://stackoverflow.com/questions/13316397/matplotlib-animation-no-moviewriters-available) answer. You have to install ffmpeg in your Conda environment. It can be done using the following command.
#
# ```bash
# #Install ffmpeg using Conda
# conda install -c conda-forge ffmpeg
# ```

# %%
# visualise vessel movements based on the information included in the vessel.log
# plot.vessel_kml(env, vessels, stepsize = 60)
#plot.graph_kml(env)

# %%
! start explorer .
