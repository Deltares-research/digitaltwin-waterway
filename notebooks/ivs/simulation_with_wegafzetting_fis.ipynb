# %% [markdown]
# # simulation with ivs data

# %% [markdown]
# ### Imports
# Import the required libraries

# %%
# package(s) related to time, space and id
import datetime, time
import platform
import random
import os
import pathlib

# you need these dependencies (you can get these from anaconda)
# package(s) related to the simulation
import simpy

# spatial libraries 
import pyproj
import shapely.geometry
from shapely.geometry import Point
import shapely
import geopandas as gpd
import movingpandas as mpd

# package(s) for data handling
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import pickle

# OpenTNSIM
import opentnsim
import opentnsim.core as core
import opentnsim.graph_module as graph_module
import opentnsim.plot as plot


# dtv_backend
import dtv_backend.fis as fis
import dtv_backend.network
import dtv_backend.network.network_utilities
import dtv_backend.postprocessing
import dtv_backend.simple
import dtv_backend.simulate

# Used for mathematical functions
import math             
import numpy as np

# Used for making the graph to visualize our problem
import networkx as nx  
import requests
import io

# %% [markdown]
# ### Create graph

# %%
#Load lock info
url = "https://zenodo.org/records/6673604/files/FIS_locks_grouped.geojson?download=1"
resp = requests.get(url)
stream = io.BytesIO(resp.content)
locks_gdf = gpd.read_file(stream)

# %%
#Load graph
url = "https://zenodo.org/record/6673604/files/network_digital_twin_v0.3.pickle?download=1"
graph1 = dtv_backend.fis.load_fis_network(url).copy()

# remove edge ('8865412', 'B20540_A')
graph1.remove_edge('8865412', 'B20540_A')


# #remove edges without classification
# for edge in graph1.edges:
#     if str(graph1.edges[edge]['Classification']) == 'nan':
#         graph1.remove_edge(edge[0], edge[1])

graph = graph_module.Graph()
graph.graph = graph1
graph.graph_info = opentnsim.utils.info(graph.graph)

# %%
# save afzetting in geopanda
afzetting = pd.DataFrame({'A': graph1.nodes['8865412'],
'B': graph1.nodes['B20540_A']}).T
afzetting = gpd.GeoDataFrame(afzetting)
pathlib.Path('plots_routes').mkdir(exist_ok=True)
afzetting.to_file('plots_routes/afzetting_locatie')

# %%
# save graph in geopanda
df_edges = nx.to_pandas_edgelist(graph1)
gpd.GeoDataFrame(df_edges).to_file('plots_routes/edges_met_afzetting')
# Out:
# C:\Users\hemert\AppData\Local\Temp\ipykernel_21592\415873159.py:3: UserWarning:
#
# Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.

# %% [markdown]
# ### Make vessels and paths

# %%
import pickle
data = pickle.load(open(pathlib.Path("~/data/ivs/ivs-2024-geocoded_filtered.pkl").expanduser(), 'rb'))

# %% [markdown]
# ##### read data

# %%
# # lees data in.
# data = gpd.read_file("data\ivs\ivs-2024-geocoded.gpkg")

# #filter data op bestaande iso datum en geometry.
# data['datetime'] = pd.to_datetime(data['v05_06_begindt_evenement_iso'], format = 'ISO8601', errors = 'coerce')
# data.dropna(subset = ['datetime', 'geometry'], inplace = True)

# %% [markdown]
# filter only on rotterdam to duisburg, 2023. Only keep ships in january 2023

# %%
# t_begin = pd.Timestamp('2023-12-25', tz='UTC')
# t_end = pd.Timestamp('2023-12-26', tz='UTC')
# #data1 = data[
#     #(data.UNLO_herkomst== "NLDOR")
#     #(data.UNLO_herkomst== "NLGAM")
#     #((data.UNLO_bestemming.str.startswith("DE")) | (data.UNLO_herkomst.str.startswith("DE")))
#     #  & (data.v05_06_begindt_evenement_iso.str.startswith("2023-01"))
#     #  ]
# condition_1 = (data.UNLO_bestemming.str.startswith("DE")) | (data.UNLO_herkomst.str.startswith("DE"))
# condition_2 = data.datetime>=(t_begin)
# condition_3 = data.datetime<(t_end)

# idx = np.logical_and.reduce([
#  condition_1,
#  condition_2,
#  condition_3
# ])
# data = data[idx]
# len(data)
# Out:
# 105

# %% [markdown]
# ##### Create vessels

# %%
import functools
from pandas.api.types import CategoricalDtype

def path_restricted_to_cemt_class(graph, origin, destination, ship_cemt_classe):
    """find a path restricted to allowed cemt classes

    Parameters
    ----------
    graph : networkx.Graph
        graph in which to find a path. graph edges should have information 'cemt'.
    origin : str
        origin node id
    destination : str
        destination node id
    ship_cemt_classe : str
        cemt class of the ship.
    """
    # create function to compute weights for this ship
    compute_weight = functools.partial(
        __compute_weight, ship_cemt_classe=ship_cemt_classe
    )

    # find the path
    path = nx.dijkstra_path(graph, origin, destination, weight=compute_weight)
    return path


def path_restricted_to_rws_class(graph, origin, destination, ship_rws_classe):
    """find a path restricted to allowed cemt classes

    Parameters
    ----------
    graph : networkx.Graph
        graph in which to find a path. graph edges should have information 'cemt'.
    origin : str
        origin node id
    destination : str
        destination node id
    ship_cemt_classe : str
        cemt class of the ship.
    """
    ship_cemt_classe = __scheepstype_rws_to_cemt(ship_rws_classe)
    return path_restricted_to_cemt_class(graph, origin, destination, ship_cemt_classe)


def __compute_weight(origin, target, dictionary_edge, ship_cemt_classe):
    # order classes from smallest to largest
    cemt_classes = CategoricalDtype(categories = ["0", "I", "II", "III", "IV", "IVa", "Va", "Vb", "VIa", "VIb", "VIc", "VIIa"]
                                ,ordered=True)
    #define synonyms:
    code_synonyms = {
        "_0": "0",
        "V_A": "Va",
        "V_B": "Vb",
        "VI_A": "VIa",
        "VI_B": "VIb",
        "VI_C": "VIc",
    }
    if dictionary_edge["Code"] in code_synonyms:
        edge_code= code_synonyms[dictionary_edge["Code"]]
    else:
        edge_code = dictionary_edge["Code"]
        
    # create codes
    codes = pd.Series(data=[edge_code, ship_cemt_classe], 
                        index=['edge', 'ship'], 
                        dtype=cemt_classes
                        )
    if codes.isna().any():
        return dictionary_edge["length_m"]
    if codes["edge"] < codes["ship"]:
        return np.nan
    else:
        return dictionary_edge["length_m"]


def __scheepstype_rws_to_cemt(rws_classe):
    rws_to_cemt = {
        "M0": "0",
        "M1": "I",
        "M2": "II",
        "M3": "III",
        "M4": "III",
        "M5": "III",
        "M6": "IVa",
        "M7": "IVa",
        "M8": "Va",
        "M9": "Va",
        "M10": "VIa",
        "M11": "VIa",
        "M12": "VIa",
        "M26": ?
    }
    return rws_to_cemt[rws_classe]
# Out:
#   Cell In[11], line 92
#     "M26": ?
#            ^
# SyntaxError: invalid syntax

# %%
from networkx.exception import NetworkXNoPath
#from dtv_backend.fis import path_restricted_to_rws_class

# Make a class out of mix-ins
TransportResource = type('TransportResource', 
                         (core.Identifiable, core.ContainerDependentMovable, 
                          core.HasResource, core.Routable,
                          core.VesselProperties,
                         core.ExtraMetadata), 
                         {})
#define speed: 
def compute_v_provider(v_empty, v_full):
    return lambda x: 1

# define weight
def compute_weight(origin, target, dictionary):
    if dictionary['Code'] in ('IV', 'III', 'II', "I"): #niet langs te kleine wegen
        return None
    else:
        return dictionary['length_m']

vessels = []
failed_vessels = []
for index, row in data.iterrows():
    #determine path
    try:
        point_1 = fis.find_closest_node(graph.graph, Point(row.geometry.coords[0]))
        point_2 = fis.find_closest_node(graph.graph, Point(row.geometry.coords[-1]))
        # path = path_restricted_to_rws_class(graph = graph.graph, 
        #                                     origin = point_1[0], 
        #                                     destination=point_2[0], 
        #                                     ship_rws_classe=f"M{row['v15_1_Scheepstype_RWS']}") 
        path = nx.dijkstra_path(graph.graph, point_1[0], point_2[0], weight=compute_weight)
        #determine capacity
        capacity = max(row.v18_Laadvermogen*1000, row.v38_Vervoerd_gewicht, 1)
        data_vessel = {"env": None,
                "name": row.name,
                "type": row['v15_1_Scheepstype_RWS'],
                "B": 8,
                "L": 100,
                "route": path,
                "geometry": Point(row.geometry.coords[0]),  # lon, lat
                "capacity": capacity,
                "v": 0.5144*8, # 8 knopen
                "compute_v": compute_v_provider(v_empty=0.5144*8, v_full=0.5144*8),
                "departure_time": pd.to_datetime(row['v05_06_begindt_evenement_iso']),
                }
        vessel = TransportResource(**data_vessel)
        vessels.append(vessel)
    except NetworkXNoPath:
        failed_vessels.append(row.name)
    except ValueError:
        failed_vessels.append(row.name)
print(f"Failed vessels: {failed_vessels}")
        

# korte_route = nx.dijkstra_path(graph.graph, "8865735", "8861687")
# vessels = [TransportResource(**{
#     "env" : None,
#     "name": 'korte_route', 
#     "type": 'M6',
#     "B": 1, 
#     "L": 10,
#     "route": korte_route,
#     "geometry": Point(row.geometry.coords[0]),  # lon, lat
#     "capacity": capacity,
#     "v": 1,
#     "compute_v": compute_v_provider(v_empty=1, v_full=1),
# })]
# Out:
# Failed vessels: [464617, 659126, 797994, 835063, 1044412, 1561014, 1826422, 2138285, 2412099]

# %% [markdown]
# # sluis maken

# %% [markdown]
# ### Start simulation

# %%
def start(env, vessel):
    while True:
        #wait untill ship will start sailing
        time_departure = time.mktime(vessel.metadata['departure_time'].timetuple())
        yield env.timeout(time_departure-env.now)

        # start sailing
        vessel.log_entry_v0("Start sailing", env.now, "", vessel.geometry)
        yield from vessel.move()
        vessel.log_entry_v0("Stop sailing", env.now, "", vessel.geometry)
        
        if vessel.geometry == nx.get_node_attributes(env.FG, "geometry")[vessel.route[-1]]:
            break

# %%
# Start simpy environment
simulation_start = min([vessel.metadata['departure_time'] for vessel in vessels])

env = simpy.Environment(initial_time = time.mktime(simulation_start.timetuple()))
env.epoch = time.mktime(simulation_start.timetuple())


# Add graph to environment
#graph.add_resources(list(graph.graph.edges), np.ones(len(list(graph.graph.edges))), env)
env.FG = graph.graph

# %%
from dtv_backend.lock import Lock, Locks

locks = Locks(env)

# %%
import functools
for i, vessel in enumerate(vessels):
    # Add environment and path to the vessel
    vessel.env = env

    # add passing of a lock
    filled_pass_lock = functools.partial(locks.pass_lock_v2, vessel=vessel)
    vessel.on_pass_edge_functions = [filled_pass_lock]

    # Add the movements of the vessel to the simulation
    env.process(start(env, vessel))

env.run(until=env.timeout(60*60*24*30))
# Out:
# 1703468791.0 s: 1779687 is waiting for lock L1306537_A
# 1703468791.0 s: 1779687 enters lock on side A
# 1703468851.0 s: lock 1306537 closes entry A
# 1703470651.0 s: lock 1306537 opens entry B
# 1703479591.0 s: 1306537 closes entry B
# 1703479591.0 s: 1046675 is waiting for lock L1306537_A
# 1703481391.0 s: 1306537 opens entry A
# 1703481391.0 s: 1046675 enters lock on side A
# 1703481511.0 s: lock 1306537 closes entry A
# 1703482751.7 s: 2244521 is waiting for lock L7069282_B
# 1703482811.7 s: lock 7069282 closes entry A
# 1703483191.0 s: 1950006 is waiting for lock L1306537_A
# 1703483311.0 s: lock 1306537 opens entry B
# 1703483431.0 s: 1306537 closes entry B
# 1703484611.7 s: lock 7069282 opens entry B
# 1703484611.7 s: 2244521 enters lock on side B
# 1703484731.7 s: 7069282 closes entry B
# 1703485231.0 s: 1306537 opens entry A
# 1703485231.0 s: 1950006 enters lock on side A
# 1703485351.0 s: lock 1306537 closes entry A
# 1703486531.7 s: 7069282 opens entry A
# 1703487151.0 s: lock 1306537 opens entry B
# 1703490391.0 s: 1306537 closes entry B
# 1703490391.0 s: 647517 is waiting for lock L1306537_A
# 1703490391.0 s: 1647172 is waiting for lock L1306537_A
# 1703492191.0 s: 1306537 opens entry A
# 1703492191.0 s: 647517 enters lock on side A
# 1703492191.0 s: 1647172 enters lock on side A
# 1703492311.0 s: lock 1306537 closes entry A
# 1703493410.9 s: 934524 is waiting for lock L1293320_B
# 1703493470.9 s: lock 1293320 closes entry A
# 1703493991.0 s: 1742300 is waiting for lock L1306537_A
# 1703494111.0 s: lock 1306537 opens entry B
# 1703494231.0 s: 1306537 closes entry B
# 1703495270.9 s: lock 1293320 opens entry B
# 1703495270.9 s: 934524 enters lock on side B
# 1703495390.9 s: 1293320 closes entry B
# 1703496031.0 s: 1306537 opens entry A
# 1703496031.0 s: 1742300 enters lock on side A
# 1703496151.0 s: lock 1306537 closes entry A
# 1703496385.7 s: 464616 is waiting for lock L36941_B
# 1703496445.7 s: lock 36941 closes entry A
# 1703497190.9 s: 1293320 opens entry A
# 1703497221.5 s: 934524 is waiting for lock L1293320_A
# 1703497221.5 s: 934524 enters lock on side A
# 1703497310.9 s: lock 1293320 closes entry A
# 1703497591.0 s: 239315 is waiting for lock L1306537_A
# 1703497591.0 s: 457564 is waiting for lock L1306537_A
# 1703497951.0 s: lock 1306537 opens entry B
# 1703498071.0 s: 1306537 closes entry B
# 1703498245.7 s: lock 36941 opens entry B
# 1703498245.7 s: 464616 enters lock on side B
# 1703498365.7 s: 36941 closes entry B
# 1703499110.9 s: lock 1293320 opens entry B
# 1703499502.8 s: 883691 is waiting for lock L1287367_A
# 1703499502.8 s: 883691 enters lock on side A
# 1703499562.8 s: lock 1287367 closes entry A
# 1703499837.2 s: 663922 is waiting for lock L1279565_B
# 1703499871.0 s: 1306537 opens entry A
# 1703499871.0 s: 239315 enters lock on side A
# 1703499871.0 s: 457564 enters lock on side A
# 1703499897.2 s: lock 1279565 closes entry A
# 1703499991.0 s: lock 1306537 closes entry A
# 1703500165.7 s: 36941 opens entry A
# 1703500329.2 s: 1090460 is waiting for lock L6568083_B
# 1703500389.2 s: lock 6568083 closes entry A
# 1703500920.5 s: 2486060 is waiting for lock L25235_B
# 1703500980.5 s: lock 25235 closes entry A
# 1703501362.8 s: lock 1287367 opens entry B
# 1703501697.2 s: lock 1279565 opens entry B
# 1703501697.2 s: 663922 enters lock on side B
# 1703501791.0 s: lock 1306537 opens entry B
# 1703501817.2 s: 1279565 closes entry B
# 1703502189.2 s: lock 6568083 opens entry B
# 1703502189.2 s: 1090460 enters lock on side B
# 1703502309.2 s: 6568083 closes entry B
# 1703502780.5 s: lock 25235 opens entry B
# 1703502780.5 s: 2486060 enters lock on side B
# 1703502900.5 s: 25235 closes entry B
# 1703503617.2 s: 1279565 opens entry A
# 1703504109.2 s: 6568083 opens entry A
# 1703504700.5 s: 25235 opens entry A
# 1703508391.0 s: 1306537 closes entry B
# 1703508391.0 s: 2061609 is waiting for lock L1306537_A
# 1703508497.5 s: 828146 is waiting for lock L1288616_B
# 1703508557.5 s: lock 1288616 closes entry A
# 1703508846.4 s: 1779687 is waiting for lock L9305_B
# 1703508906.4 s: lock 9305 closes entry A
# 1703509626.5 s: 934524 is waiting for lock L1293297_B
# 1703509686.5 s: lock 1293297 closes entry A
# 1703510191.0 s: 1306537 opens entry A
# 1703510191.0 s: 2061609 enters lock on side A
# 1703510311.0 s: lock 1306537 closes entry A
# 1703510357.5 s: lock 1288616 opens entry B
# 1703510357.5 s: 828146 enters lock on side B
# 1703510477.5 s: 1288616 closes entry B
# 1703510706.4 s: lock 9305 opens entry B
# 1703510706.4 s: 1779687 enters lock on side B
# 1703510826.4 s: 9305 closes entry B
# 1703511486.5 s: lock 1293297 opens entry B
# 1703511486.5 s: 934524 enters lock on side B
# 1703511606.5 s: 1293297 closes entry B
# 1703512111.0 s: lock 1306537 opens entry B
# 1703512277.5 s: 1288616 opens entry A
# 1703512305.2 s: 828146 is waiting for lock L1288616_A
# 1703512305.2 s: 828146 enters lock on side A
# 1703512397.5 s: lock 1288616 closes entry A
# 1703512455.1 s: 2003602 is waiting for lock L1293297_A
# 1703512455.1 s: 2193858 is waiting for lock L1293297_A
# 1703512626.4 s: 9305 opens entry A
# 1703513406.5 s: 1293297 opens entry A
# 1703513415.1 s: 2003602 enters lock on side A
# 1703513415.1 s: 2193858 enters lock on side A
# 1703513435.5 s: 934524 is waiting for lock L1293297_A
# 1703513526.5 s: lock 1293297 closes entry A
# 1703514197.5 s: lock 1288616 opens entry B
# 1703514555.3 s: 663922 is waiting for lock L1282583_A
# 1703514555.3 s: 663922 enters lock on side A
# 1703514615.3 s: lock 1282583 closes entry A
# 1703515326.5 s: lock 1293297 opens entry B
# 1703515446.5 s: 1293297 closes entry B
# 1703516055.1 s: 939224 is waiting for lock L1293297_A
# 1703516055.1 s: 2003603 is waiting for lock L1293297_A
# 1703516415.3 s: lock 1282583 opens entry B
# 1703516455.1 s: 663922 is waiting for lock L1282583_B
# 1703516455.1 s: 663922 enters lock on side B
# 1703516535.3 s: 1282583 closes entry B
# 1703517246.5 s: 1293297 opens entry A
# 1703517255.1 s: 939224 enters lock on side A
# 1703517255.1 s: 2003603 enters lock on side A
# 1703517366.5 s: lock 1293297 closes entry A
# 1703518335.3 s: 1282583 opens entry A
# 1703518723.0 s: 2244521 is waiting for lock L39446_B
# 1703518783.0 s: lock 39446 closes entry A
# 1703519166.5 s: lock 1293297 opens entry B
# 1703519191.0 s: 1306537 closes entry B
# 1703519191.0 s: 2033644 is waiting for lock L1306537_A
# 1703519286.5 s: 1293297 closes entry B
# 1703519866.2 s: 459886 is waiting for lock L1287830_B
# 1703519926.2 s: lock 1287830 closes entry A
# 1703520583.0 s: lock 39446 opens entry B
# 1703520583.0 s: 2244521 enters lock on side B
# 1703520703.0 s: 39446 closes entry B
# 1703520991.0 s: 1306537 opens entry A
# 1703520991.0 s: 2033644 enters lock on side A
# 1703521086.5 s: 1293297 opens entry A
# 1703521095.5 s: 934524 enters lock on side A
# 1703521111.0 s: lock 1306537 closes entry A
# 1703521206.5 s: lock 1293297 closes entry A
# 1703521506.4 s: lock 9305 closes entry A
# 1703521506.4 s: 1046675 is waiting for lock L9305_B
# 1703521670.4 s: 1090460 is waiting for lock L1295285_A
# 1703521670.4 s: 1090460 enters lock on side A
# 1703521726.2 s: lock 1287830 opens entry B
# 1703521726.2 s: 459886 enters lock on side B
# 1703521730.4 s: lock 1295285 closes entry A
# 1703521846.2 s: 1287830 closes entry B
# 1703522503.0 s: 39446 opens entry A
# 1703522791.0 s: 876766 is waiting for lock L1306537_A
# 1703522897.5 s: 323124 is waiting for lock L1288616_B
# 1703522897.5 s: 1095151 is waiting for lock L1288616_B
# 1703522897.5 s: 1143818 is waiting for lock L1288616_B
# 1703522897.5 s: 323124 enters lock on side B
# 1703522897.5 s: 1095151 enters lock on side B
# 1703522911.0 s: lock 1306537 opens entry B
# 1703522957.5 s: 1288616 closes entry B
# 1703523006.5 s: lock 1293297 opens entry B
# 1703523031.0 s: 1306537 closes entry B
# 1703523306.4 s: lock 9305 opens entry B
# 1703523306.4 s: 1046675 enters lock on side B
# 1703523426.4 s: 9305 closes entry B
# 1703523530.4 s: lock 1295285 opens entry B
# 1703523574.9 s: 1090460 is waiting for lock L1295285_B
# 1703523574.9 s: 1090460 enters lock on side B
# 1703523646.2 s: 1287830 opens entry A
# 1703523650.4 s: 1295285 closes entry B
# 1703523679.8 s: 459886 is waiting for lock L1287830_A
# 1703523679.8 s: 459886 enters lock on side A
# 1703523766.2 s: lock 1287830 closes entry A
# 1703524379.7 s: 211232 is waiting for lock L1296934_B
# 1703524439.7 s: lock 1296934 closes entry A
# 1703524757.5 s: 1288616 opens entry A
# 1703524781.0 s: 2003602 is waiting for lock L1293260_B
# 1703524781.0 s: 2193858 is waiting for lock L1293260_B
# 1703524785.2 s: 323124 is waiting for lock L1288616_A
# 1703524785.2 s: 1095151 is waiting for lock L1288616_A
# 1703524785.2 s: 323124 enters lock on side A
# 1703524785.2 s: 1095151 enters lock on side A
# 1703524831.0 s: 1306537 opens entry A
# 1703524831.0 s: 876766 enters lock on side A
# 1703524841.0 s: lock 1293260 closes entry A
# 1703524877.5 s: lock 1288616 closes entry A
# 1703524951.0 s: lock 1306537 closes entry A
# 1703525226.4 s: 9305 opens entry A
# 1703525346.4 s: lock 9305 closes entry A
# 1703525346.4 s: 1950006 is waiting for lock L9305_B
# 1703525450.4 s: 1295285 opens entry A
# 1703525566.2 s: lock 1287830 opens entry B
# 1703526239.7 s: lock 1296934 opens entry B
# 1703526239.7 s: 211232 enters lock on side B
# 1703526359.7 s: 1296934 closes entry B
# 1703526497.5 s: 800360 is waiting for lock L1288616_B
# 1703526641.0 s: lock 1293260 opens entry B
# 1703526641.0 s: 2003602 enters lock on side B
# 1703526641.0 s: 2193858 enters lock on side B
# 1703526677.5 s: lock 1288616 opens entry B
# 1703526687.5 s: 1143818 enters lock on side B
# 1703526687.5 s: 800360 enters lock on side B
# 1703526751.0 s: lock 1306537 opens entry B
# 1703526761.0 s: 1293260 closes entry B
# 1703526797.5 s: 1288616 closes entry B
# 1703527146.4 s: lock 9305 opens entry B
# 1703527146.4 s: 1950006 enters lock on side B
# 1703527266.4 s: 9305 closes entry B
# 1703528159.7 s: 1296934 opens entry A
# 1703528302.8 s: 1287367 closes entry B
# 1703528302.8 s: 476297 is waiting for lock L1287367_A
# 1703528561.0 s: 1293260 opens entry A
# 1703528591.3 s: 2003602 is waiting for lock L1293260_A
# 1703528591.3 s: 2193858 is waiting for lock L1293260_A
# 1703528591.3 s: 2003602 enters lock on side A
# 1703528591.3 s: 2193858 enters lock on side A
# 1703528597.5 s: 1288616 opens entry A
# 1703528621.0 s: 939224 is waiting for lock L1293260_B
# 1703528621.0 s: 2003603 is waiting for lock L1293260_B
# 1703528625.2 s: 1143818 is waiting for lock L1288616_A
# 1703528625.2 s: 800360 is waiting for lock L1288616_A
# 1703528625.2 s: 1143818 enters lock on side A
# 1703528625.2 s: 800360 enters lock on side A
# 1703528681.0 s: lock 1293260 closes entry A
# 1703528717.5 s: lock 1288616 closes entry A
# 1703529066.4 s: 9305 opens entry A
# 1703529185.6 s: 464616 is waiting for lock L56766_A
# 1703529185.6 s: 464616 enters lock on side A
# 1703529245.6 s: lock 56766 closes entry A
# 1703529991.0 s: 1306537 closes entry B
# 1703529991.0 s: 1308697 is waiting for lock L1306537_A
# 1703530102.8 s: 1287367 opens entry A
# 1703530102.8 s: 476297 enters lock on side A
# 1703530222.8 s: lock 1287367 closes entry A
# 1703530481.0 s: lock 1293260 opens entry B
# 1703530491.0 s: 939224 enters lock on side B
# 1703530491.0 s: 2003603 enters lock on side B
# 1703530517.5 s: lock 1288616 opens entry B
# 1703530601.0 s: 1293260 closes entry B
# 1703531045.6 s: lock 56766 opens entry B
# 1703531205.7 s: 1090460 is waiting for lock L1295302_A
# 1703531205.7 s: 1090460 enters lock on side A
# 1703531227.3 s: 663922 is waiting for lock L1291004_A
# 1703531227.3 s: 663922 enters lock on side A
# 1703531265.7 s: lock 1295302 closes entry A
# 1703531287.3 s: lock 1291004 closes entry A
# 1703531436.6 s: 828146 is waiting for lock L1288610_B
# 1703531496.6 s: lock 1288610 closes entry A
# 1703531791.0 s: 1306537 opens entry A
# 1703531791.0 s: 1308697 enters lock on side A
# 1703531911.0 s: lock 1306537 closes entry A
# 1703532022.8 s: lock 1287367 opens entry B
# 1703532306.4 s: lock 9305 closes entry A
# 1703532306.4 s: 647517 is waiting for lock L9305_B
# 1703532306.4 s: 1647172 is waiting for lock L9305_B
# 1703532401.0 s: 1293260 opens entry A
# 1703532431.3 s: 939224 is waiting for lock L1293260_A
# 1703532431.3 s: 2003603 is waiting for lock L1293260_A
# 1703532431.3 s: 939224 enters lock on side A
# 1703532431.3 s: 2003603 enters lock on side A
# 1703532461.0 s: 934524 is waiting for lock L1293260_B
# 1703532521.0 s: lock 1293260 closes entry A
# 1703532735.6 s: 1500941 is waiting for lock L36941_B
# 1703532745.7 s: lock 36941 closes entry A
# 1703533065.7 s: lock 1295302 opens entry B
# 1703533087.3 s: lock 1291004 opens entry B
# 1703533108.8 s: 1090460 is waiting for lock L1295302_B
# 1703533108.8 s: 1090460 enters lock on side B
# 1703533131.2 s: 663922 is waiting for lock L1291004_B
# 1703533131.2 s: 663922 enters lock on side B
# 1703533185.7 s: 1295302 closes entry B
# 1703533207.3 s: 1291004 closes entry B
# 1703533296.6 s: lock 1288610 opens entry B
# 1703533296.6 s: 828146 enters lock on side B
# 1703533416.6 s: 1288610 closes entry B
# 1703533711.0 s: lock 1306537 opens entry B
# 1703534106.4 s: lock 9305 opens entry B
# 1703534106.4 s: 647517 enters lock on side B
# 1703534106.4 s: 1647172 enters lock on side B
# 1703534226.4 s: 9305 closes entry B
# 1703534321.0 s: lock 1293260 opens entry B
# 1703534331.0 s: 934524 enters lock on side B
# 1703534441.0 s: 1293260 closes entry B
# 1703534545.7 s: lock 36941 opens entry B
# 1703534555.6 s: 1500941 enters lock on side B
# 1703534665.7 s: 36941 closes entry B
# 1703534985.7 s: 1295302 opens entry A
# 1703535007.3 s: 1291004 opens entry A
# 1703535216.6 s: 1288610 opens entry A
# 1703535244.3 s: 828146 is waiting for lock L1288610_A
# 1703535244.3 s: 828146 enters lock on side A
# 1703535336.6 s: lock 1288610 closes entry A
# 1703536026.4 s: 9305 opens entry A
# 1703536146.4 s: lock 9305 closes entry A
# 1703536146.4 s: 1742300 is waiting for lock L9305_B
# 1703536241.0 s: 1293260 opens entry A
# 1703536271.3 s: 934524 is waiting for lock L1293260_A
# 1703536271.3 s: 934524 enters lock on side A
# 1703536355.5 s: 459886 is waiting for lock L1287810_B
# 1703536361.0 s: lock 1293260 closes entry A
# 1703536415.5 s: lock 1287810 closes entry A
# 1703536465.7 s: 36941 opens entry A
# 1703537136.6 s: lock 1288610 opens entry B
# 1703537946.4 s: lock 9305 opens entry B
# 1703537946.4 s: 1742300 enters lock on side B
# 1703537969.9 s: 1303944 is waiting for lock L45980_B
# 1703538029.9 s: lock 45980 closes entry A
# 1703538066.4 s: 9305 closes entry B
# 1703538161.0 s: lock 1293260 opens entry B
# 1703538215.5 s: lock 1287810 opens entry B
# 1703538215.5 s: 459886 enters lock on side B
# 1703538292.5 s: 164947 is waiting for lock L6816_B
# 1703538335.5 s: 1287810 closes entry B
# 1703538352.5 s: lock 6816 closes entry A
# 1703539000.6 s: 2486060 is waiting for lock L39446_B
# 1703539003.0 s: lock 39446 closes entry A
# 1703539829.9 s: lock 45980 opens entry B
# 1703539829.9 s: 1303944 enters lock on side B
# 1703539866.4 s: 9305 opens entry A
# 1703539949.9 s: 45980 closes entry B
# 1703539986.4 s: lock 9305 closes entry A
# 1703539986.4 s: 239315 is waiting for lock L9305_B
# 1703539986.4 s: 457564 is waiting for lock L9305_B
# 1703540135.5 s: 1287810 opens entry A
# 1703540152.5 s: lock 6816 opens entry B
# 1703540152.5 s: 164947 enters lock on side B
# 1703540272.5 s: 6816 closes entry B
# 1703540803.0 s: lock 39446 opens entry B
# 1703540810.6 s: 2486060 enters lock on side B
# 1703540817.0 s: 2003602 is waiting for lock L1293397_B
# 1703540817.0 s: 2193858 is waiting for lock L1293397_B
# 1703540877.0 s: lock 1293397 closes entry A
# 1703540923.0 s: 39446 closes entry B
# 1703541131.3 s: 2189225 is waiting for lock L1293308_B
# 1703541191.3 s: lock 1293308 closes entry A
# 1703541534.9 s: 2145169 is waiting for lock L49032_B
# 1703541594.9 s: lock 49032 closes entry A
# 1703541749.9 s: 45980 opens entry A
# 1703541786.4 s: lock 9305 opens entry B
# 1703541786.4 s: 239315 enters lock on side B
# 1703541786.4 s: 457564 enters lock on side B
# 1703541906.4 s: 9305 closes entry B
# 1703542072.5 s: 6816 opens entry A
# 1703542303.6 s: 2244521 is waiting for lock L42863_B
# 1703542363.6 s: lock 42863 closes entry A
# 1703542677.0 s: lock 1293397 opens entry B
# 1703542677.0 s: 2003602 enters lock on side B
# 1703542677.0 s: 2193858 enters lock on side B
# 1703542723.0 s: 39446 opens entry A
# 1703542797.0 s: 1293397 closes entry B
# 1703542991.3 s: lock 1293308 opens entry B
# 1703542991.3 s: 2189225 enters lock on side B
# 1703543111.3 s: 1293308 closes entry B
# 1703543394.9 s: lock 49032 opens entry B
# 1703543394.9 s: 2145169 enters lock on side B
# 1703543514.9 s: 49032 closes entry B
# 1703543706.4 s: 9305 opens entry A
# 1703543916.6 s: 323124 is waiting for lock L1288610_B
# 1703543916.6 s: 1095151 is waiting for lock L1288610_B
# 1703543916.6 s: 323124 enters lock on side B
# 1703543916.6 s: 1095151 enters lock on side B
# 1703543976.6 s: 1288610 closes entry B
# 1703544144.0 s: 464616 is waiting for lock L22179_A
# 1703544144.0 s: 464616 enters lock on side A
# 1703544163.6 s: lock 42863 opens entry B
# 1703544163.6 s: 2244521 enters lock on side B
# 1703544204.0 s: lock 22179 closes entry A
# 1703544283.6 s: 42863 closes entry B
# 1703544597.0 s: 1293397 opens entry A
# 1703544627.8 s: 2003602 is waiting for lock L1293397_A
# 1703544627.8 s: 2193858 is waiting for lock L1293397_A
# 1703544627.8 s: 2003602 enters lock on side A
# 1703544627.8 s: 2193858 enters lock on side A
# 1703544657.0 s: 939224 is waiting for lock L1293397_B
# 1703544657.0 s: 2003603 is waiting for lock L1293397_B
# 1703544717.0 s: lock 1293397 closes entry A
# 1703544855.1 s: 936841 is waiting for lock L1293297_A
# 1703544906.5 s: 1293297 closes entry B
# 1703544911.3 s: 1293308 opens entry A
# 1703545193.8 s: 1090460 is waiting for lock L1295301_A
# 1703545193.8 s: 1090460 enters lock on side A
# 1703545253.8 s: lock 1295301 closes entry A
# 1703545314.9 s: 49032 opens entry A
# 1703545776.6 s: 1288610 opens entry A
# 1703545804.3 s: 323124 is waiting for lock L1288610_A
# 1703545804.3 s: 1095151 is waiting for lock L1288610_A
# 1703545804.3 s: 323124 enters lock on side A
# 1703545804.3 s: 1095151 enters lock on side A
# 1703545896.6 s: lock 1288610 closes entry A
# 1703546004.0 s: lock 22179 opens entry B
# 1703546083.6 s: 42863 opens entry A
# 1703546517.0 s: lock 1293397 opens entry B
# 1703546527.0 s: 939224 enters lock on side B
# 1703546527.0 s: 2003603 enters lock on side B
# 1703546637.0 s: 1293397 closes entry B
# 1703546706.5 s: 1293297 opens entry A
# 1703546715.1 s: 936841 enters lock on side A
# 1703546826.5 s: lock 1293297 closes entry A
# 1703547053.8 s: lock 1295301 opens entry B
# 1703547696.6 s: lock 1288610 opens entry B
# 1703547756.6 s: 1143818 is waiting for lock L1288610_B
# 1703547756.6 s: 800360 is waiting for lock L1288610_B
# 1703547756.6 s: 1143818 enters lock on side B
# 1703547756.6 s: 800360 enters lock on side B
# 1703547816.6 s: 1288610 closes entry B
# 1703547991.0 s: 1306537 closes entry B
# 1703547991.0 s: 1779688 is waiting for lock L1306537_A
# 1703548437.0 s: 1293397 opens entry A
# 1703548467.8 s: 939224 is waiting for lock L1293397_A
# 1703548467.8 s: 2003603 is waiting for lock L1293397_A
# 1703548467.8 s: 939224 enters lock on side A
# 1703548467.8 s: 2003603 enters lock on side A
# 1703548497.0 s: 934524 is waiting for lock L1293397_B
# 1703548557.0 s: lock 1293397 closes entry A
# 1703548608.8 s: 828146 is waiting for lock L1288670_B
# 1703548626.5 s: lock 1293297 opens entry B
# 1703548668.8 s: lock 1288670 closes entry A
# 1703548769.9 s: lock 45980 closes entry A
# 1703548769.9 s: 1285416 is waiting for lock L45980_B
# 1703548769.9 s: 2170669 is waiting for lock L45980_B
# 1703549616.6 s: 1288610 opens entry A
# 1703549644.3 s: 1143818 is waiting for lock L1288610_A
# 1703549644.3 s: 800360 is waiting for lock L1288610_A
# 1703549644.3 s: 1143818 enters lock on side A
# 1703549644.3 s: 800360 enters lock on side A
# 1703549736.6 s: lock 1288610 closes entry A
# 1703549791.0 s: 1306537 opens entry A
# 1703549791.0 s: 1779688 enters lock on side A
# 1703549907.5 s: 1779687 is waiting for lock L42863_B
# 1703549911.0 s: lock 1306537 closes entry A
# 1703549923.6 s: lock 42863 closes entry A
# 1703550306.4 s: lock 9305 closes entry A
# 1703550306.4 s: 2061609 is waiting for lock L9305_B
# 1703550357.0 s: lock 1293397 opens entry B
# 1703550367.0 s: 934524 enters lock on side B
# 1703550468.8 s: lock 1288670 opens entry B
# 1703550468.8 s: 828146 enters lock on side B
# 1703550477.0 s: 1293397 closes entry B
# 1703550569.9 s: lock 45980 opens entry B
# 1703550569.9 s: 1285416 enters lock on side B
# 1703550569.9 s: 2170669 enters lock on side B
# 1703550588.8 s: 1288670 closes entry B
# 1703550689.9 s: 45980 closes entry B
# 1703550994.5 s: 464616 is waiting for lock L57548_A
# 1703550994.5 s: 464616 enters lock on side A
# 1703551041.5 s: 663922 is waiting for lock L1291009_A
# 1703551041.5 s: 663922 enters lock on side A
# 1703551054.5 s: lock 57548 closes entry A
# 1703551101.5 s: lock 1291009 closes entry A
# 1703551536.6 s: lock 1288610 opens entry B
# 1703551711.0 s: lock 1306537 opens entry B
# 1703551714.6 s: 1938225 is waiting for lock L4737157_B
# 1703551723.6 s: lock 42863 opens entry B
# 1703551727.5 s: 1779687 enters lock on side B
# 1703551773.8 s: 1081906 is waiting for lock L49032_B
# 1703551774.6 s: lock 4737157 closes entry A
# 1703551794.9 s: lock 49032 closes entry A
# 1703551843.6 s: 42863 closes entry B
# 1703552106.4 s: lock 9305 opens entry B
# 1703552106.4 s: 2061609 enters lock on side B
# 1703552226.4 s: 9305 closes entry B
# 1703552277.0 s: 1293397 opens entry A
# 1703552307.8 s: 934524 is waiting for lock L1293397_A
# 1703552307.8 s: 934524 enters lock on side A
# 1703552369.9 s: 1500940 is waiting for lock L45980_B
# 1703552388.8 s: 1288670 opens entry A
# 1703552397.0 s: lock 1293397 closes entry A
# 1703552489.9 s: 45980 opens entry A
# 1703552609.9 s: lock 45980 closes entry A
# 1703552854.5 s: lock 57548 opens entry B
# 1703552901.5 s: lock 1291009 opens entry B
# 1703552945.4 s: 663922 is waiting for lock L1291009_B
# 1703552945.4 s: 663922 enters lock on side B
# 1703553021.5 s: 1291009 closes entry B
# 1703553351.2 s: 459886 is waiting for lock L1300104_B
# 1703553411.2 s: lock 1300104 closes entry A
# 1703553574.6 s: lock 4737157 opens entry B
# 1703553574.6 s: 1938225 enters lock on side B
# 1703553594.9 s: lock 49032 opens entry B
# 1703553603.8 s: 1081906 enters lock on side B
# 1703553643.6 s: 42863 opens entry A
# 1703553694.6 s: 4737157 closes entry B
# 1703553714.9 s: 49032 closes entry B
# 1703554026.4 s: 9305 opens entry A
# 1703554197.0 s: lock 1293397 opens entry B
# 1703554409.9 s: lock 45980 opens entry B
# 1703554409.9 s: 1500940 enters lock on side B
# 1703554529.9 s: 45980 closes entry B
# 1703554821.5 s: 1291009 opens entry A
# 1703555211.2 s: lock 1300104 opens entry B
# 1703555211.2 s: 459886 enters lock on side B
# 1703555331.2 s: 1300104 closes entry B
# 1703555494.6 s: 4737157 opens entry A
# 1703555514.9 s: 49032 opens entry A
# 1703555529.7 s: 1938225 is waiting for lock L4737157_A
# 1703555529.7 s: 1938225 enters lock on side A
# 1703555614.6 s: lock 4737157 closes entry A
# 1703555969.9 s: 1887281 is waiting for lock L45980_B
# 1703555981.6 s: 139553 is waiting for lock L8031154_B
# 1703556041.6 s: lock 8031154 closes entry A
# 1703556329.9 s: 45980 opens entry A
# 1703556449.9 s: lock 45980 closes entry A
# 1703557131.2 s: 1300104 opens entry A
# 1703557161.9 s: 459886 is waiting for lock L1300104_A
# 1703557161.9 s: 459886 enters lock on side A
# 1703557251.2 s: lock 1300104 closes entry A
# 1703557414.6 s: lock 4737157 opens entry B
# 1703557551.2 s: 2003602 is waiting for lock L1293308_B
# 1703557551.2 s: 2193858 is waiting for lock L1293308_B
# 1703557571.3 s: lock 1293308 closes entry A
# 1703557841.6 s: lock 8031154 opens entry B
# 1703557841.6 s: 139553 enters lock on side B
# 1703557961.6 s: 8031154 closes entry B
# 1703558081.0 s: 936841 is waiting for lock L1293260_B
# 1703558081.0 s: 936841 enters lock on side B
# 1703558141.0 s: 1293260 closes entry B
# 1703558249.9 s: lock 45980 opens entry B
# 1703558249.9 s: 1887281 enters lock on side B
# 1703558369.9 s: 45980 closes entry B
# 1703559051.2 s: lock 1300104 opens entry B
# 1703559124.0 s: 1090460 is waiting for lock L1295171_A
# 1703559124.0 s: 1090460 enters lock on side A
# 1703559168.8 s: lock 1288670 closes entry A
# 1703559168.8 s: 323124 is waiting for lock L1288670_B
# 1703559168.8 s: 1095151 is waiting for lock L1288670_B
# 1703559184.0 s: lock 1295171 closes entry A
# 1703559371.3 s: lock 1293308 opens entry B
# 1703559381.2 s: 2003602 enters lock on side B
# 1703559381.2 s: 2193858 enters lock on side B
# 1703559491.3 s: 1293308 closes entry B
# 1703559569.9 s: 1376160 is waiting for lock L45980_B
# 1703559761.6 s: 8031154 opens entry A
# 1703559805.7 s: 139553 is waiting for lock L8031154_A
# 1703559805.7 s: 139553 enters lock on side A
# 1703559881.6 s: lock 8031154 closes entry A
# 1703559941.0 s: 1293260 opens entry A
# 1703559971.3 s: 936841 is waiting for lock L1293260_A
# 1703559971.3 s: 936841 enters lock on side A
# 1703560061.0 s: lock 1293260 closes entry A
# 1703560169.9 s: 45980 opens entry A
# 1703560289.9 s: lock 45980 closes entry A
# 1703560703.5 s: 1938225 is waiting for lock L6533640_B
# 1703560763.5 s: lock 6533640 closes entry A
# 1703560968.8 s: lock 1288670 opens entry B
# 1703560968.8 s: 323124 enters lock on side B
# 1703560968.8 s: 1095151 enters lock on side B
# 1703560984.0 s: lock 1295171 opens entry B
# 1703561020.3 s: 1090460 is waiting for lock L1295171_B
# 1703561020.3 s: 1090460 enters lock on side B
# 1703561088.8 s: 1288670 closes entry B
# 1703561104.0 s: 1295171 closes entry B
# 1703561106.4 s: lock 9305 closes entry A
# 1703561106.4 s: 2033644 is waiting for lock L9305_B
# 1703561291.3 s: 1293308 opens entry A
# 1703561391.2 s: 939224 is waiting for lock L1293308_B
# 1703561391.2 s: 2003603 is waiting for lock L1293308_B
# 1703561411.3 s: lock 1293308 closes entry A
# 1703561681.6 s: lock 8031154 opens entry B
# 1703561861.0 s: lock 1293260 opens entry B
# 1703562089.9 s: lock 45980 opens entry B
# 1703562089.9 s: 1376160 enters lock on side B
# 1703562209.9 s: 45980 closes entry B
# 1703562507.5 s: 1046675 is waiting for lock L42863_B
# 1703562523.6 s: lock 42863 closes entry A
# 1703562523.6 s: 2486060 is waiting for lock L42863_B
# 1703562563.5 s: lock 6533640 opens entry B
# 1703562563.5 s: 1938225 enters lock on side B
# 1703562683.5 s: 6533640 closes entry B
# 1703562888.8 s: 1288670 opens entry A
# 1703562904.0 s: 1295171 opens entry A
# 1703562906.4 s: lock 9305 opens entry B
# 1703562906.4 s: 2033644 enters lock on side B
# 1703563008.8 s: lock 1288670 closes entry A
# 1703563008.8 s: 1143818 is waiting for lock L1288670_B
# 1703563008.8 s: 800360 is waiting for lock L1288670_B
# 1703563026.4 s: 9305 closes entry B
# 1703563169.9 s: 957734 is waiting for lock L45980_B
# 1703563211.3 s: lock 1293308 opens entry B
# 1703563221.2 s: 939224 enters lock on side B
# 1703563221.2 s: 2003603 enters lock on side B
# 1703563331.3 s: 1293308 closes entry B
# 1703564009.9 s: 45980 opens entry A
# 1703564129.9 s: lock 45980 closes entry A
# 1703564323.6 s: lock 42863 opens entry B
# 1703564323.6 s: 2486060 enters lock on side B
# 1703564327.5 s: 1046675 enters lock on side B
# 1703564443.6 s: 42863 closes entry B
# 1703564483.5 s: 6533640 opens entry A
# 1703564808.8 s: lock 1288670 opens entry B
# 1703564808.8 s: 1143818 enters lock on side B
# 1703564808.8 s: 800360 enters lock on side B
# 1703564826.4 s: 9305 opens entry A
# 1703564928.8 s: 1288670 closes entry B
# 1703564946.4 s: lock 9305 closes entry A
# 1703564946.4 s: 876766 is waiting for lock L9305_B
# 1703565131.3 s: 1293308 opens entry A
# 1703565231.2 s: 934524 is waiting for lock L1293308_B
# 1703565251.3 s: lock 1293308 closes entry A
# 1703565485.6 s: 1500941 is waiting for lock L56766_A
# 1703565545.6 s: 56766 closes entry B
# 1703565929.9 s: lock 45980 opens entry B
# 1703565929.9 s: 957734 enters lock on side B
# 1703566049.9 s: 45980 closes entry B
# 1703566243.6 s: 42863 opens entry A
# 1703566347.5 s: 1950006 is waiting for lock L42863_B
# 1703566363.6 s: lock 42863 closes entry A
# 1703566728.8 s: 1288670 opens entry A
# 1703566746.4 s: lock 9305 opens entry B
# 1703566746.4 s: 876766 enters lock on side B
# 1703566769.9 s: 1635497 is waiting for lock L45980_B
# 1703566866.4 s: 9305 closes entry B
# 1703566920.0 s: 663922 is waiting for lock L1290993_A
# 1703566920.0 s: 663922 enters lock on side A
# 1703566980.0 s: lock 1290993 closes entry A
# 1703567051.3 s: lock 1293308 opens entry B
# 1703567061.2 s: 934524 enters lock on side B
# 1703567171.3 s: 1293308 closes entry B
# 1703567345.6 s: 56766 opens entry A
# 1703567345.6 s: 1500941 enters lock on side A
# 1703567465.6 s: lock 56766 closes entry A
# 1703567849.9 s: 45980 opens entry A
# 1703567969.9 s: lock 45980 closes entry A
# 1703568163.6 s: lock 42863 opens entry B
# 1703568167.5 s: 1950006 enters lock on side B
# 1703568283.6 s: 42863 closes entry B
# 1703568666.4 s: 9305 opens entry A
# 1703568780.0 s: lock 1290993 opens entry B
# 1703568824.4 s: 663922 is waiting for lock L1290993_B
# 1703568824.4 s: 663922 enters lock on side B
# 1703568900.0 s: 1290993 closes entry B
# 1703568971.3 s: 1293308 opens entry A
# 1703569265.6 s: lock 56766 opens entry B
# 1703569769.9 s: lock 45980 opens entry B
# 1703569769.9 s: 1635497 enters lock on side B
# 1703569889.9 s: 45980 closes entry B
# 1703570083.6 s: 42863 opens entry A
# 1703570223.2 s: 139553 is waiting for lock L1299706_B
# 1703570283.2 s: lock 1299706 closes entry A
# 1703570369.9 s: 1510192 is waiting for lock L45980_B
# 1703570700.0 s: 1290993 opens entry A
# 1703571689.9 s: 45980 opens entry A
# 1703571809.9 s: lock 45980 closes entry A
# 1703571906.4 s: lock 9305 closes entry A
# 1703571906.4 s: 1308697 is waiting for lock L9305_B
# 1703572083.2 s: lock 1299706 opens entry B
# 1703572083.2 s: 139553 enters lock on side B
# 1703572137.9 s: 459886 is waiting for lock L1300203_B
# 1703572197.0 s: 936841 is waiting for lock L1293397_B
# 1703572197.0 s: 936841 enters lock on side B
# 1703572197.9 s: lock 1300203 closes entry A
# 1703572202.9 s: 1090460 is waiting for lock L1295204_A
# 1703572202.9 s: 1090460 enters lock on side A
# 1703572203.2 s: 1299706 closes entry B
# 1703572257.0 s: 1293397 closes entry B
# 1703572262.9 s: lock 1295204 closes entry A
# 1703573307.5 s: 647517 is waiting for lock L42863_B
# 1703573307.5 s: 1647172 is waiting for lock L42863_B
# 1703573323.6 s: lock 42863 closes entry A
# 1703573609.9 s: lock 45980 opens entry B
# 1703573609.9 s: 1510192 enters lock on side B
# 1703573706.4 s: lock 9305 opens entry B
# 1703573706.4 s: 1308697 enters lock on side B
# 1703573729.9 s: 45980 closes entry B
# 1703573826.4 s: 9305 closes entry B
# 1703573997.9 s: lock 1300203 opens entry B
# 1703573997.9 s: 459886 enters lock on side B
# 1703574003.2 s: 1299706 opens entry A
# 1703574046.6 s: 139553 is waiting for lock L1299706_A
# 1703574046.6 s: 139553 enters lock on side A
# 1703574057.0 s: 1293397 opens entry A
# 1703574062.9 s: lock 1295204 opens entry B
# 1703574087.8 s: 936841 is waiting for lock L1293397_A
# 1703574087.8 s: 936841 enters lock on side A
# 1703574117.9 s: 1300203 closes entry B
# 1703574123.2 s: lock 1299706 closes entry A
# 1703574177.0 s: lock 1293397 closes entry A
# 1703575123.6 s: lock 42863 opens entry B
# 1703575127.5 s: 647517 enters lock on side B
# 1703575127.5 s: 1647172 enters lock on side B
# 1703575243.6 s: 42863 closes entry B
# 1703575529.9 s: 45980 opens entry A
# 1703575626.4 s: 9305 opens entry A
# 1703575678.9 s: 464616 is waiting for lock L51498_A
# 1703575678.9 s: 464616 enters lock on side A
# 1703575738.9 s: lock 51498 closes entry A
# 1703575917.9 s: 1300203 opens entry A
# 1703575923.2 s: lock 1299706 opens entry B
# 1703575949.6 s: 459886 is waiting for lock L1300203_A
# 1703575949.6 s: 459886 enters lock on side A
# 1703575977.0 s: lock 1293397 opens entry B
# 1703576037.9 s: lock 1300203 closes entry A
# 1703577043.6 s: 42863 opens entry A
# 1703577147.5 s: 1742300 is waiting for lock L42863_B
# 1703577163.6 s: lock 42863 closes entry A
# 1703577538.9 s: lock 51498 opens entry B
# 1703577569.9 s: lock 45980 closes entry A
# 1703577569.9 s: 2421374 is waiting for lock L45980_B
# 1703577837.9 s: lock 1300203 opens entry B
# 1703578963.6 s: lock 42863 opens entry B
# 1703578967.5 s: 1742300 enters lock on side B
# 1703579083.6 s: 42863 closes entry B
# 1703579369.9 s: lock 45980 opens entry B
# 1703579369.9 s: 2421374 enters lock on side B
# 1703579489.9 s: 45980 closes entry B
# 1703579538.3 s: 211232 is waiting for lock L6764638_B
# 1703579598.3 s: lock 6764638 closes entry A
# 1703580120.5 s: lock 25235 closes entry A
# 1703580120.5 s: 927645 is waiting for lock L25235_B
# 1703580883.6 s: 42863 opens entry A
# 1703580987.5 s: 239315 is waiting for lock L42863_B
# 1703580987.5 s: 457564 is waiting for lock L42863_B
# 1703581003.6 s: lock 42863 closes entry A
# 1703581169.9 s: 2407437 is waiting for lock L45980_B
# 1703581289.9 s: 45980 opens entry A
# 1703581398.3 s: lock 6764638 opens entry B
# 1703581398.3 s: 211232 enters lock on side B
# 1703581409.9 s: lock 45980 closes entry A
# 1703581518.3 s: 6764638 closes entry B
# 1703581920.5 s: lock 25235 opens entry B
# 1703581920.5 s: 927645 enters lock on side B
# 1703582040.5 s: 25235 closes entry B
# 1703582364.0 s: 22179 closes entry B
# 1703582364.0 s: 1500941 is waiting for lock L22179_A
# 1703582803.6 s: lock 42863 opens entry B
# 1703582807.5 s: 239315 enters lock on side B
# 1703582807.5 s: 457564 enters lock on side B
# 1703582923.6 s: 42863 closes entry B
# 1703583209.9 s: lock 45980 opens entry B
# 1703583209.9 s: 2407437 enters lock on side B
# 1703583318.3 s: 6764638 opens entry A
# 1703583329.9 s: 45980 closes entry B
# 1703583840.5 s: 25235 opens entry A
# 1703584164.0 s: 22179 opens entry A
# 1703584164.0 s: 1500941 enters lock on side A
# 1703584284.0 s: lock 22179 closes entry A
# 1703584723.6 s: 42863 opens entry A
# 1703585006.1 s: 164947 is waiting for lock L50750_A
# 1703585006.1 s: 164947 enters lock on side A
# 1703585066.1 s: lock 50750 closes entry A
# 1703585082.0 s: 1090460 is waiting for lock L1295180_A
# 1703585082.0 s: 1090460 enters lock on side A
# 1703585129.9 s: 45980 opens entry A
# 1703585142.0 s: lock 1295180 closes entry A
# 1703585163.1 s: 663922 is waiting for lock L1291035_A
# 1703585163.1 s: 663922 enters lock on side A
# 1703585223.1 s: lock 1291035 closes entry A
# 1703586084.0 s: lock 22179 opens entry B
# 1703586866.1 s: lock 50750 opens entry B
# 1703586942.0 s: lock 1295180 opens entry B
# 1703586971.9 s: 1090460 is waiting for lock L1295180_B
# 1703586971.9 s: 1090460 enters lock on side B
# 1703587011.2 s: 936841 is waiting for lock L1293308_B
# 1703587023.1 s: lock 1291035 opens entry B
# 1703587031.3 s: lock 1293308 closes entry A
# 1703587062.0 s: 1295180 closes entry B
# 1703587065.5 s: 663922 is waiting for lock L1291035_B
# 1703587065.5 s: 663922 enters lock on side B
# 1703587143.1 s: 1291035 closes entry B
# 1703588369.9 s: lock 45980 closes entry A
# 1703588369.9 s: 1195091 is waiting for lock L45980_B
# 1703588831.3 s: lock 1293308 opens entry B
# 1703588841.2 s: 936841 enters lock on side B
# 1703588862.0 s: 1295180 opens entry A
# 1703588943.1 s: 1291035 opens entry A
# 1703588951.3 s: 1293308 closes entry B
# 1703589167.9 s: 459886 is waiting for lock L1300102_B
# 1703589227.9 s: lock 1300102 closes entry A
# 1703589906.4 s: lock 9305 closes entry A
# 1703589906.4 s: 1779688 is waiting for lock L9305_B
# 1703590169.9 s: lock 45980 opens entry B
# 1703590169.9 s: 1195091 enters lock on side B
# 1703590289.9 s: 45980 closes entry B
# 1703590751.3 s: 1293308 opens entry A
# 1703591027.9 s: lock 1300102 opens entry B
# 1703591027.9 s: 459886 enters lock on side B
# 1703591074.5 s: 57548 closes entry B
# 1703591074.5 s: 1500941 is waiting for lock L57548_A
# 1703591147.9 s: 1300102 closes entry B
# 1703591307.5 s: 2061609 is waiting for lock L42863_B
# 1703591323.6 s: lock 42863 closes entry A
# 1703591706.4 s: lock 9305 opens entry B
# 1703591706.4 s: 1779688 enters lock on side B
# 1703591826.4 s: 9305 closes entry B
# 1703591992.8 s: 211232 is waiting for lock L6764544_B
# 1703592052.8 s: lock 6764544 closes entry A
# 1703592089.9 s: 45980 opens entry A
# 1703592874.5 s: 57548 opens entry A
# 1703592874.5 s: 1500941 enters lock on side A
# 1703592947.9 s: 1300102 opens entry A
# 1703592980.5 s: 459886 is waiting for lock L1300102_A
# 1703592980.5 s: 459886 enters lock on side A
# 1703592994.5 s: lock 57548 closes entry A
# 1703593067.9 s: lock 1300102 closes entry A
# 1703593123.6 s: lock 42863 opens entry B
# 1703593127.5 s: 2061609 enters lock on side B
# 1703593243.6 s: 42863 closes entry B
# 1703593626.4 s: 9305 opens entry A
# 1703593852.8 s: lock 6764544 opens entry B
# 1703593852.8 s: 211232 enters lock on side B
# 1703593972.8 s: 6764544 closes entry B
# 1703594794.5 s: lock 57548 opens entry B
# 1703594867.9 s: lock 1300102 opens entry B
# 1703595043.6 s: 42863 opens entry A
# 1703595569.9 s: lock 45980 closes entry A
# 1703595569.9 s: 777209 is waiting for lock L45980_B
# 1703595668.9 s: 1090460 is waiting for lock L1295215_A
# 1703595668.9 s: 1090460 enters lock on side A
# 1703595728.9 s: lock 1295215 closes entry A
# 1703595772.8 s: 6764544 opens entry A
# 1703595800.1 s: 211232 is waiting for lock L6764544_A
# 1703595800.1 s: 211232 enters lock on side A
# 1703595892.8 s: lock 6764544 closes entry A
# 1703597369.9 s: lock 45980 opens entry B
# 1703597369.9 s: 777209 enters lock on side B
# 1703597489.9 s: 45980 closes entry B
# 1703597528.9 s: lock 1295215 opens entry B
# 1703597692.8 s: lock 6764544 opens entry B
# 1703599169.9 s: 753938 is waiting for lock L45980_B
# 1703599289.9 s: 45980 opens entry A
# 1703599409.9 s: lock 45980 closes entry A
# 1703600455.5 s: 1938225 is waiting for lock L6525862_B
# 1703600515.5 s: lock 6525862 closes entry A
# 1703601209.9 s: lock 45980 opens entry B
# 1703601209.9 s: 753938 enters lock on side B
# 1703601329.9 s: 45980 closes entry B
# 1703602107.5 s: 2033644 is waiting for lock L42863_B
# 1703602123.6 s: lock 42863 closes entry A
# 1703602315.5 s: lock 6525862 opens entry B
# 1703602315.5 s: 1938225 enters lock on side B
# 1703602435.5 s: 6525862 closes entry B
# 1703603129.9 s: 45980 opens entry A
# 1703603923.6 s: lock 42863 opens entry B
# 1703603927.5 s: 2033644 enters lock on side B
# 1703604043.6 s: 42863 closes entry B
# 1703604235.5 s: 6525862 opens entry A
# 1703604262.9 s: 1938225 is waiting for lock L6525862_A
# 1703604262.9 s: 1938225 enters lock on side A
# 1703604355.5 s: lock 6525862 closes entry A
# 1703604925.3 s: 663922 is waiting for lock L1291001_A
# 1703604925.3 s: 663922 enters lock on side A
# 1703604985.3 s: lock 1291001 closes entry A
# 1703605598.1 s: 459886 is waiting for lock L1300188_B
# 1703605658.1 s: lock 1300188 closes entry A
# 1703605692.5 s: 1102026 is waiting for lock L49032_B
# 1703605734.9 s: lock 49032 closes entry A
# 1703605843.6 s: 42863 opens entry A
# 1703605947.5 s: 876766 is waiting for lock L42863_B
# 1703605963.6 s: lock 42863 closes entry A
# 1703606155.5 s: lock 6525862 opens entry B
# 1703606369.9 s: lock 45980 closes entry A
# 1703606369.9 s: 227671 is waiting for lock L45980_B
# 1703606369.9 s: 1677302 is waiting for lock L45980_B
# 1703606785.3 s: lock 1291001 opens entry B
# 1703606826.8 s: 663922 is waiting for lock L1291001_B
# 1703606826.8 s: 663922 enters lock on side B
# 1703606905.3 s: 1291001 closes entry B
# 1703607458.1 s: lock 1300188 opens entry B
# 1703607458.1 s: 459886 enters lock on side B
# 1703607503.6 s: 693954 is waiting for lock L49032_B
# 1703607534.9 s: lock 49032 opens entry B
# 1703607542.5 s: 1102026 enters lock on side B
# 1703607543.6 s: 693954 enters lock on side B
# 1703607578.1 s: 1300188 closes entry B
# 1703607654.9 s: 49032 closes entry B
# 1703607763.6 s: lock 42863 opens entry B
# 1703607767.5 s: 876766 enters lock on side B
# 1703607883.6 s: 42863 closes entry B
# 1703608169.9 s: lock 45980 opens entry B
# 1703608169.9 s: 227671 enters lock on side B
# 1703608169.9 s: 1677302 enters lock on side B
# 1703608289.9 s: 45980 closes entry B
# 1703608705.3 s: 1291001 opens entry A
# 1703609378.1 s: 1300188 opens entry A
# 1703609416.7 s: 459886 is waiting for lock L1300188_A
# 1703609416.7 s: 459886 enters lock on side A
# 1703609454.9 s: 49032 opens entry A
# 1703609498.1 s: lock 1300188 closes entry A
# 1703609683.6 s: 42863 opens entry A
# 1703609969.9 s: 1737684 is waiting for lock L45980_B
# 1703610089.9 s: 45980 opens entry A
# 1703610209.9 s: lock 45980 closes entry A
# 1703611298.1 s: lock 1300188 opens entry B
# 1703612009.9 s: lock 45980 opens entry B
# 1703612009.9 s: 1737684 enters lock on side B
# 1703612129.9 s: 45980 closes entry B
# 1703612907.5 s: 1308697 is waiting for lock L42863_B
# 1703612923.6 s: lock 42863 closes entry A
# 1703613569.9 s: 760855 is waiting for lock L45980_B
# 1703613569.9 s: 1215924 is waiting for lock L45980_B
# 1703613569.9 s: 2200797 is waiting for lock L45980_B
# 1703613929.9 s: 45980 opens entry A
# 1703614049.9 s: lock 45980 closes entry A
# 1703614723.6 s: lock 42863 opens entry B
# 1703614727.5 s: 1308697 enters lock on side B
# 1703614843.6 s: 42863 closes entry B
# 1703615849.9 s: lock 45980 opens entry B
# 1703615849.9 s: 760855 enters lock on side B
# 1703615849.9 s: 1215924 enters lock on side B
# 1703615969.9 s: 45980 closes entry B
# 1703616492.5 s: 2337674 is waiting for lock L49032_B
# 1703616534.9 s: lock 49032 closes entry A
# 1703616643.6 s: 42863 opens entry A
# 1703617618.9 s: 51498 closes entry B
# 1703617618.9 s: 1500941 is waiting for lock L51498_A
# 1703617769.9 s: 45980 opens entry A
# 1703617889.9 s: lock 45980 closes entry A
# 1703618047.9 s: 459886 is waiting for lock L1300148_B
# 1703618107.9 s: lock 1300148 closes entry A
# 1703618140.6 s: 927645 is waiting for lock L39446_B
# 1703618143.0 s: lock 39446 closes entry A
# 1703618334.9 s: lock 49032 opens entry B
# 1703618342.5 s: 2337674 enters lock on side B
# 1703618454.9 s: 49032 closes entry B
# 1703619058.6 s: 139553 is waiting for lock L1299673_B
# 1703619118.6 s: lock 1299673 closes entry A
# 1703619418.9 s: 51498 opens entry A
# 1703619418.9 s: 1500941 enters lock on side A
# 1703619538.9 s: lock 51498 closes entry A
# 1703619689.9 s: lock 45980 opens entry B
# 1703619689.9 s: 2200797 enters lock on side B
# 1703619809.9 s: 45980 closes entry B
# 1703619907.9 s: lock 1300148 opens entry B
# 1703619907.9 s: 459886 enters lock on side B
# 1703619943.0 s: lock 39446 opens entry B
# 1703619950.6 s: 927645 enters lock on side B
# 1703620027.9 s: 1300148 closes entry B
# 1703620063.0 s: 39446 closes entry B
# 1703620078.7 s: 1772694 is waiting for lock L49032_B
# 1703620254.9 s: 49032 opens entry A
# 1703620374.9 s: lock 49032 closes entry A
# 1703620769.9 s: 545727 is waiting for lock L45980_B
# 1703620918.6 s: lock 1299673 opens entry B
# 1703620918.6 s: 139553 enters lock on side B
# 1703621038.6 s: 1299673 closes entry B
# 1703621338.9 s: lock 51498 opens entry B
# 1703621609.9 s: 45980 opens entry A
# 1703621729.9 s: lock 45980 closes entry A
# 1703621827.9 s: 1300148 opens entry A
# 1703621863.0 s: 39446 opens entry A
# 1703621865.0 s: 459886 is waiting for lock L1300148_A
# 1703621865.0 s: 459886 enters lock on side A
# 1703621947.9 s: lock 1300148 closes entry A
# 1703622174.9 s: lock 49032 opens entry B
# 1703622178.7 s: 1772694 enters lock on side B
# 1703622249.4 s: 1174221 is waiting for lock L45980_A
# 1703622294.9 s: 49032 closes entry B
# 1703622525.6 s: 663922 is waiting for lock L1291057_A
# 1703622525.6 s: 663922 enters lock on side A
# 1703622585.6 s: lock 1291057 closes entry A
# 1703622838.6 s: 1299673 opens entry A
# 1703623529.9 s: lock 45980 opens entry B
# 1703623529.9 s: 545727 enters lock on side B
# 1703623649.9 s: 45980 closes entry B
# 1703623747.9 s: lock 1300148 opens entry B
# 1703624094.9 s: 49032 opens entry A
# 1703624385.6 s: lock 1291057 opens entry B
# 1703624427.8 s: 663922 is waiting for lock L1291057_B
# 1703624427.8 s: 663922 enters lock on side B
# 1703624505.6 s: 1291057 closes entry B
# 1703625449.9 s: 45980 opens entry A
# 1703625459.4 s: 1174221 enters lock on side A
# 1703625506.4 s: 164947 is waiting for lock L22820_A
# 1703625506.4 s: 164947 enters lock on side A
# 1703625566.4 s: lock 22820 closes entry A
# 1703625569.9 s: lock 45980 closes entry A
# 1703626305.6 s: 1291057 opens entry A
# 1703627292.5 s: 1570264 is waiting for lock L49032_B
# 1703627334.9 s: lock 49032 closes entry A
# 1703627366.4 s: lock 22820 opens entry B
# 1703627369.9 s: lock 45980 opens entry B
# 1703629037.5 s: 828146 is waiting for lock L49032_B
# 1703629134.9 s: lock 49032 opens entry B
# 1703629137.5 s: 828146 enters lock on side B
# 1703629142.5 s: 1570264 enters lock on side B
# 1703629254.9 s: 49032 closes entry B
# 1703629901.6 s: 1938225 is waiting for lock L1284020_B
# 1703629961.6 s: lock 1284020 closes entry A
# 1703630907.5 s: 1779688 is waiting for lock L42863_B
# 1703630923.6 s: lock 42863 closes entry A
# 1703631054.9 s: 49032 opens entry A
# 1703631761.6 s: lock 1284020 opens entry B
# 1703631761.6 s: 1938225 enters lock on side B
# 1703631881.6 s: 1284020 closes entry B
# 1703632723.6 s: lock 42863 opens entry B
# 1703632727.5 s: 1779688 enters lock on side B
# 1703632843.6 s: 42863 closes entry B
# 1703633049.4 s: 1894321 is waiting for lock L45980_A
# 1703633069.9 s: 45980 closes entry B
# 1703633681.6 s: 1284020 opens entry A
# 1703634643.6 s: 42863 opens entry A
# 1703634869.9 s: 45980 opens entry A
# 1703634879.4 s: 1894321 enters lock on side A
# 1703634989.9 s: lock 45980 closes entry A
# 1703636789.9 s: lock 45980 opens entry B
# 1703639688.0 s: 459886 is waiting for lock L1300122_B
# 1703639748.0 s: lock 1300122 closes entry A
# 1703640920.8 s: 663922 is waiting for lock L1273380_A
# 1703640920.8 s: 663922 enters lock on side A
# 1703640980.8 s: lock 1273380 closes entry A
# 1703641548.0 s: lock 1300122 opens entry B
# 1703641548.0 s: 459886 enters lock on side B
# 1703641663.6 s: lock 42863 closes entry A
# 1703641663.6 s: 927645 is waiting for lock L42863_B
# 1703641668.0 s: 1300122 closes entry B
# 1703641803.6 s: 1938225 is waiting for lock L1295180_A
# 1703641803.6 s: 1938225 enters lock on side A
# 1703641842.0 s: lock 1295180 closes entry A
# 1703642350.5 s: 211232 is waiting for lock L6749452_B
# 1703642410.5 s: lock 6749452 closes entry A
# 1703642780.8 s: lock 1273380 opens entry B
# 1703642820.7 s: 663922 is waiting for lock L1273380_B
# 1703642820.7 s: 663922 enters lock on side B
# 1703642900.8 s: 1273380 closes entry B
# 1703643463.6 s: lock 42863 opens entry B
# 1703643463.6 s: 927645 enters lock on side B
# 1703643468.0 s: 1300122 opens entry A
# 1703643498.4 s: 459886 is waiting for lock L1300122_A
# 1703643498.4 s: 459886 enters lock on side A
# 1703643583.6 s: 42863 closes entry B
# 1703643588.0 s: lock 1300122 closes entry A
# 1703643642.0 s: lock 1295180 opens entry B
# 1703643671.9 s: 1938225 is waiting for lock L1295180_B
# 1703643671.9 s: 1938225 enters lock on side B
# 1703643762.0 s: 1295180 closes entry B
# 1703644210.5 s: lock 6749452 opens entry B
# 1703644210.5 s: 211232 enters lock on side B
# 1703644330.5 s: 6749452 closes entry B
# 1703644700.8 s: 1273380 opens entry A
# 1703645383.6 s: 42863 opens entry A
# 1703645388.0 s: lock 1300122 opens entry B
# 1703645562.0 s: 1295180 opens entry A
# 1703646130.5 s: 6749452 opens entry A
# 1703646160.0 s: 211232 is waiting for lock L6749452_A
# 1703646160.0 s: 211232 enters lock on side A
# 1703646250.5 s: lock 6749452 closes entry A
# 1703646320.9 s: 2131288 is waiting for lock L45980_A
# 1703646329.9 s: 45980 closes entry B
# 1703648050.5 s: lock 6749452 opens entry B
# 1703648129.9 s: 45980 opens entry A
# 1703648130.9 s: 2131288 enters lock on side A
# 1703648249.9 s: lock 45980 closes entry A
# 1703649345.3 s: 459886 is waiting for lock L1300124_B
# 1703649405.3 s: lock 1300124 closes entry A
# 1703650049.9 s: lock 45980 opens entry B
# 1703651205.3 s: lock 1300124 opens entry B
# 1703651205.3 s: 459886 enters lock on side B
# 1703651325.3 s: 1300124 closes entry B
# 1703652368.9 s: 1295215 closes entry B
# 1703652368.9 s: 1938225 is waiting for lock L1295215_A
# 1703652537.9 s: 464616 is waiting for lock L49032_A
# 1703652537.9 s: 464616 enters lock on side A
# 1703652594.9 s: lock 49032 closes entry A
# 1703653125.3 s: 1300124 opens entry A
# 1703653160.5 s: 459886 is waiting for lock L1300124_A
# 1703653160.5 s: 459886 enters lock on side A
# 1703653228.2 s: 1496287 is waiting for lock L49032_B
# 1703653245.3 s: lock 1300124 closes entry A
# 1703654168.9 s: 1295215 opens entry A
# 1703654168.9 s: 1938225 enters lock on side A
# 1703654288.9 s: lock 1295215 closes entry A
# 1703654394.9 s: lock 49032 opens entry B
# 1703654398.2 s: 1496287 enters lock on side B
# 1703654514.9 s: 49032 closes entry B
# 1703655045.3 s: lock 1300124 opens entry B
# 1703656088.9 s: lock 1295215 opens entry B
# 1703656314.9 s: 49032 opens entry A
# 1703662546.4 s: 2170669 is waiting for lock L1288670_A
# 1703662546.4 s: 2170669 enters lock on side A
# 1703662548.8 s: lock 1288670 closes entry A
# 1703664281.7 s: 663922 is waiting for lock L1273378_A
# 1703664281.7 s: 663922 enters lock on side A
# 1703664341.7 s: lock 1273378 closes entry A
# 1703664348.8 s: lock 1288670 opens entry B
# 1703664377.2 s: 2170669 is waiting for lock L1288670_B
# 1703664377.2 s: 2170669 enters lock on side B
# 1703664468.8 s: 1288670 closes entry B
# 1703665142.1 s: 459886 is waiting for lock L1300095_B
# ...
# 1704205691.3 s: 927645 enters lock on side B
# 1704205781.0 s: 1293260 closes entry B
# 1704207581.0 s: 1293260 opens entry A
# 1704213374.3 s: 459886 is waiting for lock L1293320_B
# 1704213374.3 s: 459886 enters lock on side B
# 1704213410.9 s: 1293320 closes entry B
# 1704214314.5 s: 2382082 is waiting for lock L1306537_B
# 1704214351.0 s: lock 1306537 closes entry A
# 1704215210.9 s: 1293320 opens entry A
# 1704215241.5 s: 459886 is waiting for lock L1293320_A
# 1704215241.5 s: 459886 enters lock on side A
# 1704215330.9 s: lock 1293320 closes entry A
# 1704216151.0 s: lock 1306537 opens entry B
# 1704216154.5 s: 2382082 enters lock on side B
# 1704216271.0 s: 1306537 closes entry B
# 1704217035.4 s: 927645 is waiting for lock L1293297_A
# 1704217086.5 s: 1293297 closes entry B
# 1704217130.9 s: lock 1293320 opens entry B
# 1704218071.0 s: 1306537 opens entry A
# 1704218886.5 s: 1293297 opens entry A
# 1704218895.4 s: 927645 enters lock on side A
# 1704219006.5 s: lock 1293297 closes entry A
# 1704219835.3 s: 2003603 is waiting for lock L1307832_B
# 1704219895.3 s: lock 1307832 closes entry A
# 1704220806.5 s: lock 1293297 opens entry B
# 1704220835.5 s: 927645 is waiting for lock L1293297_B
# 1704220835.5 s: 927645 enters lock on side B
# 1704220926.5 s: 1293297 closes entry B
# 1704221695.3 s: lock 1307832 opens entry B
# 1704221695.3 s: 2003603 enters lock on side B
# 1704221815.3 s: 1307832 closes entry B
# 1704222726.5 s: 1293297 opens entry A
# 1704223615.3 s: 1307832 opens entry A
# 1704224164.0 s: 2003603 is waiting for lock L26499185_B
# 1704224224.0 s: lock 26499185 closes entry A
# 1704226024.0 s: lock 26499185 opens entry B
# 1704226024.0 s: 2003603 enters lock on side B
# 1704226144.0 s: 26499185 closes entry B
# 1704227459.6 s: 241611 is waiting for lock L42863_A
# 1704227503.6 s: 42863 closes entry B
# 1704227646.5 s: lock 1293297 closes entry A
# 1704227646.5 s: 459886 is waiting for lock L1293297_B
# 1704227944.0 s: 26499185 opens entry A
# 1704227957.5 s: 139553 is waiting for lock L49032_B
# 1704227994.9 s: lock 49032 closes entry A
# 1704229303.6 s: 42863 opens entry A
# 1704229309.6 s: 241611 enters lock on side A
# 1704229423.6 s: lock 42863 closes entry A
# 1704229446.5 s: lock 1293297 opens entry B
# 1704229446.5 s: 459886 enters lock on side B
# 1704229566.5 s: 1293297 closes entry B
# 1704229794.9 s: lock 49032 opens entry B
# 1704229797.5 s: 139553 enters lock on side B
# 1704229914.9 s: 49032 closes entry B
# 1704231223.6 s: lock 42863 opens entry B
# 1704231366.5 s: 1293297 opens entry A
# 1704231395.5 s: 459886 is waiting for lock L1293297_A
# 1704231395.5 s: 459886 enters lock on side A
# 1704231486.5 s: lock 1293297 closes entry A
# 1704231714.9 s: 49032 opens entry A
# 1704233242.2 s: 927645 is waiting for lock L1293320_A
# 1704233270.9 s: 1293320 closes entry B
# 1704233286.5 s: lock 1293297 opens entry B
# 1704235070.9 s: 1293320 opens entry A
# 1704235072.2 s: 927645 enters lock on side A
# 1704235190.9 s: lock 1293320 closes entry A
# 1704236990.9 s: lock 1293320 opens entry B
# 1704237021.5 s: 927645 is waiting for lock L1293320_B
# 1704237021.5 s: 927645 enters lock on side B
# 1704237110.9 s: 1293320 closes entry B
# 1704238910.9 s: 1293320 opens entry A
# 1704242741.0 s: lock 1293260 closes entry A
# 1704242741.0 s: 459886 is waiting for lock L1293260_B
# 1704244541.0 s: lock 1293260 opens entry B
# 1704244541.0 s: 459886 enters lock on side B
# 1704244661.0 s: 1293260 closes entry B
# 1704246461.0 s: 1293260 opens entry A
# 1704246491.3 s: 459886 is waiting for lock L1293260_A
# 1704246491.3 s: 459886 enters lock on side A
# 1704246581.0 s: lock 1293260 closes entry A
# 1704247083.7 s: 927645 is waiting for lock L1293434_A
# 1704247141.4 s: 1293434 closes entry B
# 1704248381.0 s: lock 1293260 opens entry B
# 1704248941.4 s: 1293434 opens entry A
# 1704248943.7 s: 927645 enters lock on side A
# 1704249061.4 s: lock 1293434 closes entry A
# 1704250861.4 s: lock 1293434 opens entry B
# 1704250895.8 s: 927645 is waiting for lock L1293434_B
# 1704250895.8 s: 927645 enters lock on side B
# 1704250981.4 s: 1293434 closes entry B
# 1704252781.4 s: 1293434 opens entry A
# 1704253045.5 s: 663922 is waiting for lock L49032_B
# 1704253074.9 s: lock 49032 closes entry A
# 1704254874.9 s: lock 49032 opens entry B
# 1704254875.5 s: 663922 enters lock on side B
# 1704254994.9 s: 49032 closes entry B
# 1704256794.9 s: 49032 opens entry A
# 1704258717.0 s: lock 1293397 closes entry A
# 1704258717.0 s: 459886 is waiting for lock L1293397_B
# 1704259899.6 s: 1215924 is waiting for lock L6824837_A
# 1704259899.6 s: 1215924 enters lock on side A
# 1704259959.6 s: lock 6824837 closes entry A
# 1704260517.0 s: lock 1293397 opens entry B
# 1704260517.0 s: 459886 enters lock on side B
# 1704260637.0 s: 1293397 closes entry B
# 1704261759.6 s: lock 6824837 opens entry B
# 1704262437.0 s: 1293397 opens entry A
# 1704262467.8 s: 459886 is waiting for lock L1293397_A
# 1704262467.8 s: 459886 enters lock on side A
# 1704262557.0 s: lock 1293397 closes entry A
# 1704262976.9 s: 927645 is waiting for lock L1293427_A
# 1704262985.8 s: 1293427 closes entry B
# 1704264357.0 s: lock 1293397 opens entry B
# 1704264785.8 s: 1293427 opens entry A
# 1704264786.9 s: 927645 enters lock on side A
# 1704264905.8 s: lock 1293427 closes entry A
# 1704266705.8 s: lock 1293427 opens entry B
# 1704266742.3 s: 927645 is waiting for lock L1293427_B
# 1704266742.3 s: 927645 enters lock on side B
# 1704266825.8 s: 1293427 closes entry B
# 1704268493.0 s: 241611 is waiting for lock L9305_A
# 1704268506.4 s: 9305 closes entry B
# 1704268625.8 s: 1293427 opens entry A
# 1704269499.6 s: 6824837 closes entry B
# 1704269499.6 s: 464616 is waiting for lock L6824837_A
# 1704270306.4 s: 9305 opens entry A
# 1704270313.0 s: 241611 enters lock on side A
# 1704270426.4 s: lock 9305 closes entry A
# 1704271299.6 s: 6824837 opens entry A
# 1704271299.6 s: 464616 enters lock on side A
# 1704271419.6 s: lock 6824837 closes entry A
# 1704272226.4 s: lock 9305 opens entry B
# 1704273219.6 s: lock 6824837 opens entry B
# 1704275391.2 s: 459886 is waiting for lock L1293308_B
# 1704275411.3 s: lock 1293308 closes entry A
# 1704277211.3 s: lock 1293308 opens entry B
# 1704277221.2 s: 459886 enters lock on side B
# 1704277331.3 s: 1293308 closes entry B
# 1704278334.0 s: 927645 is waiting for lock L1293316_A
# 1704278357.6 s: 1293316 closes entry B
# 1704279131.3 s: 1293308 opens entry A
# 1704279523.5 s: 1215924 is waiting for lock L1292134_A
# 1704279523.5 s: 1215924 enters lock on side A
# 1704279583.5 s: lock 1292134 closes entry A
# 1704280157.6 s: 1293316 opens entry A
# 1704280164.0 s: 927645 enters lock on side A
# 1704280277.6 s: lock 1293316 closes entry A
# 1704281383.5 s: lock 1292134 opens entry B
# 1704281418.5 s: 1215924 is waiting for lock L1292134_B
# 1704281418.5 s: 1215924 enters lock on side B
# 1704281503.5 s: 1292134 closes entry B
# 1704282077.6 s: lock 1293316 opens entry B
# 1704282116.8 s: 927645 is waiting for lock L1293316_B
# 1704282116.8 s: 927645 enters lock on side B
# 1704282197.6 s: 1293316 closes entry B
# 1704283303.5 s: 1292134 opens entry A
# 1704283997.6 s: 1293316 opens entry A
# 1704287148.5 s: 1215924 is waiting for lock L1292135_A
# 1704287148.5 s: 1215924 enters lock on side A
# 1704287208.5 s: lock 1292135 closes entry A
# 1704289008.5 s: lock 1292135 opens entry B
# 1704289052.8 s: 1215924 is waiting for lock L1292135_B
# 1704289052.8 s: 1215924 enters lock on side B
# 1704289128.5 s: 1292135 closes entry B
# 1704290928.5 s: 1292135 opens entry A
# 1704290964.8 s: 1215924 is waiting for lock L5657504_A
# 1704290964.8 s: 1215924 enters lock on side A
# 1704290983.5 s: 464616 is waiting for lock L1292134_A
# 1704290983.5 s: 464616 enters lock on side A
# 1704291024.8 s: lock 5657504 closes entry A
# 1704291043.5 s: lock 1292134 closes entry A
# 1704291507.5 s: 927645 is waiting for lock L1293276_A
# 1704291547.8 s: 1293276 closes entry B
# 1704292824.8 s: lock 5657504 opens entry B
# 1704292843.5 s: lock 1292134 opens entry B
# 1704292878.5 s: 464616 is waiting for lock L1292134_B
# 1704292878.5 s: 464616 enters lock on side B
# 1704292963.5 s: 1292134 closes entry B
# 1704293347.8 s: 1293276 opens entry A
# 1704293357.5 s: 927645 enters lock on side A
# 1704293467.8 s: lock 1293276 closes entry A
# 1704294763.5 s: 1292134 opens entry A
# 1704294789.4 s: 1500941 is waiting for lock L1299673_A
# 1704294789.4 s: 1500941 enters lock on side A
# 1704294838.6 s: lock 1299673 closes entry A
# 1704295267.8 s: lock 1293276 opens entry B
# 1704295310.7 s: 927645 is waiting for lock L1293276_B
# 1704295310.7 s: 927645 enters lock on side B
# 1704295387.8 s: 1293276 closes entry B
# 1704296638.6 s: lock 1299673 opens entry B
# 1704297187.8 s: 1293276 opens entry A
# 1704298608.5 s: 464616 is waiting for lock L1292135_A
# 1704298608.5 s: 464616 enters lock on side A
# 1704298668.5 s: lock 1292135 closes entry A
# 1704300468.5 s: lock 1292135 opens entry B
# 1704300512.8 s: 464616 is waiting for lock L1292135_B
# 1704300512.8 s: 464616 enters lock on side B
# 1704300588.5 s: 1292135 closes entry B
# 1704302388.5 s: 1292135 opens entry A
# 1704302424.8 s: 464616 is waiting for lock L5657504_A
# 1704302484.8 s: 5657504 closes entry B
# 1704304284.8 s: 5657504 opens entry A
# 1704304284.8 s: 464616 enters lock on side A
# 1704304404.8 s: lock 5657504 closes entry A
# 1704306204.8 s: lock 5657504 opens entry B
# 1704307325.5 s: 927645 is waiting for lock L1293435_A
# 1704307330.1 s: 1293435 closes entry B
# 1704309130.1 s: 1293435 opens entry A
# 1704309135.5 s: 927645 enters lock on side A
# 1704309250.1 s: lock 1293435 closes entry A
# 1704310434.5 s: 241611 is waiting for lock L1306537_B
# 1704310471.0 s: lock 1306537 closes entry A
# 1704311050.1 s: lock 1293435 opens entry B
# 1704311091.8 s: 927645 is waiting for lock L1293435_B
# 1704311091.8 s: 927645 enters lock on side B
# 1704311170.1 s: 1293435 closes entry B
# 1704312271.0 s: lock 1306537 opens entry B
# 1704312274.5 s: 241611 enters lock on side B
# 1704312391.0 s: 1306537 closes entry B
# 1704312970.1 s: 1293435 opens entry A
# 1704314191.0 s: 1306537 opens entry A
# 1704321238.4 s: 927645 is waiting for lock L1293356_A
# 1704321261.9 s: 1293356 closes entry B
# 1704323061.9 s: 1293356 opens entry A
# 1704323068.4 s: 927645 enters lock on side A
# 1704323181.9 s: lock 1293356 closes entry A
# 1704324981.9 s: lock 1293356 opens entry B
# 1704325017.6 s: 927645 is waiting for lock L1293356_B
# 1704325017.6 s: 927645 enters lock on side B
# 1704325101.9 s: 1293356 closes entry B
# 1704326901.9 s: 1293356 opens entry A
# 1704334617.1 s: 927645 is waiting for lock L1293436_A
# 1704334666.7 s: 1293436 closes entry B
# 1704336466.7 s: 1293436 opens entry A
# 1704336467.1 s: 927645 enters lock on side A
# 1704336586.7 s: lock 1293436 closes entry A
# 1704338386.7 s: lock 1293436 opens entry B
# 1704338417.6 s: 927645 is waiting for lock L1293436_B
# 1704338417.6 s: 927645 enters lock on side B
# 1704338506.7 s: 1293436 closes entry B
# 1704340306.7 s: 1293436 opens entry A
# 1704349583.5 s: 927645 is waiting for lock L1293289_A
# 1704349629.9 s: 1293289 closes entry B
# 1704351429.9 s: 1293289 opens entry A
# 1704351433.5 s: 927645 enters lock on side A
# 1704351549.9 s: lock 1293289 closes entry A
# 1704353349.9 s: lock 1293289 opens entry B
# 1704353379.7 s: 927645 is waiting for lock L1293289_B
# 1704353379.7 s: 927645 enters lock on side B
# 1704353469.9 s: 1293289 closes entry B
# 1704355269.9 s: 1293289 opens entry A
# 1704360239.6 s: 139553 is waiting for lock L42863_A
# 1704360283.6 s: 42863 closes entry B
# 1704362083.6 s: 42863 opens entry A
# 1704362089.6 s: 139553 enters lock on side A
# 1704362203.6 s: lock 42863 closes entry A
# 1704363700.9 s: 927645 is waiting for lock L1293399_A
# 1704363759.0 s: 1293399 closes entry B
# 1704364003.6 s: lock 42863 opens entry B
# 1704365559.0 s: 1293399 opens entry A
# 1704365560.9 s: 927645 enters lock on side A
# 1704365679.0 s: lock 1293399 closes entry A
# 1704367479.0 s: lock 1293399 opens entry B
# 1704367513.4 s: 927645 is waiting for lock L1293399_B
# 1704367513.4 s: 927645 enters lock on side B
# 1704367599.0 s: 1293399 closes entry B
# 1704369399.0 s: 1293399 opens entry A
# 1704376160.1 s: 927645 is waiting for lock L1293437_A
# 1704376197.8 s: 1293437 closes entry B
# 1704377997.8 s: 1293437 opens entry A
# 1704378000.1 s: 927645 enters lock on side A
# 1704378117.8 s: lock 1293437 closes entry A
# 1704379917.8 s: lock 1293437 opens entry B
# 1704379959.6 s: 927645 is waiting for lock L1293437_B
# 1704379959.6 s: 927645 enters lock on side B
# 1704380037.8 s: 1293437 closes entry B
# 1704381837.8 s: 1293437 opens entry A
# 1704385319.6 s: 663922 is waiting for lock L42863_A
# 1704385363.6 s: 42863 closes entry B
# 1704387163.6 s: 42863 opens entry A
# 1704387169.6 s: 663922 enters lock on side A
# 1704387283.6 s: lock 42863 closes entry A
# 1704389083.6 s: lock 42863 opens entry B
# 1704391555.5 s: 927645 is waiting for lock L1293288_A
# 1704391560.1 s: 1293288 closes entry B
# 1704393360.1 s: 1293288 opens entry A
# 1704393365.5 s: 927645 enters lock on side A
# 1704393480.1 s: lock 1293288 closes entry A
# 1704395280.1 s: lock 1293288 opens entry B
# 1704395324.4 s: 927645 is waiting for lock L1293288_B
# 1704395324.4 s: 927645 enters lock on side B
# 1704395400.1 s: 1293288 closes entry B
# 1704397200.1 s: 1293288 opens entry A
# 1704401273.0 s: 139553 is waiting for lock L9305_A
# 1704401286.4 s: 9305 closes entry B
# 1704403086.4 s: 9305 opens entry A
# 1704403093.0 s: 139553 enters lock on side A
# 1704403206.4 s: lock 9305 closes entry A
# 1704405006.4 s: lock 9305 opens entry B
# 1704409665.2 s: 927645 is waiting for lock L1293331_A
# 1704409695.0 s: 1293331 closes entry B
# 1704411495.0 s: 1293331 opens entry A
# 1704411495.2 s: 927645 enters lock on side A
# 1704411615.0 s: lock 1293331 closes entry A
# 1704413415.0 s: lock 1293331 opens entry B
# 1704413451.6 s: 927645 is waiting for lock L1293331_B
# 1704413451.6 s: 927645 enters lock on side B
# 1704413535.0 s: 1293331 closes entry B
# 1704415335.0 s: 1293331 opens entry A
# 1704423323.9 s: 927645 is waiting for lock L1293405_A
# 1704423366.1 s: 1293405 closes entry B
# 1704425166.1 s: 1293405 opens entry A
# 1704425173.9 s: 927645 enters lock on side A
# 1704425286.1 s: lock 1293405 closes entry A
# 1704426353.0 s: 663922 is waiting for lock L9305_A
# 1704426366.4 s: 9305 closes entry B
# 1704427086.1 s: lock 1293405 opens entry B
# 1704427118.9 s: 927645 is waiting for lock L1293405_B
# 1704427118.9 s: 927645 enters lock on side B
# 1704427206.1 s: 1293405 closes entry B
# 1704428166.4 s: 9305 opens entry A
# 1704428173.0 s: 663922 enters lock on side A
# 1704428286.4 s: lock 9305 closes entry A
# 1704429006.1 s: 1293405 opens entry A
# 1704430086.4 s: lock 9305 opens entry B
# 1704439615.6 s: 927645 is waiting for lock L1293341_A
# 1704439636.7 s: 1293341 closes entry B
# 1704441436.7 s: 1293341 opens entry A
# 1704441445.6 s: 927645 enters lock on side A
# 1704441556.7 s: lock 1293341 closes entry A
# 1704443214.5 s: 139553 is waiting for lock L1306537_B
# 1704443251.0 s: lock 1306537 closes entry A
# 1704443356.7 s: lock 1293341 opens entry B
# 1704443394.6 s: 927645 is waiting for lock L1293341_B
# 1704443394.6 s: 927645 enters lock on side B
# 1704443476.7 s: 1293341 closes entry B
# 1704445051.0 s: lock 1306537 opens entry B
# 1704445054.5 s: 139553 enters lock on side B
# 1704445171.0 s: 1306537 closes entry B
# 1704445276.7 s: 1293341 opens entry A
# 1704446971.0 s: 1306537 opens entry A
# 1704453468.3 s: 927645 is waiting for lock L1293287_A
# 1704453525.1 s: 1293287 closes entry B
# 1704455325.1 s: 1293287 opens entry A
# 1704455328.3 s: 927645 enters lock on side A
# 1704455445.1 s: lock 1293287 closes entry A
# 1704457245.1 s: lock 1293287 opens entry B
# 1704457283.1 s: 927645 is waiting for lock L1293287_B
# 1704457283.1 s: 927645 enters lock on side B
# 1704457365.1 s: 1293287 closes entry B
# 1704459165.1 s: 1293287 opens entry A
# 1704468294.5 s: 663922 is waiting for lock L1306537_B
# 1704468331.0 s: lock 1306537 closes entry A
# 1704470131.0 s: lock 1306537 opens entry B
# 1704470134.5 s: 663922 enters lock on side B
# 1704470251.0 s: 1306537 closes entry B
# 1704472051.0 s: 1306537 opens entry A
# 1704709825.3 s: 459886 is waiting for lock L45980_A
# 1704709829.9 s: 45980 closes entry B
# 1704711629.9 s: 45980 opens entry A
# 1704711635.3 s: 459886 enters lock on side A
# 1704711749.9 s: lock 45980 closes entry A
# 1704713549.9 s: lock 45980 opens entry B

# %% [markdown]
# ### Obtain vessel log information
# The cel below uses the vessel log. The core function *log_entry* is used, which takes four arguments:
#
# - **Log.** A text to describe what is logged.
# - **t.** The timestamp.
# - **Value.**  The value for the log (for sailing this is the distance).
# - **Geometry** The location of the vessel while loggin.

# %%
# vessel_log = gpd.GeoDataFrame(vessels[0].logbook, geometry='Geometry')
# vessel_log = mpd.Trajectory(vessel_log, traj_id='vessel_1_trip_1', obj_id='vessel_1', t='Timestamp')
# vessel_log.to_line_gdf().to_file('plots_routes/dordrecht_afzetting_met_weight_function.gpkg')

# %%
vessels
# Out:
# [<__main__.TransportResource at 0x1b798854be0>,
#  <__main__.TransportResource at 0x1b79880c130>,
#  <__main__.TransportResource at 0x1b7987883d0>,
#  <__main__.TransportResource at 0x1b798656cb0>,
#  <__main__.TransportResource at 0x1b7987f3d90>,
#  <__main__.TransportResource at 0x1b79860bf70>,
#  <__main__.TransportResource at 0x1b7987b5240>,
#  <__main__.TransportResource at 0x1b79854dd20>,
#  <__main__.TransportResource at 0x1b7987f2a10>,
#  <__main__.TransportResource at 0x1b798839a50>,
#  <__main__.TransportResource at 0x1b79846c460>,
#  <__main__.TransportResource at 0x1b79868d4e0>,
#  <__main__.TransportResource at 0x1b7953a06a0>,
#  <__main__.TransportResource at 0x1b791798280>,
#  <__main__.TransportResource at 0x1b78fe742e0>,
#  <__main__.TransportResource at 0x1b78f6cddb0>,
#  <__main__.TransportResource at 0x1b78f072b30>,
#  <__main__.TransportResource at 0x1b78ce58370>,
#  <__main__.TransportResource at 0x1b798584a90>,
#  <__main__.TransportResource at 0x1b78c2134f0>,
#  <__main__.TransportResource at 0x1b796c112a0>,
#  <__main__.TransportResource at 0x1b79691ffd0>,
#  <__main__.TransportResource at 0x1b793647a30>,
#  <__main__.TransportResource at 0x1b79801d7e0>,
#  <__main__.TransportResource at 0x1b7961f4d90>,
#  <__main__.TransportResource at 0x1b797f799c0>,
#  <__main__.TransportResource at 0x1b797f787f0>,
#  <__main__.TransportResource at 0x1b795d39f00>,
#  <__main__.TransportResource at 0x1b795e63760>,
#  <__main__.TransportResource at 0x1b792e4f190>,
#  <__main__.TransportResource at 0x1b7958fde10>,
#  <__main__.TransportResource at 0x1b7951d23e0>,
#  <__main__.TransportResource at 0x1b795f07bb0>,
#  <__main__.TransportResource at 0x1b794e3fc40>,
#  <__main__.TransportResource at 0x1b795731e70>,
#  <__main__.TransportResource at 0x1b7966ae9e0>,
#  <__main__.TransportResource at 0x1b795007a00>,
#  <__main__.TransportResource at 0x1b7937e61a0>,
#  <__main__.TransportResource at 0x1b793a5a980>,
#  <__main__.TransportResource at 0x1b795a47b80>,
#  <__main__.TransportResource at 0x1b792caad10>,
#  <__main__.TransportResource at 0x1b7931620e0>,
#  <__main__.TransportResource at 0x1b794f88340>,
#  <__main__.TransportResource at 0x1b7923b4bb0>,
#  <__main__.TransportResource at 0x1b791b5b730>,
#  <__main__.TransportResource at 0x1b791d24340>,
#  <__main__.TransportResource at 0x1b79113d120>,
#  <__main__.TransportResource at 0x1b79274db10>,
#  <__main__.TransportResource at 0x1b792a3b5e0>,
#  <__main__.TransportResource at 0x1b7923b4c40>,
#  <__main__.TransportResource at 0x1b7917c27a0>,
#  <__main__.TransportResource at 0x1b790bda620>,
#  <__main__.TransportResource at 0x1b78ff495d0>,
#  <__main__.TransportResource at 0x1b790095510>,
#  <__main__.TransportResource at 0x1b790c7e4d0>,
#  <__main__.TransportResource at 0x1b7901be170>,
#  <__main__.TransportResource at 0x1b78f38b8b0>,
#  <__main__.TransportResource at 0x1b78fecbeb0>,
#  <__main__.TransportResource at 0x1b7920c3e50>,
#  <__main__.TransportResource at 0x1b79030e500>,
#  <__main__.TransportResource at 0x1b78ff4ad70>,
#  <__main__.TransportResource at 0x1b78cac4460>,
#  <__main__.TransportResource at 0x1b790bd8b50>,
#  <__main__.TransportResource at 0x1b7fc47c220>,
#  <__main__.TransportResource at 0x1b78c456e00>,
#  <__main__.TransportResource at 0x1b7983d8160>,
#  <__main__.TransportResource at 0x1b78f4b13c0>,
#  <__main__.TransportResource at 0x1b79835f8e0>,
#  <__main__.TransportResource at 0x1b78fa0fbb0>,
#  <__main__.TransportResource at 0x1b788696470>,
#  <__main__.TransportResource at 0x1b788696500>,
#  <__main__.TransportResource at 0x1b788695de0>,
#  <__main__.TransportResource at 0x1b7886961a0>,
#  <__main__.TransportResource at 0x1b7886962c0>,
#  <__main__.TransportResource at 0x1b788696da0>,
#  <__main__.TransportResource at 0x1b788697370>,
#  <__main__.TransportResource at 0x1b788696260>,
#  <__main__.TransportResource at 0x1b788697e80>,
#  <__main__.TransportResource at 0x1b788696110>,
#  <__main__.TransportResource at 0x1b788697790>,
#  <__main__.TransportResource at 0x1b7886961d0>,
#  <__main__.TransportResource at 0x1b788697d00>,
#  <__main__.TransportResource at 0x1b788697b50>,
#  <__main__.TransportResource at 0x1b7886976d0>,
#  <__main__.TransportResource at 0x1b7886974f0>,
#  <__main__.TransportResource at 0x1b788695810>,
#  <__main__.TransportResource at 0x1b7886978e0>,
#  <__main__.TransportResource at 0x1b788694520>,
#  <__main__.TransportResource at 0x1b788694850>,
#  <__main__.TransportResource at 0x1b788695600>,
#  <__main__.TransportResource at 0x1b7886947c0>,
#  <__main__.TransportResource at 0x1b788695db0>,
#  <__main__.TransportResource at 0x1b7886955d0>,
#  <__main__.TransportResource at 0x1b798568b20>,
#  <__main__.TransportResource at 0x1b7886958d0>,
#  <__main__.TransportResource at 0x1b7886954e0>,
#  <__main__.TransportResource at 0x1b798569a20>,
#  <__main__.TransportResource at 0x1b788696d40>,
#  <__main__.TransportResource at 0x1b788694700>,
#  <__main__.TransportResource at 0x1b788697a30>,
#  <__main__.TransportResource at 0x1b788680b20>,
#  <__main__.TransportResource at 0x1b788683c10>,
#  <__main__.TransportResource at 0x1b788683e50>,
#  <__main__.TransportResource at 0x1b7886805e0>,
#  <__main__.TransportResource at 0x1b788683d00>,
#  <__main__.TransportResource at 0x1b788680790>,
#  <__main__.TransportResource at 0x1b788680940>,
#  <__main__.TransportResource at 0x1b788680a30>,
#  <__main__.TransportResource at 0x1b788683d30>,
#  <__main__.TransportResource at 0x1b788680cd0>,
#  <__main__.TransportResource at 0x1b788680880>,
#  <__main__.TransportResource at 0x1b788680c40>,
#  <__main__.TransportResource at 0x1b788680760>,
#  <__main__.TransportResource at 0x1b788680ee0>,
#  <__main__.TransportResource at 0x1b788680df0>,
#  <__main__.TransportResource at 0x1b788680bb0>,
#  <__main__.TransportResource at 0x1b788681240>,
#  <__main__.TransportResource at 0x1b788681270>,
#  <__main__.TransportResource at 0x1b788680550>,
#  <__main__.TransportResource at 0x1b788681360>,
#  <__main__.TransportResource at 0x1b788681210>,
#  <__main__.TransportResource at 0x1b788681450>,
#  <__main__.TransportResource at 0x1b7886814e0>,
#  <__main__.TransportResource at 0x1b788681720>,
#  <__main__.TransportResource at 0x1b788680e20>,
#  <__main__.TransportResource at 0x1b788681060>,
#  <__main__.TransportResource at 0x1b7886819c0>,
#  <__main__.TransportResource at 0x1b788681b40>,
#  <__main__.TransportResource at 0x1b788681390>,
#  <__main__.TransportResource at 0x1b788681c30>,
#  <__main__.TransportResource at 0x1b788681c90>,
#  <__main__.TransportResource at 0x1b788681c60>,
#  <__main__.TransportResource at 0x1b788681930>,
#  <__main__.TransportResource at 0x1b788681f00>,
#  <__main__.TransportResource at 0x1b7886818a0>,
#  <__main__.TransportResource at 0x1b788682110>,
#  <__main__.TransportResource at 0x1b788682050>,
#  <__main__.TransportResource at 0x1b788681e40>,
#  <__main__.TransportResource at 0x1b788681690>,
#  <__main__.TransportResource at 0x1b788682260>,
#  <__main__.TransportResource at 0x1b788682440>,
#  <__main__.TransportResource at 0x1b7886825c0>,
#  <__main__.TransportResource at 0x1b788682620>,
#  <__main__.TransportResource at 0x1b788681cc0>,
#  <__main__.TransportResource at 0x1b7886822f0>,
#  <__main__.TransportResource at 0x1b788682500>,
#  <__main__.TransportResource at 0x1b788682410>,
#  <__main__.TransportResource at 0x1b788682890>,
#  <__main__.TransportResource at 0x1b788682980>,
#  <__main__.TransportResource at 0x1b788682a70>,
#  <__main__.TransportResource at 0x1b788682650>,
#  <__main__.TransportResource at 0x1b788682b60>,
#  <__main__.TransportResource at 0x1b788682c50>,
#  <__main__.TransportResource at 0x1b788682f80>,
#  <__main__.TransportResource at 0x1b788682d10>,
#  <__main__.TransportResource at 0x1b788682dd0>,
#  <__main__.TransportResource at 0x1b788683070>,
#  <__main__.TransportResource at 0x1b788681ea0>,
#  <__main__.TransportResource at 0x1b788682830>,
#  <__main__.TransportResource at 0x1b7886832e0>,
#  <__main__.TransportResource at 0x1b7886833d0>,
#  <__main__.TransportResource at 0x1b788682ec0>,
#  <__main__.TransportResource at 0x1b788683130>,
#  <__main__.TransportResource at 0x1b788683460>,
#  <__main__.TransportResource at 0x1b788683670>,
#  <__main__.TransportResource at 0x1b7886835b0>,
#  <__main__.TransportResource at 0x1b7886834f0>,
#  <__main__.TransportResource at 0x1b788683700>,
#  <__main__.TransportResource at 0x1b788683af0>,
#  <__main__.TransportResource at 0x1b788683a60>,
#  <__main__.TransportResource at 0x1b7886839d0>,
#  <__main__.TransportResource at 0x1b788683370>,
#  <__main__.TransportResource at 0x1b7886805b0>,
#  <__main__.TransportResource at 0x1b7886803d0>,
#  <__main__.TransportResource at 0x1b788683a00>,
#  <__main__.TransportResource at 0x1b788680280>,
#  <__main__.TransportResource at 0x1b788683760>,
#  <__main__.TransportResource at 0x1b788680100>,
#  <__main__.TransportResource at 0x1b788680640>,
#  <__main__.TransportResource at 0x1b788683880>,
#  <__main__.TransportResource at 0x1b788680160>,
#  <__main__.TransportResource at 0x1b7886801c0>,
#  <__main__.TransportResource at 0x1b7886802e0>,
#  <__main__.TransportResource at 0x1b7886804f0>,
#  <__main__.TransportResource at 0x1b787693d00>,
#  <__main__.TransportResource at 0x1b787693e50>,
#  <__main__.TransportResource at 0x1b787693b80>,
#  <__main__.TransportResource at 0x1b7876939d0>,
#  <__main__.TransportResource at 0x1b787693ee0>,
#  <__main__.TransportResource at 0x1b787693790>,
#  <__main__.TransportResource at 0x1b7876936d0>,
#  <__main__.TransportResource at 0x1b7876936a0>,
#  <__main__.TransportResource at 0x1b7876938e0>,
#  <__main__.TransportResource at 0x1b787693af0>,
#  <__main__.TransportResource at 0x1b787693c40>,
#  <__main__.TransportResource at 0x1b787693370>,
#  <__main__.TransportResource at 0x1b7876934f0>,
#  <__main__.TransportResource at 0x1b787693cd0>,
#  <__main__.TransportResource at 0x1b787693430>,
#  <__main__.TransportResource at 0x1b787692fb0>,
#  <__main__.TransportResource at 0x1b7876930a0>,
#  <__main__.TransportResource at 0x1b787693580>,
#  <__main__.TransportResource at 0x1b7876931f0>,
#  <__main__.TransportResource at 0x1b787692d40>,
#  <__main__.TransportResource at 0x1b787692cb0>,
#  <__main__.TransportResource at 0x1b7876938b0>,
#  <__main__.TransportResource at 0x1b787692c20>,
#  <__main__.TransportResource at 0x1b787692b30>,
#  <__main__.TransportResource at 0x1b787692bf0>,
#  <__main__.TransportResource at 0x1b787692a40>,
#  <__main__.TransportResource at 0x1b7876928f0>,
#  <__main__.TransportResource at 0x1b787692ad0>,
#  <__main__.TransportResource at 0x1b787692680>,
#  <__main__.TransportResource at 0x1b7876933a0>,
#  <__main__.TransportResource at 0x1b7876925f0>,
#  <__main__.TransportResource at 0x1b787692410>,
#  <__main__.TransportResource at 0x1b787692320>,
#  <__main__.TransportResource at 0x1b787693130>,
#  <__main__.TransportResource at 0x1b787692260>,
#  <__main__.TransportResource at 0x1b7876921d0>,
#  <__main__.TransportResource at 0x1b787692740>,
#  <__main__.TransportResource at 0x1b787692140>,
#  <__main__.TransportResource at 0x1b787691ff0>,
#  <__main__.TransportResource at 0x1b787691e10>,
#  <__main__.TransportResource at 0x1b787692530>,
#  <__main__.TransportResource at 0x1b787691f90>,
#  <__main__.TransportResource at 0x1b787691ea0>,
#  <__main__.TransportResource at 0x1b787691c00>,
#  <__main__.TransportResource at 0x1b787691b40>,
#  <__main__.TransportResource at 0x1b787691840>,
#  <__main__.TransportResource at 0x1b7876926b0>,
#  <__main__.TransportResource at 0x1b787691b70>,
#  <__main__.TransportResource at 0x1b787691750>,
#  <__main__.TransportResource at 0x1b7876918d0>,
#  <__main__.TransportResource at 0x1b787691e40>,
#  <__main__.TransportResource at 0x1b787691630>,
#  <__main__.TransportResource at 0x1b7876915a0>,
#  <__main__.TransportResource at 0x1b787691480>,
#  <__main__.TransportResource at 0x1b787691870>,
#  <__main__.TransportResource at 0x1b7876910c0>,
#  <__main__.TransportResource at 0x1b787691150>,
#  <__main__.TransportResource at 0x1b787691390>,
#  <__main__.TransportResource at 0x1b787691a80>,
#  <__main__.TransportResource at 0x1b787690dc0>,
#  <__main__.TransportResource at 0x1b787690f70>,
#  <__main__.TransportResource at 0x1b787691060>,
#  <__main__.TransportResource at 0x1b787690c70>,
#  <__main__.TransportResource at 0x1b787690d30>]

# %%
log = gpd.GeoDataFrame()
for vessel in vessels:
    vessel_log = gpd.GeoDataFrame(vessel.logbook, geometry='Geometry')
    vessel_log['trajectory_id'] = f'vessel_{vessel.name}_trip_1'
    vessel_log['object_id'] = f'vessel_{vessel.name}'
    log = pd.concat([log, vessel_log])
mpd_log = mpd.TrajectoryCollection(log, traj_id_col='trajectory_id', obj_id_col='object_id', t='Timestamp')
mpd_log.to_line_gdf().to_file('plots_routes/duitsland_trajectories_met_afzetting_met_weight_function.gpkg')
# Out:
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.
#
# c:\Users\hemert\Anaconda3\envs\trans2\Lib\site-packages\movingpandas\trajectory.py:166: MissingCRSWarning:
#
# Trajectory generated without CRS. Computations will use Euclidean distances.

# %%
lock_dfs = []
for id, lock_object in locks.locks_resources.items():
    lock = pd.DataFrame(lock_object.logbook)
    lock_properties = pd.DataFrame(lock["Value"].values.tolist())
    lock_df = pd.concat([lock, lock_properties], axis=1)
    lock_df['lock_id'] = id
    lock_dfs.append(lock_df)

all_locks_df = pd.concat(lock_dfs, axis=0)
all_locks_df = all_locks_df.drop(columns=['Value'])
all_locks_df.to_csv('plots_routes/trajectories_met_afzetting_met_weight_function_locks.csv')

# %% [markdown]
# ### Visualization of path
# If you get an error regarding ffmpeg use [this](https://stackoverflow.com/questions/13316397/matplotlib-animation-no-moviewriters-available) answer. You have to install ffmpeg in your Conda environment. It can be done using the following command.
#
# ```bash
# #Install ffmpeg using Conda
# conda install -c conda-forge ffmpeg
# ```

# %%
# visualise vessel movements based on the information included in the vessel.log
plot.vessel_kml(env, vessels, stepsize = 60)
#plot.graph_kml(env)

# %%
data.to_pickle('data/ivs/ivs-2024-geocoded_filtered.pkl')

# %%
data = pickle.load(open('data/ivs/ivs-2024-geocoded_filtered.pkl', 'rb'))

# %%
! start explorer .
