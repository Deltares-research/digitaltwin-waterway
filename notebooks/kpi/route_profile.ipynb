# %%
import json
import pathlib

import geopandas as gpd
import pandas as pd

import matplotlib.pyplot as plt

import dtv_backend.charts

plt.style.use('dark_background')

# %%
path = pathlib.Path('../../dtv_backend/tests/user/2022-11-06-config.json')
with path.open() as f:
    config = json.load(f)

# %%
config['quantities'].keys()
# Out:
# dict_keys(['bathymetry', 'waterlevels', 'velocities'])

# %%
dtv_backend.charts.route_profile(config)
# Out:
# (<Figure size 936x576 with 2 Axes>,
#  array([<AxesSubplot:xlabel='Route length [km]', ylabel='Height [m w.r.t. NAP]'>,
#         <AxesSubplot:ylabel='Velocity [m/s]'>], dtype=object))
